# %% [markdown]
# -- Get indicator to analyze
#
#   -- Top/Bottom method
#
#   -- Cosine Vector method
#
# -- Get df_indicators
#
# -- Return list_indicator_to_analyze
#
# 	-- for each indicator.
#
# 	 -- calcule features.

# %%
# Load libraries
import sqlite3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as spstats
from scipy.spatial import distance 
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from tqdm.notebook import tqdm



pd.set_option("display.width"    , 1000)
pd.set_option("display.max_rows" , 1500)

pd.options.display.max_colwidth = 100

# Static info
REMOVE_COUNTRIES_CLUSTERS ="""
   ( 
      CountryCode != 'WLD' AND     CountryCode != 'LMY' AND     CountryCode != 'MIC' AND     CountryCode != 'LMC' AND     CountryCode != 'UMC' AND     CountryCode != 'EAS' AND     CountryCode != 'EAP' AND     CountryCode != 'SAS' AND     CountryCode != 'HIC' AND     CountryCode != 'OED' AND     CountryCode != 'OEC' AND     CountryCode != 'SSF' AND     CountryCode != 'SSA' AND     CountryCode != 'LDC' AND     CountryCode != 'ECS' AND     CountryCode != 'LCN' AND     CountryCode != 'LIC' AND     CountryCode != 'LAC' AND     CountryCode != 'EUU' AND     CountryCode != 'FCS' AND     CountryCode != 'MEA' AND     CountryCode != 'ARB' AND     CountryCode != 'MNA' AND     CountryCode != 'NAC' AND     CountryCode != 'EMU' AND     CountryCode != 'NOC'   AND     CountryCode != 'ECA' AND     CountryCode != 'HPC' 
    )
"""


ARRAY_INDICATORS=[       'Access to electricity (% of population)',
    'Access to non-solid fuel (% of population)',
    'Adjusted net enrolment rate, primary, both sexes (%)',
    'Adjusted net national income (annual % growth)',
    'Adjusted net national income (constant 2005 US$)',
    'Adjusted net national income per capita (annual % growth)',
    'Adjusted net national income per capita (constant 2005 US$)',
    'Adjusted net savings, excluding particulate emission damage (% of GNI)',
    'Adjusted net savings, including particulate emission damage (% of GNI)',
    'Adjusted savings: carbon dioxide damage (% of GNI)',
    'Adjusted savings: consumption of fixed capital (% of GNI)',
    'Adjusted savings: education expenditure (% of GNI)',
    'Adjusted savings: energy depletion (% of GNI)',
    'Adjusted savings: gross savings (% of GNI)',
    'Adjusted savings: mineral depletion (% of GNI)',
    'Adjusted savings: natural resources depletion (% of GNI)',
    'Adjusted savings: net forest depletion (% of GNI)',
    'Adjusted savings: net national savings (% of GNI)',
    'Adjusted savings: particulate emission damage (% of GNI)',
    'Adolescent fertility rate (births per 1,000 women ages 15-19)',
    'Adult literacy rate, population 15+ years, both sexes (%)',
    'Age dependency ratio (% of working-age population)',
    'Age dependency ratio, old (% of working-age population)',
    'Age dependency ratio, young (% of working-age population)',
    'Agricultural irrigated land (% of total agricultural land)',
    'Agricultural land (% of land area)',
    'Agricultural machinery, tractors per 100 sq. km of arable land',
    'Agricultural raw materials exports (% of merchandise exports)',
    'Agricultural raw materials imports (% of merchandise imports)',
    'Agriculture value added per worker (constant 2005 US$)',
    'Agriculture, value added (% of GDP)',
    'Agriculture, value added (annual % growth)',
    'Agriculture, value added (constant 2005 US$)',
    'Alternative and nuclear energy (% of total energy use)',
    'Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)',
    'Annualized average growth rate in per capita real survey mean consumption or income, total population (%)',
    'Arable land (% of land area)',
    'Armed forces personnel, total',
    'Arms exports (SIPRI trend indicator values)',
    'Arms imports (SIPRI trend indicator values)',
    'Automated teller machines (ATMs) (per 100,000 adults)',
    'Average precipitation in depth (mm per year)',
    'Average time to clear exports through customs (days)',
    'Bank capital to assets ratio (%)',
    'Bank nonperforming loans to total gross loans (%)',
    'Battle-related deaths (number of people)',
    'Binding coverage, all products (%)',
    'Binding coverage, manufactured products (%)',
    'Binding coverage, primary products (%)',
    'Bound rate, simple mean, all products (%)',
    'Bound rate, simple mean, manufactured products (%)',
    'Bound rate, simple mean, primary products (%)',
    'Burden of customs procedure, WEF (1=extremely inefficient to 7=extremely efficient)',
    'Business extent of disclosure index (0=less disclosure to 10=more disclosure)',
    'Cash surplus/deficit (% of GDP)',
    'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)',
    'Cause of death, by injury (% of total)',
    'Cause of death, by non-communicable diseases (% of total)',
    'Central government debt, total (% of GDP)',
    'Cereal production (metric tons)', 'Cereal yield (kg per hectare)',
    'Chemicals (% of value added in manufacturing)',
    'Coal rents (% of GDP)',
    'Combustible renewables and waste (% of total energy)',
    'Commercial bank branches (per 100,000 adults)',
    'Communications, computer, etc. (% of service exports, BoP)',
    'Communications, computer, etc. (% of service imports, BoP)',
    'Compensation of employees (% of expense)',
    'Computer, communications and other services (% of commercial service exports)',
    'Computer, communications and other services (% of commercial service imports)',
    'Consumer price index (2010 = 100)',
    'Container port traffic (TEU: 20 foot equivalent units)',
    'Contraceptive prevalence (% of women ages 15-49)',
    'Contributing family workers, total (% of total employed)',
    'Cost of business start-up procedures (% of GNI per capita)',
    'Cost to export (US$ per container)',
    'Cost to import (US$ per container)',
    'Crop production index (2004-2006 = 100)',
    'Current account balance (% of GDP)',
    'Current education expenditure, primary (% of total expenditure in primary public institutions)',
    'Current education expenditure, secondary (% of total expenditure in secondary public institutions)',
    'Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)',
    'Current education expenditure, total (% of total expenditure in public institutions)',
    'Customs and other import duties (% of tax revenue)',
    'Death rate, crude (per 1,000 people)',
    'Delay in obtaining an electrical connection (days)',
    'Deposit interest rate (%)',
    'Depth of credit information index (0=low to 8=high)',
    'Diabetes prevalence (% of population ages 20 to 79)',
    'Distance to frontier score (0=lowest performance to 100=frontier)',
    'Documents to export (number)', 'Documents to import (number)',
    'Droughts, floods, extreme temperatures (% of population, average 1990-2009)',
    'Ease of doing business index (1=most business-friendly regulations)',
    'Electric power consumption (kWh per capita)',
    'Electric power transmission and distribution losses (% of output)',
    'Electricity production from coal sources (% of total)',
    'Electricity production from hydroelectric sources (% of total)',
    'Electricity production from natural gas sources (% of total)',
    'Electricity production from nuclear sources (% of total)',
    'Electricity production from oil sources (% of total)',
    'Electricity production from renewable sources, excluding hydroelectric (% of total)',
    'Emigration rate of tertiary educated (% of total tertiary educated population)',
    'Employers, total (% of employment)',
    'Employment in agriculture (% of total employment)',
    'Employment in industry (% of total employment)',
    'Employment in services (% of total employment)',
    'Employment to population ratio, 15+, total (%) (modeled ILO estimate)',
    'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
    'Energy imports, net (% of energy use)',
    'Energy intensity level of primary energy (MJ/$2011 PPP GDP)',
    'Energy use (kg of oil equivalent per capita)',
    'Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)',
    'Enrolment in primary education, both sexes (number)',
    'Enrolment in secondary education, both sexes (number)',
    'Enrolment in secondary general, both sexes (number)',
    'Enrolment in secondary vocational, both sexes (number)',
    'Expenditure on education as % of total government expenditure (%)',
    'Expenditure on primary as % of government expenditure on education (%)',
    'Expenditure on secondary as % of government expenditure on education (%)',
    'Expenditure on tertiary as % of government expenditure on education (%)',
    'Export value index (2000 = 100)',
    'Export volume index (2000 = 100)',
    'Exports of goods and services (% of GDP)',
    'Exports of goods and services (annual % growth)',
    'Exports of goods and services (constant 2005 US$)',
    'External balance on goods and services (% of GDP)',
    'External resources for health (% of total expenditure on health)',
    'Fertility rate, total (births per woman)',
    'Fertilizer consumption (% of fertilizer production)',
    'Fertilizer consumption (kilograms per hectare of arable land)',
    'Final consumption expenditure (constant 2005 US$)',
    'Final consumption expenditure, etc. (% of GDP)',
    'Final consumption expenditure, etc. (annual % growth)',
    'Final consumption expenditure, etc. (constant 2005 US$)',
    'Firms expected to give gifts in meetings with tax officials (% of firms)',
    'Firms offering formal training (% of firms)',
    'Firms that do not report all sales for tax purposes (% of firms)',
    'Firms using banks to finance investment (% of firms)',
    'Firms using banks to finance working capital (% of firms)',
    'Fixed broadband subscriptions (per 100 people)',
    'Fixed telephone subscriptions (per 100 people)',
    'Food exports (% of merchandise exports)',
    'Food imports (% of merchandise imports)',
    'Food production index (2004-2006 = 100)',
    'Food, beverages and tobacco (% of value added in manufacturing)',
    'Foreign direct investment, net inflows (% of GDP)',
    'Foreign direct investment, net outflows (% of GDP)',
    'Forest area (% of land area)', 'Forest area (sq. km)',
    'Forest rents (% of GDP)',
    'Fossil fuel energy consumption (% of total)',
    'Fuel exports (% of merchandise exports)',
    'GDP deflator (base year varies by country)',
    'GDP growth (annual %)',
    'GDP per capita (constant 2005 US$)',
    'GDP per person employed (constant 1990 PPP $)',
    'GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent)',
    'GDP, PPP (constant 2011 international $)',
    'GEF benefits index for biodiversity (0 = no biodiversity potential to 100 = maximum)',
    'GINI index (World Bank estimate)', 'GNI (constant 2005 US$)',
    'GNI growth (annual %)', 'GNI per capita (constant 2005 US$)',
    'GNI per capita growth (annual %)',
    'GNI per capita, PPP (constant 2011 international $)',
    'General government final consumption expenditure (% of GDP)',
    'General government final consumption expenditure (annual % growth)',
    'General government final consumption expenditure (constant 2005 US$)',
    'Goods and services expense (% of expense)',
    'Government expenditure on education as % of GDP (%)',
    'Government expenditure per primary student as % of GDP per capita (%)',
    'Government expenditure per secondary student as % of GDP per capita (%)',
    'Government expenditure per tertiary student as % of GDP per capita (%)',
    'Grants and other revenue (% of revenue)',
    'Gross capital formation (% of GDP)',
    'Gross capital formation (annual % growth)',
    'Gross capital formation (constant 2005 US$)',
    'Gross domestic income (constant 2005 US$)',
    'Gross domestic savings (% of GDP)',
    'Gross enrolment ratio, pre-primary, both sexes (%)',
    'Gross enrolment ratio, primary and secondary, gender parity index (GPI)',
    'Gross enrolment ratio, primary, both sexes (%)',
    'Gross enrolment ratio, primary, gender parity index (GPI)',
    'Gross enrolment ratio, secondary, both sexes (%)',
    'Gross enrolment ratio, tertiary, both sexes (%)',
    'Gross enrolment ratio, tertiary, gender parity index (GPI)',
    'Gross fixed capital formation (% of GDP)',
    'Gross fixed capital formation (annual % growth)',
    'Gross fixed capital formation (constant 2005 US$)',
    'Gross intake ratio to Grade 1 of primary education, both sexes (%)',
    'Gross national expenditure (% of GDP)',
    'Gross national expenditure (constant 2005 US$)',
    'Gross national expenditure deflator (base year varies by country)',
    'Gross savings (% of GDP)', 'Gross savings (% of GNI)',
    'Gross value added at factor cost (constant 2005 US$)',
    'Health expenditure per capita, PPP (constant 2011 international $)',
    'Health expenditure, private (% of GDP)',
    'Health expenditure, public (% of GDP)',
    'Health expenditure, total (% of GDP)',
    'High-technology exports (% of manufactured exports)',
    'Hospital beds (per 1,000 people)',
    'Household final consumption expenditure (annual % growth)',
    'Household final consumption expenditure (constant 2005 US$)',
    'Household final consumption expenditure per capita (constant 2005 US$)',
    'Household final consumption expenditure per capita growth (annual %)',
    'Household final consumption expenditure, PPP (constant 2011 international $)',
    'Household final consumption expenditure, PPP (current international $)',
    'Household final consumption expenditure, etc. (% of GDP)',
    'Household final consumption expenditure, etc. (annual % growth)',
    'Household final consumption expenditure, etc. (constant 2005 US$)',
    'ICT goods exports (% of total goods exports)',
    'ICT goods imports (% total goods imports)',
    'ICT service exports (% of service exports, BoP)',
    'Import value index (2000 = 100)',
    'Imports of goods and services (% of GDP)',
    'Improved sanitation facilities (% of population with access)',
    'Improved sanitation facilities, rural (% of rural population with access)',
    'Improved sanitation facilities, urban (% of urban population with access)',
    'Income share held by fourth 20%',
    'Income share held by highest 10%',
    'Income share held by highest 20%',
    'Income share held by lowest 10%',
    'Income share held by lowest 20%',
    'Income share held by second 20%',
    'Income share held by third 20%',
    'Industry, value added (% of GDP)',
    'Industry, value added (annual % growth)',
    'Industry, value added (constant 2005 US$)',
    'Inflation, GDP deflator (annual %)',
    'Inflation, consumer prices (annual %)',
    'Informal payments to public officials (% of firms)',
    'Insurance and financial services (% of commercial service exports)',
    'Insurance and financial services (% of commercial service imports)',
    'Insurance and financial services (% of service exports, BoP)',
    'Insurance and financial services (% of service imports, BoP)',
    'Intentional homicides (per 100,000 people)',
    'Interest payments (% of expense)',
    'Interest payments (% of revenue)',
    'Interest rate spread (lending rate minus deposit rate, %)',
    'International migrant stock (% of population)',
    'International migrant stock, total',
    'International tourism, expenditures (% of total imports)',
    'International tourism, number of arrivals',
    'International tourism, number of departures',
    'International tourism, receipts (% of total exports)',
    'Internationally-recognized quality certification (% of firms)',
    'Internet users (per 100 people)',
    'Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
    'Labor force participation rate for ages 15-24, total (%) (national estimate)',
    'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
    'Labor force participation rate, total (% of total population ages 15+) (national estimate)',
    'Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
    'Labor force with primary education (% of total)',
    'Labor force with secondary education (% of total)',
    'Labor force with tertiary education (% of total)',
    'Labor tax and contributions (% of commercial profits)',
    'Lead time to export, median case (days)',
    'Lead time to import, median case (days)',
    'Lending interest rate (%)',
    'Life expectancy at birth, total (years)',
    'Lifetime risk of maternal death (%)',
    'Lifetime risk of maternal death (1 in: rate varies by country)',
    'Liner shipping connectivity index (maximum value in 2004 = 100)',
    'Listed domestic companies, total',
    'Livestock production index (2004-2006 = 100)',
    'Logistics performance index: Overall (1=low to 5=high)',
    'Long-term unemployment (% of total unemployment)',
    'Losses due to theft, robbery, vandalism, and arson (% sales)',
    'Low-birthweight babies (% of births)',
    'Lower secondary completion rate, both sexes (%)',
    'Machinery and transport equipment (% of value added in manufacturing)',
    'Manufactures exports (% of merchandise exports)',
    'Manufactures imports (% of merchandise imports)',
    'Manufacturing, value added (% of GDP)',
    'Manufacturing, value added (annual % growth)',
    'Manufacturing, value added (constant 2005 US$)',
    'Marine protected areas (% of territorial waters)',
    'Market capitalization of listed domestic companies (% of GDP)',
    'Merchandise trade (% of GDP)',
    'Military expenditure (% of GDP)',
    'Military expenditure (% of central government expenditure)',
    'Mobile cellular subscriptions (per 100 people)',
    'Mortality rate, infant (per 1,000 live births)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Mortality rate, under-5 (per 1,000)',
    'Natural gas rents (% of GDP)',
    'Net barter terms of trade index (2000 = 100)',
    'Net enrolment rate, primary, both sexes (%)',
    'Net enrolment rate, secondary, both sexes (%)',
    'Net incurrence of liabilities, domestic (% of GDP)',
    'Net incurrence of liabilities, foreign (% of GDP)',
    'Net intake rate to Grade 1 of primary education, both sexes (%)',
    'New business density (new registrations per 1,000 people ages 15-64)',
    'Nurses and midwives (per 1,000 people)',
    'Official entrance age to lower secondary education (years)',
    'Official entrance age to primary education (years)',
    'Oil rents (% of GDP)',
    'Ores and metals exports (% of merchandise exports)',
    'Ores and metals imports (% of merchandise imports)',
    'Other expense (% of expense)',
    'Other manufacturing (% of value added in manufacturing)',
    'Other taxes payable by businesses (% of commercial profits)',
    'Out-of-pocket health expenditure (% of private expenditure on health)',
    'Out-of-pocket health expenditure (% of total expenditure on health)',
    'Out-of-school children of primary school age, both sexes (number)',
    'Part time employment, total (% of total employment)',
    'Percentage of enrolment in primary education in private institutions (%)',
    'Percentage of enrolment in secondary education in private institutions (%)',
    'Percentage of repeaters in primary education, all grades, both sexes (%)',
    'Percentage of repeaters in secondary general education, all grades, both sexes (%)',
    'Permanent cropland (% of land area)',
    'Personal remittances, received (% of GDP)',
    'Point-of-sale terminals (per 100,000 adults)',
    'Population ages 65 and above (% of total)',
    'Population density (people per sq. km of land area)',
    'Population growth (annual %)', 'Population in largest city',
    'Population in the largest city (% of urban population)',
    'Population in urban agglomerations of more than 1 million (% of total population)',
    'Population living in areas where elevation is below 5 meters (% of total population)',
    'Population, ages 0-14 (% of total)',
    'Population, ages 15-64 (% of total)',
    'Price level ratio of PPP conversion factor (GDP) to market exchange rate',
    'Primary completion rate, both sexes (%)',
    'Primary to secondary general education transition rate, both sexes (%)',
    'Private credit bureau coverage (% of adults)',
    'Procedures to build a warehouse (number)',
    'Procedures to register property (number)',
    'Profit tax (% of commercial profits)',
    'Proportion of seats held by women in national parliaments (%)',
    'Public credit registry coverage (% of adults)',
    'Pump price for diesel fuel (US$ per liter)',
    'Pump price for gasoline (US$ per liter)',
    'Pupil-teacher ratio in primary education (headcount basis)',
    'Pupil-teacher ratio in secondary education (headcount basis)',
    'Quality of port infrastructure, WEF (1=extremely underdeveloped to 7=well developed and efficient by international standards)',
    'Rail lines (total route-km)',
    'Railways, goods transported (million ton-km)',
    'Railways, passengers carried (million passenger-km)',
    'Real effective exchange rate index (2010 = 100)',
    'Real interest rate (%)',
    'Renewable electricity output (% of total electricity output)',
    'Renewable energy consumption (% of total final energy consumption)',
    'Renewable internal freshwater resources per capita (cubic meters)',
    'Renewable internal freshwater resources, total (billion cubic meters)',
    'Research and development expenditure (% of GDP)',
    'Researchers in R&D (per million people)',
    'Revenue, excluding grants (% of GDP)',
    'Risk premium on lending (lending rate minus treasury bill rate, %)',
    'Rural population (% of total population)',
    'Rural population growth (annual %)',
    'S&P Global Equity Indices (annual % change)',
    'Scientific and technical journal articles',
    'Self-employed, total (% of total employed)',
    'Services, etc., value added (% of GDP)',
    'Services, etc., value added (annual % growth)',
    'Services, etc., value added (constant 2005 US$)',
    'Share of tariff lines with international peaks, all products (%)',
    'Share of tariff lines with international peaks, manufactured products (%)',
    'Share of tariff lines with international peaks, primary products (%)',
    'Share of tariff lines with specific rates, all products (%)',
    'Share of tariff lines with specific rates, manufactured products (%)',
    'Share of tariff lines with specific rates, primary products (%)',
    'Share of women in wage employment in the nonagricultural sector (% of total nonagricultural employment)',
    'Share of youth not in education, employment, or training, total (% of youth population)',
    'Social contributions (% of revenue)',
    'Start-up procedures to register a business (number)',
    'Stocks traded, total value (% of GDP)',
    'Stocks traded, turnover ratio of domestic shares (%)',
    'Strength of legal rights index (0=weak to 12=strong)',
    'Subsidies and other transfers (% of expense)',
    'Survey mean consumption or income per capita, bottom 40% of population (2011 PPP $ per day)',
    'Survey mean consumption or income per capita, total population (2011 PPP $ per day)',
    'Survival rate to Grade 5 of primary education, both sexes (%)',
    'Survival rate to the last grade of primary education, both sexes (%)',
    'Tariff rate, applied, simple mean, all products (%)',
    'Tariff rate, applied, simple mean, manufactured products (%)',
    'Tariff rate, applied, simple mean, primary products (%)',
    'Tariff rate, applied, weighted mean, all products (%)',
    'Tariff rate, applied, weighted mean, manufactured products (%)',
    'Tariff rate, applied, weighted mean, primary products (%)',
    'Tariff rate, most favored nation, simple mean, all products (%)',
    'Tariff rate, most favored nation, simple mean, manufactured products (%)',
    'Tariff rate, most favored nation, simple mean, primary products (%)',
    'Tariff rate, most favored nation, weighted mean, all products (%)',
    'Tariff rate, most favored nation, weighted mean, manufactured products (%)',
    'Tariff rate, most favored nation, weighted mean, primary products (%)',
    'Tax payments (number)', 'Tax revenue (% of GDP)',
    'Taxes on goods and services (% of revenue)',
    'Taxes on goods and services (% value added of industry and services)',
    'Taxes on income, profits and capital gains (% of revenue)',
    'Taxes on income, profits and capital gains (% of total taxes)',
    'Taxes on international trade (% of revenue)',
    'Teachers in primary education, both sexes (number)',
    'Teachers in secondary education, both sexes (number)',
    'Technicians in R&D (per million people)',
    'Terrestrial and marine protected areas (% of total territorial area)',
    'Terrestrial protected areas (% of total land area)',
    'Textiles and clothing (% of value added in manufacturing)',
    'Theoretical duration of primary education (years)',
    'Theoretical duration of secondary education (years)',
    'Time required to build a warehouse (days)',
    'Time required to enforce a contract (days)',
    'Time required to get electricity (days)',
    'Time required to register property (days)',
    'Time required to start a business (days)',
    'Time spent dealing with the requirements of government regulations (% of senior management time)',
    'Time to export (days)', 'Time to import (days)',
    'Time to prepare and pay taxes (hours)',
    'Time to resolve insolvency (years)',
    'Total natural resources rents (% of GDP)',
    'Total reserves in months of imports',
    'Total tax rate (% of commercial profits)', 'Trade (% of GDP)',
    'Trade in services (% of GDP)',
    'Transport services (% of commercial service exports)',
    'Transport services (% of commercial service imports)',
    'Transport services (% of service exports, BoP)',
    'Transport services (% of service imports, BoP)',
    'Travel services (% of commercial service exports)',
    'Travel services (% of commercial service imports)',
    'Travel services (% of service exports, BoP)',
    'Travel services (% of service imports, BoP)',
    'Unemployment with tertiary education (% of total unemployment)',
    'Unemployment with secondary education (% of total unemployment)',
    'Unemployment with primary education (% of total unemployment)',
    'Unmet need for contraception (% of married women ages 15-49)',                  
    'Unemployment, total (% of total labor force)',
    'Unmet need for contraception (% of married women ages 15-49)',
    'Urban population (% of total)',
    'Urban population growth (annual %)',
    'Vulnerable employment, total (% of total employment)',
    'Wage and salaried workers, total (% of total employed)',
    'Wholesale price index (2010 = 100)',
    'Youth literacy rate, population 15-24 years, both sexes (%)']


ARRAY_INDICATORS = list(set(ARRAY_INDICATORS))

conn = sqlite3.connect('../input/world-development-indicators/database.sqlite')

# %% [markdown]
# # Get indicators to analyze

# %% [markdown]
# ## Top/Bottom method

# %% [markdown]
# ### Get data for the country

# %%
CountryName = 'Spain'  # Change this to another country

# %%
CountryCode = pd.read_sql(f"""SELECT CountryCode 
               FROM Indicators
               WHERE CountryName = '{CountryName}'
               LIMIT 1""",
           conn).values[0][0]

Region  = pd.read_sql(f"""SELECT Region
               FROM Country
               WHERE CountryCode = '{CountryCode}'
               LIMIT 1""", conn).values[0][0]

Neigbours_in_the_zone  = pd.read_sql(f"""SELECT *
               FROM Country
               WHERE Region = '{Region}'
               """, conn)

neighbours = Neigbours_in_the_zone.shape[0]
neighbours

print(f"Lets analyze the indicator for: {CountryName} ({CountryCode}), from zone: {Region}, that has {neighbours} countries")
# Out:
# Lets analyze the indicator for: Spain (ESP), from zone: Europe & Central Asia, that has 57 countries

# %%
# %%time

### Rankings

LIMIT_TOPBOTTOM_FEATURES=10

### For each indicator, last values, for all countries.
def get_indicators_topbottom_method(CountryCode):
    """Return DataFrame with the indicators ranked according the position in the region for a given country (aka, very good/very bad indicators for a country )"""
    arr_rankings = []
    
    Region  = pd.read_sql(f"""SELECT Region
               FROM Country
               WHERE CountryCode = '{CountryCode}'
               LIMIT 1""", conn).values[0][0]
    
    Neigbours_in_the_zone  = pd.read_sql(f"""SELECT *
                   FROM Country
                   WHERE Region = '{Region}'
                   """, conn)

    neighbours = Neigbours_in_the_zone.shape[0]
    neighbours
      
    for indicator in tqdm(ARRAY_INDICATORS) :
            
        SQL=f"""   
        SELECT 
            Indicators.CountryCode AS CountryCode, 
            Indicators.Value AS  'Last Value in country', 
            Indicators.IndicatorName
        FROM
        Indicators,
        (
            SELECT  (CountryCode||'_'||MAX(Year)) AS Country_Year
            FROM   Indicators 
            WHERE  IndicatorName = '{indicator}'
                   AND CountryCode in ( SELECT CountryCode  FROM Country WHERE Region = '{Region}' )
            GROUP BY CountryCode, Year
            ORDER BY Value desc
        ) LAST_YEAR_WITH_DATA
        WHERE 
            LAST_YEAR_WITH_DATA.Country_Year =  (Indicators.CountryCode||'_'||Indicators.Year) AND
            IndicatorName = '{indicator}'
        ORDER BY Value desc
        """
        #print(f"SQL={SQL}")
        df_sql =  pd.read_sql(SQL,conn)
        for ascending in [True,False]:
            df_indicators = df_sql.copy()

            df_indicators = df_indicators.sort_values(by=['Last Value in country'], ascending=ascending)
            if CountryCode not in df_indicators.CountryCode.head(LIMIT_TOPBOTTOM_FEATURES).values: continue

            df_indicators['order'] = "bottom" if ascending else "top"
            df_indicators['average Value in region']=  df_indicators['Last Value in country'].mean()
            df_indicators = df_indicators.head(LIMIT_TOPBOTTOM_FEATURES)
            df_indicators['ranking'] = range(1,df_indicators.shape[0]+1)
            df_indicators['distance with average'] = ( 
                (
                    (df_indicators['Last Value in country'] - df_indicators['average Value in region']) **2
                    / 
                    (df_indicators['average Value in region']) **2
                )  )
            df_indicators['distance with average'] = df_indicators['distance with average'].apply(lambda col:pd.to_numeric(col, errors='coerce'))
 
            arr_rankings.append(df_indicators.query( f'CountryCode == "{CountryCode}"', engine = 'python'  ).head(1))

    

    df_rankings = pd.concat(arr_rankings)
    df_rankings['countries in the region'] = neighbours
    df_rankings = df_rankings.sort_values('ranking')
    df_rankings['Region'] = Region 

    df_rankings= df_rankings[['ranking','order','IndicatorName','Last Value in country',
                       'average Value in region','distance with average','CountryCode' ,'Region', 'countries in the region'
                      ]]

    return  df_rankings


df_rankings = get_indicators_topbottom_method(CountryCode)
df_rankings = df_rankings.head(25)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=438.0), HTML(value='')))
# CPU times: user 10.8 s, sys: 7.76 s, total: 18.6 s
# Wall time: 18.5 s

# %%
df_rankings.head(30)
# Out:
#      ranking   order                                                                                     IndicatorName  Last Value in country  average Value in region  distance with average CountryCode                 Region  countries in the region
# 0          1     top                                                       Net enrolment rate, primary, both sexes (%)              99.997190                94.017695               0.004045         ESP  Europe & Central Asia                       57
# 0          1     top                                              Adjusted net enrolment rate, primary, both sexes (%)              99.997190                95.277061               0.002454         ESP  Europe & Central Asia                       57
# 910        1  bottom                                   Unemployment with secondary education (% of total unemployment)               7.400000                49.480351               0.723258         ESP  Europe & Central Asia                       57
# 658        1  bottom                                                        Taxes on goods and services (% of revenue)               9.558768                33.697314               0.513135         ESP  Europe & Central Asia                       57
# 0          1     top                                                          Time required to start a business (days)             138.000000                20.780268              31.819927         ESP  Europe & Central Asia                       57
# 651        1  bottom                              Taxes on goods and services (% value added of industry and services)               2.575314                13.903937               0.663863         ESP  Europe & Central Asia                       57
# 0          1     top                                                                  Listed domestic companies, total            3538.000000               335.466119              91.136036         ESP  Europe & Central Asia                       57
# 358        2     top                                                                Binding coverage, all products (%)             100.000000                98.614088               0.000198         ESP  Europe & Central Asia                       57
# 1          2     top                                   Net intake rate to Grade 1 of primary education, both sexes (%)              98.988243                79.050172               0.063615         ESP  Europe & Central Asia                       57
# 837        2  bottom                                                 Adjusted savings: net forest depletion (% of GNI)               0.000000                 0.085367               1.000000         ESP  Europe & Central Asia                       57
# 1          2     top                                     Taxes on income, profits and capital gains (% of total taxes)              68.677883                33.503132               1.102278         ESP  Europe & Central Asia                       57
# 113        2  bottom                                                           Lead time to export, median case (days)               1.000000                 2.485481               0.357202         ESP  Europe & Central Asia                       57
# 123        2  bottom  Time spent dealing with the requirements of government regulations (% of senior management time)               0.800000                 8.116800               0.812592         ESP  Europe & Central Asia                       57
# 2          3     top                                                      Point-of-sale terminals (per 100,000 adults)            3523.039000              1349.233603               2.595775         ESP  Europe & Central Asia                       57
# 363        3     top                                                            Binding coverage, primary products (%)             100.000000                97.823469               0.000495         ESP  Europe & Central Asia                       57
# 2          3     top              GEF benefits index for biodiversity (0 = no biodiversity potential to 100 = maximum)               6.842703                 1.700861               9.139028         ESP  Europe & Central Asia                       57
# 671        3  bottom                                                                            Tax revenue (% of GDP)               7.161857                20.054054               0.413285         ESP  Europe & Central Asia                       57
# 64         4  bottom                                  Firms that do not report all sales for tax purposes (% of firms)              18.330000                44.543971               0.346328         ESP  Europe & Central Asia                       57
# 107        4     top                         Improved sanitation facilities, rural (% of rural population with access)             100.000000                90.653517               0.010630         ESP  Europe & Central Asia                       57
# 91         5  bottom                                                            Cause of death, by injury (% of total)               3.400000                 6.317708               0.213287         ESP  Europe & Central Asia                       57
# 4          5     top                                                                   Income share held by fourth 20%              23.580000                22.401264               0.002769         ESP  Europe & Central Asia                       57
# 118        5  bottom                                                Informal payments to public officials (% of firms)               4.400000                30.930894               0.735731         ESP  Europe & Central Asia                       57
# 5          6     top                                      Pupil-teacher ratio in secondary education (headcount basis)              26.140250                12.538447               1.176807         ESP  Europe & Central Asia                       57
# 68         6     top                                                        Access to non-solid fuel (% of population)             100.000000                87.612393               0.019991         ESP  Europe & Central Asia                       57
# 5          6     top                       Droughts, floods, extreme temperatures (% of population, average 1990-2009)               0.729194                 0.392112               0.739005         ESP  Europe & Central Asia                       57

# %% [markdown]
# ## Cosine distance  method

# %% [markdown]
# https://datascience-enthusiast.com/figures/cosine_sim.png

# %%
CountryCode1 = 'ESP'
CountryCode2 = 'WLD'
filter_indicator = '%'
DEBUG=False

def get_indicators_cosine_method(CountryCode1,Region,filter_indicator='%',DEBUG=False):    
    """ Compare two countries with a specific filter"""
    
    result_array = []
    df_result = pd.DataFrame()
    Neigbours_in_the_zone  = pd.read_sql(f"""SELECT *
                   FROM Country
                   WHERE Region = '{Region}'
                   """, conn)

    neighbours = Neigbours_in_the_zone.shape[0]
    neighbours
    
    # We extract indicator from
    df_indicators = pd.read_sql(f"""
                   SELECT distinct(IndicatorName) as IndicatorName
                   FROM Indicators
                   WHERE  CountryCode  = '{CountryCode1}'
                          AND IndicatorName LIKE  '%{filter_indicator}%' """,
               conn)
    if DEBUG : print(f"""SELECT distinct(IndicatorName) as IndicatorName
                   FROM Indicators
                   WHERE  CountryCode  = '{CountryCode1}'
                          AND IndicatorName LIKE  '%{filter_indicator}%' """)

    df_world = pd.read_sql(f"""
                    SELECT distinct(IndicatorName) as IndicatorName
                    FROM Indicators
                    WHERE CountryCode in ( SELECT CountryCode  FROM Country WHERE Region = '{Region}' )
                          AND IndicatorName LIKE  '%{filter_indicator}%'""",
               conn)
    if DEBUG : print(f"""2 : 
                    SELECT distinct(IndicatorName) as IndicatorName
                    FROM Indicators
                    WHERE CountryCode in ( SELECT CountryCode  FROM Country WHERE Region = '{Region}' )
                          AND IndicatorName LIKE  '%{filter_indicator}%' """)

    indicators_array = df_indicators.IndicatorName.values
    world_array      = df_world.IndicatorName.values
    indicator_array  = set(indicators_array) & set( world_array)  & set( ARRAY_INDICATORS)
    indicator_array_size = len (indicator_array)

    
    SQL=  f"""
    SELECT Year,Value,IndicatorName
    FROM Indicators
    WHERE CountryCode = '{CountryCode1}' AND Value != 0 """ 
    df_CountryCode1_master =  pd.read_sql(SQL,conn)
    

    
    SQL=  f"""
    SELECT Year,AVG(Value) AS Value, IndicatorName
    FROM Indicators
    WHERE CountryCode in ( SELECT CountryCode  FROM Country WHERE Region = '{Region}' ) 
    GROUP BY CountryCode, Year,IndicatorName""" 
    df_CountryCode2_master =  pd.read_sql(SQL,conn)

    
    for IndicatorName in tqdm(indicator_array) :
        df_CountryCode1 = df_CountryCode1_master.copy()
        df_CountryCode2 = df_CountryCode2_master.copy()
        df_1 = df_CountryCode1.loc[df_CountryCode1['IndicatorName'] == IndicatorName]
        df_2 = df_CountryCode2.loc[df_CountryCode2['IndicatorName'] == IndicatorName]

        df_dst = pd.merge(df_1, df_2, on='Year')
        length = df_dst.shape[0]
        if length < 3 : 
            if DEBUG : print(f"df_values: {IndicatorName} not enough common values  {length} ,to evaluate properly")
            continue
        dst = distance.cosine(df_dst.Value_x.values ,df_dst.Value_y.values )

     
        
        
        result_array.append({ 
            'Cosine distance country-region' : dst                          ,
            "IndicatorName"                  : IndicatorName                ,
            'Last Value in country'          : df_dst.Value_x.values[-1]    ,
            'average Value in region'        : df_dst.Value_y.values.mean() ,
            #'Region Value'                   : df_dst.Value_y.values[-1]    ,
        } )


        
    df_result = pd.DataFrame(result_array) 

    length = df_result.shape[0]
    if DEBUG : print(df_result.columns,length)

    if length == 0 : 
        if DEBUG : print(f"Vacio: {IndicatorName} al the end")
        return None
    
    df_result['distance with average'] = ( 
        (
            (df_result['Last Value in country'] - df_result['average Value in region']) **2
            / 
            (df_result['average Value in region']) **2
        )  )
    df_result['distance with average'] = df_result['distance with average'].apply(lambda col:pd.to_numeric(col, errors='coerce'))
    df_result['CountryCode']             = CountryCode1
    df_result['Region']                  = Region
    df_result['countries in the region'] = neighbours

    df_result = df_result[df_result['Last Value in country'].notna()]
    df_result = df_result.sort_values('Cosine distance country-region')
    return df_result    



df_cosine_results = get_indicators_cosine_method('ESP',Region)
df_cosine_results.head(20)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=438.0), HTML(value='')))
#      Cosine distance country-region                                                                                       IndicatorName  Last Value in country  average Value in region  distance with average CountryCode                 Region  countries in the region
# 21                         0.000040                                         Youth literacy rate, population 15-24 years, both sexes (%)              99.669258                99.280955               0.000015         ESP  Europe & Central Asia                       57
# 129                        0.000099                                                             Access to electricity (% of population)             100.000000                99.572972               0.000018         ESP  Europe & Central Asia                       57
# 174                        0.000271                                                                     Income share held by fourth 20%              23.450000                22.414477               0.002134         ESP  Europe & Central Asia                       57
# 181                        0.000461                                           Gross enrolment ratio, primary, gender parity index (GPI)               1.009460                 0.991537               0.000327         ESP  Europe & Central Asia                       57
# 333                        0.000620                                           Adult literacy rate, population 15+ years, both sexes (%)              98.079124                97.011481               0.000121         ESP  Europe & Central Asia                       57
# 296                        0.000980      Current education expenditure, primary (% of total expenditure in primary public institutions)              95.908958                92.549688               0.001317         ESP  Europe & Central Asia                       57
# 433                        0.001231  Current education expenditure, secondary (% of total expenditure in secondary public institutions)              91.605614                92.424764               0.000079         ESP  Europe & Central Asia                       57
# 78                         0.001379                Current education expenditure, total (% of total expenditure in public institutions)              92.155197                91.786435               0.000016         ESP  Europe & Central Asia                       57
# 124                        0.001391                             Gross enrolment ratio, primary and secondary, gender parity index (GPI)               1.007720                 0.993185               0.000214         ESP  Europe & Central Asia                       57
# 351                        0.001440                                                                      Income share held by third 20%              17.030000                16.906247               0.000054         ESP  Europe & Central Asia                       57
# 261                        0.001505                           Improved sanitation facilities, urban (% of urban population with access)              99.800000                95.908346               0.001646         ESP  Europe & Central Asia                       57
# 243                        0.001612                                                              Binding coverage, primary products (%)             100.000000                97.823469               0.000495         ESP  Europe & Central Asia                       57
# 89                         0.001687                                                Adjusted net enrolment rate, primary, both sexes (%)              98.489731                95.377286               0.001065         ESP  Europe & Central Asia                       57
# 70                         0.001889                                                         Net enrolment rate, primary, both sexes (%)              98.441780                94.101064               0.002128         ESP  Europe & Central Asia                       57
# 113                        0.001911                                                                 Population, ages 15-64 (% of total)              66.685543                64.517429               0.001129         ESP  Europe & Central Asia                       57
# 346                        0.002130                                                             Life expectancy at birth, total (years)              82.426829                71.639248               0.022675         ESP  Europe & Central Asia                       57
# 238                        0.002328                                Survival rate to the last grade of primary education, both sexes (%)              97.147438                94.791047               0.000618         ESP  Europe & Central Asia                       57
# 16                         0.002439                                                                  Binding coverage, all products (%)             100.000000                98.614088               0.000198         ESP  Europe & Central Asia                       57
# 318                        0.002771                                           Cause of death, by non-communicable diseases (% of total)              91.800000                87.362500               0.002580         ESP  Europe & Central Asia                       57
# 256                        0.002847                                                         Binding coverage, manufactured products (%)             100.000000                98.848062               0.000136         ESP  Europe & Central Asia                       57

# %%
df_cosine_results.sort_values(by=['distance with average'], ascending=False).head(20)
# Out:
#      Cosine distance country-region                                                                         IndicatorName  Last Value in country  average Value in region  distance with average CountryCode                 Region  countries in the region
# 250                        0.424460   Electricity production from renewable sources, excluding hydroelectric (% of total)           2.639793e+01             2.022040e+00             145.325358         ESP  Europe & Central Asia                       57
# 171                        0.551439                                                      Listed domestic companies, total           3.419000e+03             3.405369e+02              81.722087         ESP  Europe & Central Asia                       57
# 319                        0.903261                                                    Rural population growth (annual %)          -1.551949e+00            -1.976884e-01              46.929087         ESP  Europe & Central Asia                       57
# 211                        0.615465                                                    International migrant stock, total           6.377524e+06             9.341270e+05              33.956914         ESP  Europe & Central Asia                       57
# 372                        0.472543                                             International tourism, number of arrivals           6.066100e+07             9.008123e+06              32.879136         ESP  Europe & Central Asia                       57
# 119                        0.556412                                                       Cash surplus/deficit (% of GDP)          -8.916626e+00            -1.655011e+00              19.251506         ESP  Europe & Central Asia                       57
# 121                        0.456166                                          Agriculture, value added (constant 2005 US$)           3.556207e+10             7.256721e+09              15.214450         ESP  Europe & Central Asia                       57
# 223                        0.565617                                             Scientific and technical journal articles           2.291030e+04             4.818115e+03              14.100282         ESP  Europe & Central Asia                       57
# 303                        1.013096         Computer, communications and other services (% of commercial service imports)           5.108085e+01            -1.962841e+01              12.977243         ESP  Europe & Central Asia                       57
# 300                        0.516728                                         Public credit registry coverage (% of adults)           4.980000e+01             1.132262e+01              11.548272         ESP  Europe & Central Asia                       57
# 67                         0.535979              Percentage of enrolment in primary education in private institutions (%)           3.167808e+01             7.283786e+00              11.216624         ESP  Europe & Central Asia                       57
# 210                        0.635074                                     Net incurrence of liabilities, foreign (% of GDP)           6.136880e+00             1.467971e+00              10.115704         ESP  Europe & Central Asia                       57
# 273                        0.403197                                Container port traffic (TEU: 20 foot equivalent units)           1.402016e+07             3.382160e+06               9.893087         ESP  Europe & Central Asia                       57
# 390                        0.973188                                            Agriculture, value added (annual % growth)          -3.737019e+00             1.831404e+00               9.244774         ESP  Europe & Central Asia                       57
# 258                        0.676523  GEF benefits index for biodiversity (0 = no biodiversity potential to 100 = maximum)           6.842703e+00             1.700861e+00               9.139028         ESP  Europe & Central Asia                       57
# 310                        0.358062                                                   Permanent cropland (% of land area)           9.933828e+00             2.501126e+00               8.831256         ESP  Europe & Central Asia                       57
# 86                         0.475628                                     Exports of goods and services (constant 2005 US$)           3.724670e+11             9.628279e+10               8.228113         ESP  Europe & Central Asia                       57
# 168                        0.479038                Household final consumption expenditure, PPP (current international $)           8.083603e+11             2.145804e+11               7.657215         ESP  Europe & Central Asia                       57
# 120                        0.538594                                       Services, etc., value added (constant 2005 US$)           7.970071e+11             2.199631e+11               6.882052         ESP  Europe & Central Asia                       57
# 331                        0.490617                                              GDP, PPP (constant 2011 international $)           1.475756e+12             4.300464e+11               5.912784         ESP  Europe & Central Asia                       57

# %%
def Draw_Difference_Countries(IndicatorName,CountryCode1, CountryCode2):
    """ Draw difference between a country and the rest of the world"""
    CountryCode = CountryCode1
    conn = sqlite3.connect('../input/world-development-indicators/database.sqlite')
    df = pd.read_sql(f"""SELECT CountryName,IndicatorName,IndicatorCode,Year,Value
                   FROM Indicators
                   WHERE IndicatorName = '{IndicatorName}' 
                     AND CountryCode   = '{CountryCode}'  """,
               conn)

    length = df.shape[0]
    large_name  = df.CountryName.values[0]

    x = df['Year' ].values
    y = df['Value'].values
    x = x.reshape(length,1)
    y = y.reshape(length,1)
    fig = plt.figure()
    plt.scatter(x,y,color='red')
    regr = LinearRegression()
    regr.fit(x,y)
    plt.plot(x,regr.predict(x),color='red',label=f'{large_name}')
    otro =  pd.read_sql(f"""SELECT IndicatorName,IndicatorCode,Year,AVG(Value) As Value
                   FROM Indicators
                   WHERE IndicatorName = '{IndicatorName}' 
                     AND CountryCode != '{CountryCode}' 
                     AND CountryCode = '{CountryCode2}' 
                     group by Year""",
               conn)
    
    if otro.shape[0] == 0 :
        print(f"vacio, {IndicatorName}")
        otro =  pd.read_sql(f"""SELECT IndicatorName,IndicatorCode,Year,AVG(Value) As Value
               FROM Indicators
               WHERE IndicatorName = '{IndicatorName}' 
                 AND CountryCode != '{CountryCode}' 
                group by Year""",
           conn)
    
    length = otro.shape[0]

    x = otro['Year' ].values
    y = otro['Value'].values
    x = x.reshape(length,1)
    y = y.reshape(length,1)
    regr = LinearRegression()
    regr.fit(x,y)

    # Get Large name for the title
    CountryName2 = pd.read_sql(f"""SELECT CountryName
               FROM Indicators
               WHERE CountryCode = '{CountryCode2}'
               LIMIT 1""",
           conn).values[0][0]
    
    plt.title(f"{IndicatorName}, {large_name} vs {CountryName2} ")
    plt.scatter(x,y,color='gray')
    plt.plot(x,regr.predict(x),color='gray',label=f'{CountryName2}')
    plt.legend(loc=2)

    return plt ,df,otro

def Draw_Difference_Region(IndicatorName,CountryCode1, Region):
    """ Draw difference between a country and the rest of the world"""
    CountryCode = CountryCode1
    conn = sqlite3.connect('../input/world-development-indicators/database.sqlite')
    df = pd.read_sql(f"""SELECT CountryName,IndicatorName,Year,Value
                   FROM Indicators
                   WHERE IndicatorName = '{IndicatorName}' 
                     AND CountryCode   = '{CountryCode}'  """,
               conn)

    length = df.shape[0]
    large_name  = df.CountryName.values[0]

    x = df['Year' ].values
    y = df['Value'].values
    x = x.reshape(length,1)
    y = y.reshape(length,1)
    fig = plt.figure()
    plt.scatter(x,y,color='red')
    regr = LinearRegression()
    regr.fit(x,y)
    plt.plot(x,regr.predict(x),color='red',label=f'{large_name}')
    otro =  pd.read_sql(f"""SELECT IndicatorName,Year,AVG(Value) As Value
                   FROM Indicators
                   WHERE IndicatorName = '{IndicatorName}' AND
                        CountryCode in ( SELECT CountryCode  FROM Country WHERE Region = '{Region}' )  
                   group by Year,IndicatorName""",
               conn)
    
    if otro.empty :
        print(f"vacio, {IndicatorName}")
        return None
    

    x = otro['Year' ].values
    y = otro['Value'].values
    x = x.reshape(length,1)
    y = y.reshape(length,1)
    regr = LinearRegression()
    regr.fit(x,y)

    # Get Large name for the title
    CountryName2 = pd.read_sql(f"""SELECT CountryName
               FROM Indicators
               WHERE CountryCode = '{CountryCode2}'
               LIMIT 1""",
           conn).values[0][0]
    
    plt.title(f"{IndicatorName},\n {large_name} vs '{Region}'' ")
    plt.scatter(x,y,color='gray')
    plt.plot(x,regr.predict(x),color='gray',label=f'{Region}')
    plt.legend(loc=2)

    return plt ,df,otro

# %%
for IndicatorName in df_cosine_results.tail(20).IndicatorName.values :
    try:
        plt ,df_country,df_rest = Draw_Difference_Region(IndicatorName,CountryCode,Region)
    except :
        pass

# %%
 df_cosine_results.head(20)
# Out:
#      Cosine distance country-region                                                                                       IndicatorName  Last Value in country  average Value in region  distance with average CountryCode                 Region  countries in the region
# 21                         0.000040                                         Youth literacy rate, population 15-24 years, both sexes (%)              99.669258                99.280955               0.000015         ESP  Europe & Central Asia                       57
# 129                        0.000099                                                             Access to electricity (% of population)             100.000000                99.572972               0.000018         ESP  Europe & Central Asia                       57
# 174                        0.000271                                                                     Income share held by fourth 20%              23.450000                22.414477               0.002134         ESP  Europe & Central Asia                       57
# 181                        0.000461                                           Gross enrolment ratio, primary, gender parity index (GPI)               1.009460                 0.991537               0.000327         ESP  Europe & Central Asia                       57
# 333                        0.000620                                           Adult literacy rate, population 15+ years, both sexes (%)              98.079124                97.011481               0.000121         ESP  Europe & Central Asia                       57
# 296                        0.000980      Current education expenditure, primary (% of total expenditure in primary public institutions)              95.908958                92.549688               0.001317         ESP  Europe & Central Asia                       57
# 433                        0.001231  Current education expenditure, secondary (% of total expenditure in secondary public institutions)              91.605614                92.424764               0.000079         ESP  Europe & Central Asia                       57
# 78                         0.001379                Current education expenditure, total (% of total expenditure in public institutions)              92.155197                91.786435               0.000016         ESP  Europe & Central Asia                       57
# 124                        0.001391                             Gross enrolment ratio, primary and secondary, gender parity index (GPI)               1.007720                 0.993185               0.000214         ESP  Europe & Central Asia                       57
# 351                        0.001440                                                                      Income share held by third 20%              17.030000                16.906247               0.000054         ESP  Europe & Central Asia                       57
# 261                        0.001505                           Improved sanitation facilities, urban (% of urban population with access)              99.800000                95.908346               0.001646         ESP  Europe & Central Asia                       57
# 243                        0.001612                                                              Binding coverage, primary products (%)             100.000000                97.823469               0.000495         ESP  Europe & Central Asia                       57
# 89                         0.001687                                                Adjusted net enrolment rate, primary, both sexes (%)              98.489731                95.377286               0.001065         ESP  Europe & Central Asia                       57
# 70                         0.001889                                                         Net enrolment rate, primary, both sexes (%)              98.441780                94.101064               0.002128         ESP  Europe & Central Asia                       57
# 113                        0.001911                                                                 Population, ages 15-64 (% of total)              66.685543                64.517429               0.001129         ESP  Europe & Central Asia                       57
# 346                        0.002130                                                             Life expectancy at birth, total (years)              82.426829                71.639248               0.022675         ESP  Europe & Central Asia                       57
# 238                        0.002328                                Survival rate to the last grade of primary education, both sexes (%)              97.147438                94.791047               0.000618         ESP  Europe & Central Asia                       57
# 16                         0.002439                                                                  Binding coverage, all products (%)             100.000000                98.614088               0.000198         ESP  Europe & Central Asia                       57
# 318                        0.002771                                           Cause of death, by non-communicable diseases (% of total)              91.800000                87.362500               0.002580         ESP  Europe & Central Asia                       57
# 256                        0.002847                                                         Binding coverage, manufactured products (%)             100.000000                98.848062               0.000136         ESP  Europe & Central Asia                       57

# %%
df_cosine_results
# Out:
#      Cosine distance country-region                                                                                        IndicatorName  Last Value in country  average Value in region  distance with average CountryCode                 Region  countries in the region
# 21                         0.000040                                          Youth literacy rate, population 15-24 years, both sexes (%)           9.966926e+01             9.928096e+01               0.000015         ESP  Europe & Central Asia                       57
# 129                        0.000099                                                              Access to electricity (% of population)           1.000000e+02             9.957297e+01               0.000018         ESP  Europe & Central Asia                       57
# 174                        0.000271                                                                      Income share held by fourth 20%           2.345000e+01             2.241448e+01               0.002134         ESP  Europe & Central Asia                       57
# 181                        0.000461                                            Gross enrolment ratio, primary, gender parity index (GPI)           1.009460e+00             9.915373e-01               0.000327         ESP  Europe & Central Asia                       57
# 333                        0.000620                                            Adult literacy rate, population 15+ years, both sexes (%)           9.807912e+01             9.701148e+01               0.000121         ESP  Europe & Central Asia                       57
# 296                        0.000980       Current education expenditure, primary (% of total expenditure in primary public institutions)           9.590896e+01             9.254969e+01               0.001317         ESP  Europe & Central Asia                       57
# 433                        0.001231   Current education expenditure, secondary (% of total expenditure in secondary public institutions)           9.160561e+01             9.242476e+01               0.000079         ESP  Europe & Central Asia                       57
# 78                         0.001379                 Current education expenditure, total (% of total expenditure in public institutions)           9.215520e+01             9.178643e+01               0.000016         ESP  Europe & Central Asia                       57
# 124                        0.001391                              Gross enrolment ratio, primary and secondary, gender parity index (GPI)           1.007720e+00             9.931846e-01               0.000214         ESP  Europe & Central Asia                       57
# 351                        0.001440                                                                       Income share held by third 20%           1.703000e+01             1.690625e+01               0.000054         ESP  Europe & Central Asia                       57
# 261                        0.001505                            Improved sanitation facilities, urban (% of urban population with access)           9.980000e+01             9.590835e+01               0.001646         ESP  Europe & Central Asia                       57
# 243                        0.001612                                                               Binding coverage, primary products (%)           1.000000e+02             9.782347e+01               0.000495         ESP  Europe & Central Asia                       57
# 89                         0.001687                                                 Adjusted net enrolment rate, primary, both sexes (%)           9.848973e+01             9.537729e+01               0.001065         ESP  Europe & Central Asia                       57
# 70                         0.001889                                                          Net enrolment rate, primary, both sexes (%)           9.844178e+01             9.410106e+01               0.002128         ESP  Europe & Central Asia                       57
# 113                        0.001911                                                                  Population, ages 15-64 (% of total)           6.668554e+01             6.451743e+01               0.001129         ESP  Europe & Central Asia                       57
# 346                        0.002130                                                              Life expectancy at birth, total (years)           8.242683e+01             7.163925e+01               0.022675         ESP  Europe & Central Asia                       57
# 238                        0.002328                                 Survival rate to the last grade of primary education, both sexes (%)           9.714744e+01             9.479105e+01               0.000618         ESP  Europe & Central Asia                       57
# 16                         0.002439                                                                   Binding coverage, all products (%)           1.000000e+02             9.861409e+01               0.000198         ESP  Europe & Central Asia                       57
# 318                        0.002771                                            Cause of death, by non-communicable diseases (% of total)           9.180000e+01             8.736250e+01               0.002580         ESP  Europe & Central Asia                       57
# 256                        0.002847                                                          Binding coverage, manufactured products (%)           1.000000e+02             9.884806e+01               0.000136         ESP  Europe & Central Asia                       57
# 96                         0.002958                                                       Gross enrolment ratio, primary, both sexes (%)           1.044767e+02             1.011335e+02               0.001093         ESP  Europe & Central Asia                       57
# 33                         0.002965                                   Gross intake ratio to Grade 1 of primary education, both sexes (%)           9.820932e+01             9.984032e+01               0.000267         ESP  Europe & Central Asia                       57
# 64                         0.002992     Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)           8.432987e+01             8.957912e+01               0.003434         ESP  Europe & Central Asia                       57
# 375                        0.003580                                                   Official entrance age to primary education (years)           6.000000e+00             6.467694e+00               0.005229         ESP  Europe & Central Asia                       57
# 202                        0.003816                                                                     Income share held by highest 20%           4.183000e+01             3.991354e+01               0.002305         ESP  Europe & Central Asia                       57
# 337                        0.003837                                         Improved sanitation facilities (% of population with access)           9.990000e+01             9.378242e+01               0.004255         ESP  Europe & Central Asia                       57
# 44                         0.003872                                        Survival rate to Grade 5 of primary education, both sexes (%)           9.815086e+01             9.341017e+01               0.002576         ESP  Europe & Central Asia                       57
# 4                          0.004331                                           Official entrance age to lower secondary education (years)           1.200000e+01             1.124250e+01               0.004540         ESP  Europe & Central Asia                       57
# 127                        0.004577                                                        Net enrolment rate, secondary, both sexes (%)           9.595604e+01             8.524754e+01               0.015780         ESP  Europe & Central Asia                       57
# 176                        0.004747                                                                      Income share held by second 20%           1.194000e+01             1.284488e+01               0.004963         ESP  Europe & Central Asia                       57
# 182                        0.005070                                                              Primary completion rate, both sexes (%)           9.917982e+01             9.612766e+01               0.001008         ESP  Europe & Central Asia                       57
# 259                        0.005225                               Primary to secondary general education transition rate, both sexes (%)           9.867530e+01             9.588934e+01               0.000844         ESP  Europe & Central Asia                       57
# 194                        0.006967                                                                     Income share held by highest 10%           2.590000e+01             2.501448e+01               0.001253         ESP  Europe & Central Asia                       57
# 150                        0.007666                                                                Gross national expenditure (% of GDP)           9.750538e+01             1.030850e+02               0.002930         ESP  Europe & Central Asia                       57
# 83                         0.007718      Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)           7.440000e+01             6.873151e+01               0.006802         ESP  Europe & Central Asia                       57
# 291                        0.007951        Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)           5.900000e+01             5.909992e+01               0.000003         ESP  Europe & Central Asia                       57
# 59                         0.008434                                    Distance to frontier score (0=lowest performance to 100=frontier)           7.486000e+01             6.979110e+01               0.005275         ESP  Europe & Central Asia                       57
# 335                        0.009807                            Improved sanitation facilities, rural (% of rural population with access)           1.000000e+02             9.065352e+01               0.010630         ESP  Europe & Central Asia                       57
# 410                        0.010510                                                                     GINI index (World Bank estimate)           3.589000e+01             3.172882e+01               0.017200         ESP  Europe & Central Asia                       57
# 84                         0.010628                                                  Theoretical duration of secondary education (years)           6.000000e+00             7.028205e+00               0.021403         ESP  Europe & Central Asia                       57
# 126                        0.012417           Labor force participation rate, total (% of total population ages 15+) (national estimate)           5.890000e+01             5.926684e+01               0.000038         ESP  Europe & Central Asia                       57
# 401                        0.013566  Share of women in wage employment in the nonagricultural sector (% of total nonagricultural empl...           4.700000e+01             4.554615e+01               0.001019         ESP  Europe & Central Asia                       57
# 349                        0.013620                             Expenditure on secondary as % of government expenditure on education (%)           3.697093e+01             4.114207e+01               0.010279         ESP  Europe & Central Asia                       57
# 275                        0.013702                                                       Final consumption expenditure, etc. (% of GDP)           7.772725e+01             7.856573e+01               0.000114         ESP  Europe & Central Asia                       57
# 109                        0.015066                                Employment to population ratio, 15+, total (%) (modeled ILO estimate)           4.440000e+01             5.300799e+01               0.026371         ESP  Europe & Central Asia                       57
# 146                        0.016106                                                     Gross enrolment ratio, secondary, both sexes (%)           1.305654e+02             9.333633e+01               0.159097         ESP  Europe & Central Asia                       57
# 50                         0.016174                                                                      Income share held by lowest 20%           5.760000e+00             7.920483e+00               0.074404         ESP  Europe & Central Asia                       57
# 282                        0.016282                                               Logistics performance index: Overall (1=low to 5=high)           3.718636e+00             3.180766e+00               0.028595         ESP  Europe & Central Asia                       57
# 354                        0.016283                                      Net intake rate to Grade 1 of primary education, both sexes (%)           9.670801e+01             7.919330e+01               0.048914         ESP  Europe & Central Asia                       57
# 193                        0.016619                                               Wage and salaried workers, total (% of total employed)           8.240000e+01             7.891989e+01               0.001945         ESP  Europe & Central Asia                       57
# 353                        0.017453                                                               Services, etc., value added (% of GDP)           7.506910e+01             6.204862e+01               0.044034         ESP  Europe & Central Asia                       57
# 56                         0.017685                                              Other manufacturing (% of value added in manufacturing)           4.467702e+01             4.729923e+01               0.003073         ESP  Europe & Central Asia                       57
# 184                        0.018359                  Burden of customs procedure, WEF (1=extremely inefficient to 7=extremely efficient)           4.800000e+00             4.382615e+00               0.009070         ESP  Europe & Central Asia                       57
# 1                          0.018522                                                   Age dependency ratio (% of working-age population)           4.995754e+01             5.582172e+01               0.011036         ESP  Europe & Central Asia                       57
# 281                        0.020293                                                           Access to non-solid fuel (% of population)           1.000000e+02             8.761239e+01               0.019991         ESP  Europe & Central Asia                       57
# 76                         0.020473                                                      Manufactures imports (% of merchandise imports)           6.322052e+01             6.565867e+01               0.001379         ESP  Europe & Central Asia                       57
# 88                         0.021995                                Out-of-pocket health expenditure (% of private expenditure on health)           7.708185e+01             8.310501e+01               0.005253         ESP  Europe & Central Asia                       57
# 371                        0.024481                                                       Employment in services (% of total employment)           7.630000e+01             5.729391e+01               0.110045         ESP  Europe & Central Asia                       57
# 209                        0.024526                                                          Fossil fuel energy consumption (% of total)           7.325192e+01             7.948858e+01               0.006156         ESP  Europe & Central Asia                       57
# 295                        0.025045                                             Household final consumption expenditure, etc. (% of GDP)           5.828384e+01             6.009390e+01               0.000907         ESP  Europe & Central Asia                       57
# 35                         0.025947                                         Unmet need for contraception (% of married women ages 15-49)           1.180000e+01             1.442000e+01               0.033012         ESP  Europe & Central Asia                       57
# 369                        0.026159                                    Expenditure on education as % of total government expenditure (%)           9.229810e+00             1.214257e+01               0.057542         ESP  Europe & Central Asia                       57
# 327                        0.026365                                                    Theoretical duration of primary education (years)           6.000000e+00             4.775353e+00               0.065767         ESP  Europe & Central Asia                       57
# 125                        0.027480                                                                 Death rate, crude (per 1,000 people)           8.300000e+00             9.812224e+00               0.023752         ESP  Europe & Central Asia                       57
# 340                        0.027638                                           Gross enrolment ratio, tertiary, gender parity index (GPI)           1.220120e+00             1.095572e+00               0.012924         ESP  Europe & Central Asia                       57
# 228                        0.028821                                                             Gross fixed capital formation (% of GDP)           1.960381e+01             2.333494e+01               0.025566         ESP  Europe & Central Asia                       57
# 149                        0.029407                                                      Lower secondary completion rate, both sexes (%)           8.088891e+01             8.595890e+01               0.003479         ESP  Europe & Central Asia                       57
# 54                         0.030211                                                         Net barter terms of trade index (2000 = 100)           8.931647e+01             1.048099e+02               0.021852         ESP  Europe & Central Asia                       57
# 418                        0.030548                      Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)           3.670000e+01             4.480424e+01               0.032718         ESP  Europe & Central Asia                       57
# 49                         0.030809                                                                 Low-birthweight babies (% of births)           8.200000e+00             6.400000e+00               0.079102         ESP  Europe & Central Asia                       57
# 192                        0.031650                                      Tariff rate, most favored nation, simple mean, all products (%)           4.400000e+00             6.331916e+00               0.093091         ESP  Europe & Central Asia                       57
# 133                        0.032261                                                                   Gross capital formation (% of GDP)           1.977813e+01             2.462745e+01               0.038772         ESP  Europe & Central Asia                       57
# 378                        0.032621                                                       Employment in industry (% of total employment)           1.950000e+01             2.798265e+01               0.091894         ESP  Europe & Central Asia                       57
# 241                        0.033990                               Expenditure on primary as % of government expenditure on education (%)           2.594887e+01             2.406027e+01               0.006161         ESP  Europe & Central Asia                       57
# 230                        0.034530                                                                      Income share held by lowest 10%           1.700000e+00             3.072761e+00               0.199587         ESP  Europe & Central Asia                       57
# 132                        0.035020                         Labor force participation rate for ages 15-24, total (%) (national estimate)           3.570000e+01             4.724226e+01               0.059693         ESP  Europe & Central Asia                       57
# 279                        0.036471                                                                     Industry, value added (% of GDP)           2.241031e+01             2.943659e+01               0.056974         ESP  Europe & Central Asia                       57
# 52                         0.036482                                                         Subsidies and other transfers (% of expense)           6.757085e+01             5.541671e+01               0.048102         ESP  Europe & Central Asia                       57
# 158                        0.036892                                          General government final consumption expenditure (% of GDP)           1.944341e+01             1.773595e+01               0.009268         ESP  Europe & Central Asia                       57
# 265                        0.036974                              Government expenditure per secondary student as % of GDP per capita (%)           2.577838e+01             2.404031e+01               0.005227         ESP  Europe & Central Asia                       57
# 367                        0.037131                                                                 Health expenditure, total (% of GDP)           8.879260e+00             7.378650e+00               0.041360         ESP  Europe & Central Asia                       57
# 186                        0.038395                                                                    Consumer price index (2010 = 100)           1.070519e+02             5.685552e+01               0.779470         ESP  Europe & Central Asia                       57
# 25                         0.038710                                                                   Population, ages 0-14 (% of total)           1.487286e+01             2.430390e+01               0.150580         ESP  Europe & Central Asia                       57
# 277                        0.039374                                                  Depth of credit information index (0=low to 8=high)           7.000000e+00             6.088435e+00               0.022416         ESP  Europe & Central Asia                       57
# 116                        0.039674                                                              Pump price for gasoline (US$ per liter)           1.630000e+00             1.164600e+00               0.159698         ESP  Europe & Central Asia                       57
# 62                         0.040401                                                              Food production index (2004-2006 = 100)           1.088100e+02             9.394313e+01               0.025044         ESP  Europe & Central Asia                       57
# 105                        0.040988  Quality of port infrastructure, WEF (1=extremely underdeveloped to 7=well developed and efficien...           5.800000e+00             4.416301e+00               0.098167         ESP  Europe & Central Asia                       57
# 245                        0.041280                                                                        Urban population (% of total)           7.935500e+01             6.023297e+01               0.100786         ESP  Europe & Central Asia                       57
# 365                        0.042113                                                           Pump price for diesel fuel (US$ per liter)           1.550000e+00             1.062376e+00               0.210675         ESP  Europe & Central Asia                       57
# 298                        0.043136                                                                   Wholesale price index (2010 = 100)           1.104884e+02             6.521165e+01               0.482059         ESP  Europe & Central Asia                       57
# 206                        0.044340                              Expenditure on tertiary as % of government expenditure on education (%)           2.230695e+01             2.130899e+01               0.002193         ESP  Europe & Central Asia                       57
# 408                        0.044462                                                     Contraceptive prevalence (% of women ages 15-49)           6.570000e+01             6.416410e+01               0.000573         ESP  Europe & Central Asia                       57
# 18                         0.046062                                              Age dependency ratio, old (% of working-age population)           2.765456e+01             1.711707e+01               0.378979         ESP  Europe & Central Asia                       57
# 260                        0.046768                                                              Crop production index (2004-2006 = 100)           1.151100e+02             9.427539e+01               0.048840         ESP  Europe & Central Asia                       57
# 301                        0.047065                             Tariff rate, most favored nation, simple mean, manufactured products (%)           4.050000e+00             5.337381e+00               0.058178         ESP  Europe & Central Asia                       57
# 80                         0.047809                                                    Labor force with secondary education (% of total)           2.330000e+01             4.950304e+01               0.280182         ESP  Europe & Central Asia                       57
# 355                        0.048181                                           Pupil-teacher ratio in primary education (headcount basis)           1.260121e+01             1.691515e+01               0.065043         ESP  Europe & Central Asia                       57
# 219                        0.048780                                            Adjusted savings: consumption of fixed capital (% of GNI)           1.748829e+01             1.401828e+01               0.061273         ESP  Europe & Central Asia                       57
# 224                        0.049266                                         Pupil-teacher ratio in secondary education (headcount basis)           1.135027e+01             1.225465e+01               0.005446         ESP  Europe & Central Asia                       57
# 267                        0.050469                                                            Population ages 65 and above (% of total)           1.844159e+01             1.117870e+01               0.422121         ESP  Europe & Central Asia                       57
# 53                         0.051050                           Tariff rate, most favored nation, weighted mean, manufactured products (%)           3.240000e+00             4.663401e+00               0.093164         ESP  Europe & Central Asia                       57
# 3                          0.051601                                Government expenditure per primary student as % of GDP per capita (%)           1.881992e+01             2.007251e+01               0.003894         ESP  Europe & Central Asia                       57
# 388                        0.051735                                                                             Gross savings (% of GDP)           2.065411e+01             2.198828e+01               0.003682         ESP  Europe & Central Asia                       57
# 382                        0.052237                                                           Adjusted savings: gross savings (% of GNI)           2.126487e+01             2.227483e+01               0.002056         ESP  Europe & Central Asia                       57
# 14                         0.052380                                                                             Gross savings (% of GNI)           2.073822e+01             2.231564e+01               0.004997         ESP  Europe & Central Asia                       57
# 99                         0.052978                                      Unemployment with secondary education (% of total unemployment)           2.310000e+01             4.948035e+01               0.284247         ESP  Europe & Central Asia                       57
# 323                        0.055234                                                               Cause of death, by injury (% of total)           3.400000e+00             6.317708e+00               0.213287         ESP  Europe & Central Asia                       57
# 416                        0.058013                                                           Taxes on goods and services (% of revenue)           9.558768e+00             3.375721e+01               0.513856         ESP  Europe & Central Asia                       57
# 406                        0.058393                                                  Government expenditure on education as % of GDP (%)           4.367430e+00             4.706083e+00               0.005178         ESP  Europe & Central Asia                       57
# 237                        0.058403                                    Tariff rate, most favored nation, weighted mean, all products (%)           2.430000e+00             4.494161e+00               0.210955         ESP  Europe & Central Asia                       57
# 55                         0.060204                                                     Labor force with tertiary education (% of total)           3.720000e+01             2.432659e+01               0.280043         ESP  Europe & Central Asia                       57
# 28                         0.060803                                            Firms using banks to finance working capital (% of firms)           3.580000e+01             3.066562e+01               0.028033         ESP  Europe & Central Asia                       57
# 227                        0.060979                                            Age dependency ratio, young (% of working-age population)           2.230298e+01             3.870465e+01               0.179577         ESP  Europe & Central Asia                       57
# 17                         0.061219                                                                Manufacturing, value added (% of GDP)           1.324115e+01             1.627142e+01               0.034683         ESP  Europe & Central Asia                       57
# 112                        0.062491                                                          Firms offering formal training (% of firms)           5.130000e+01             4.516250e+01               0.018468         ESP  Europe & Central Asia                       57
# 156                        0.063500                                                                  Social contributions (% of revenue)           5.292438e+01             3.099886e+01               0.500274         ESP  Europe & Central Asia                       57
# 162                        0.064307                                                      Gross enrolment ratio, tertiary, both sexes (%)           8.593115e+01             3.690288e+01               1.765113         ESP  Europe & Central Asia                       57
# 387                        0.064546                                                                     Hospital beds (per 1,000 people)           3.100000e+00             7.538228e+00               0.346642         ESP  Europe & Central Asia                       57
# 34                         0.064578                                                       Mobile cellular subscriptions (per 100 people)           1.078493e+02             4.870210e+01               1.474934         ESP  Europe & Central Asia                       57
# 215                        0.066020                                                             Procedures to build a warehouse (number)           1.300000e+01             1.529198e+01               0.022464         ESP  Europe & Central Asia                       57
# 144                        0.066585                                        Internationally-recognized quality certification (% of firms)           2.130000e+01             1.501290e+01               0.175376         ESP  Europe & Central Asia                       57
# 189                        0.066711                                                                 Revenue, excluding grants (% of GDP)           2.078999e+01             3.335747e+01               0.141942         ESP  Europe & Central Asia                       57
# 266                        0.067449                                              Tariff rate, applied, simple mean, primary products (%)           2.180000e+00             6.872937e+00               0.466235         ESP  Europe & Central Asia                       57
# 386                        0.067960                                                  Diabetes prevalence (% of population ages 20 to 79)           7.850000e+00             5.849259e+00               0.116998         ESP  Europe & Central Asia                       57
# 235                        0.069625                                                         Livestock production index (2004-2006 = 100)           1.004600e+02             9.553873e+01               0.002653         ESP  Europe & Central Asia                       57
# 169                        0.071283                                     Firms that do not report all sales for tax purposes (% of firms)           1.833000e+01             3.738548e+01               0.259797         ESP  Europe & Central Asia                       57
# 420                        0.071592                                  Tariff rate, most favored nation, simple mean, primary products (%)           5.600000e+00             9.796100e+00               0.183479         ESP  Europe & Central Asia                       57
# 190                        0.073451                                                                Health expenditure, public (% of GDP)           6.253399e+00             4.955849e+00               0.068551         ESP  Europe & Central Asia                       57
# 326                        0.075389                                 Share of tariff lines with international peaks, primary products (%)           5.255677e+00             1.741074e+01               0.487394         ESP  Europe & Central Asia                       57
# 392                        0.077124                                                   Adjusted savings: education expenditure (% of GNI)           4.397638e+00             4.285499e+00               0.000685         ESP  Europe & Central Asia                       57
# 366                        0.077806                         Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)           1.540000e+01             3.558229e+01               0.321716         ESP  Europe & Central Asia                       57
# 311                        0.078433                                                 Firms using banks to finance investment (% of firms)           3.260000e+01             2.803750e+01               0.026481         ESP  Europe & Central Asia                       57
# 297                        0.079777                                                                   Time to resolve insolvency (years)           1.500000e+00             2.024490e+00               0.067119         ESP  Europe & Central Asia                       57
# 151                        0.081167                                                             Fertility rate, total (births per woman)           1.320000e+00             2.289224e+00               0.179255         ESP  Europe & Central Asia                       57
# 248                        0.082007                                                             Total tax rate (% of commercial profits)           5.000000e+01             4.292854e+01               0.027135         ESP  Europe & Central Asia                       57
# 315                        0.082040                                      Share of tariff lines with specific rates, primary products (%)           2.680639e+01             2.460892e+01               0.007974         ESP  Europe & Central Asia                       57
# 322                        0.082974                                                              Food imports (% of merchandise imports)           1.079814e+01             1.162749e+01               0.005087         ESP  Europe & Central Asia                       57
# 147                        0.084952                        Business extent of disclosure index (0=less disclosure to 10=more disclosure)           5.000000e+00             5.687379e+00               0.014607         ESP  Europe & Central Asia                       57
# 179                        0.085698                               Government expenditure per tertiary student as % of GDP per capita (%)           2.318017e+01             2.950505e+01               0.045953         ESP  Europe & Central Asia                       57
# 391                        0.086175                                                  Start-up procedures to register a business (number)           7.000000e+00             6.792475e+00               0.000933         ESP  Europe & Central Asia                       57
# 157                        0.086655                                                      Manufactures exports (% of merchandise exports)           6.937157e+01             6.001490e+01               0.024307         ESP  Europe & Central Asia                       57
# 308                        0.087198                                                             Imports of goods and services (% of GDP)           3.005062e+01             4.272661e+01               0.088017         ESP  Europe & Central Asia                       57
# 102                        0.088057                                                 Strength of legal rights index (0=weak to 12=strong)           5.000000e+00             5.632653e+00               0.012616         ESP  Europe & Central Asia                       57
# 424                        0.088236                                                                         Merchandise trade (% of GDP)           4.913344e+01             6.390801e+01               0.053446         ESP  Europe & Central Asia                       57
# 160                        0.089463                                                                         Documents to export (number)           4.000000e+00             5.651899e+00               0.085424         ESP  Europe & Central Asia                       57
# 218                        0.090211                            GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent)           1.249085e+01             7.136673e+00               0.562852         ESP  Europe & Central Asia                       57
# 320                        0.091418                                                             Rural population (% of total population)           2.064500e+01             3.976703e+01               0.231218         ESP  Europe & Central Asia                       57
# 173                        0.091640                                                Tariff rate, applied, weighted mean, all products (%)           1.040000e+00             3.091236e+00               0.440318         ESP  Europe & Central Asia                       57
# 198                        0.092226                                                   Bound rate, simple mean, manufactured products (%)           4.020000e+00             4.666450e+00               0.019191         ESP  Europe & Central Asia                       57
# 20                         0.092389                                                                               Tax revenue (% of GDP)           7.161857e+00             2.005178e+01               0.413233         ESP  Europe & Central Asia                       57
# 74                         0.092996                    Population in urban agglomerations of more than 1 million (% of total population)           2.443615e+01             1.777405e+01               0.140492         ESP  Europe & Central Asia                       57
# 270                        0.093109                  Survey mean consumption or income per capita, total population (2011 PPP $ per day)           3.625163e+01             3.678540e+01               0.000211         ESP  Europe & Central Asia                       57
# 374                        0.093874                                        Taxes on income, profits and capital gains (% of total taxes)           6.757488e+01             3.363414e+01               1.018314         ESP  Europe & Central Asia                       57
# 9                          0.094559                                                         Average precipitation in depth (mm per year)           6.360000e+02             8.035114e+02               0.043461         ESP  Europe & Central Asia                       57
# 405                        0.094926                                                                     Export volume index (2000 = 100)           1.423770e+02             1.629743e+02               0.015973         ESP  Europe & Central Asia                       57
# 341                        0.097314                                                                                     Trade (% of GDP)           6.259585e+01             8.257758e+01               0.058552         ESP  Europe & Central Asia                       57
# 175                        0.097485                                                             Procedures to register property (number)           5.000000e+00             5.378815e+00               0.004960         ESP  Europe & Central Asia                       57
# 287                        0.098140                                                 Average time to clear exports through customs (days)           4.900000e+00             3.728125e+00               0.098806         ESP  Europe & Central Asia                       57
# 41                         0.099203                                Machinery and transport equipment (% of value added in manufacturing)           2.123350e+01             1.630178e+01               0.091522         ESP  Europe & Central Asia                       57
# 427                        0.099789                                                           Time required to enforce a contract (days)           5.100000e+02             4.970033e+02               0.000684         ESP  Europe & Central Asia                       57
# 306                        0.100473                                                                      Internet users (per 100 people)           7.619000e+01             3.214253e+01               1.877941         ESP  Europe & Central Asia                       57
# 397                        0.102440                                        Unemployment with primary education (% of total unemployment)           5.450000e+01             3.283304e+01               0.435486         ESP  Europe & Central Asia                       57
# 251                        0.102500                                       Tariff rate, applied, weighted mean, manufactured products (%)           1.480000e+00             3.117063e+00               0.275829         ESP  Europe & Central Asia                       57
# 177                        0.102660                                                                   Agricultural land (% of land area)           5.386138e+01             4.510376e+01               0.037700         ESP  Europe & Central Asia                       57
# 208                        0.103369                                                                         Documents to import (number)           4.000000e+00             6.497890e+00               0.147775         ESP  Europe & Central Asia                       57
# 142                        0.103490                                                                        Cereal yield (kg per hectare)           4.080632e+03             3.589920e+03               0.018685         ESP  Europe & Central Asia                       57
# 268                        0.103690          Survey mean consumption or income per capita, bottom 40% of population (2011 PPP $ per day)           1.604055e+01             1.933537e+01               0.029037         ESP  Europe & Central Asia                       57
# 376                        0.104752                                                   Informal payments to public officials (% of firms)           4.400000e+00             3.241613e+01               0.746954         ESP  Europe & Central Asia                       57
# 381                        0.105183                                        Proportion of seats held by women in national parliaments (%)           4.114286e+01             2.030750e+01               1.052662         ESP  Europe & Central Asia                       57
# 395                        0.108731                                                   Gross enrolment ratio, pre-primary, both sexes (%)           9.588371e+01             6.415916e+01               0.244497         ESP  Europe & Central Asia                       57
# 280                        0.109121                                               Population in the largest city (% of urban population)           1.665384e+01             2.619266e+01               0.132626         ESP  Europe & Central Asia                       57
# 344                        0.109856                                                                      Import value index (2000 = 100)           2.175462e+02             2.155180e+02               0.000089         ESP  Europe & Central Asia                       57
# 290                        0.111461                                      Food, beverages and tobacco (% of value added in manufacturing)           1.923733e+01             1.852454e+01               0.001481         ESP  Europe & Central Asia                       57
# 336                        0.112231                             Firms expected to give gifts in meetings with tax officials (% of firms)           1.430000e+01             4.186250e+01               0.433498         ESP  Europe & Central Asia                       57
# 285                        0.113026                                                             Compensation of employees (% of expense)           7.486690e+00             1.681104e+01               0.307644         ESP  Europe & Central Asia                       57
# 107                        0.113301                                                Labor tax and contributions (% of commercial profits)           3.590000e+01             2.413077e+01               0.237878         ESP  Europe & Central Asia                       57
# 47                         0.114434                                                  Tariff rate, applied, simple mean, all products (%)           1.550000e+00             3.635238e+00               0.329038         ESP  Europe & Central Asia                       57
# 407                        0.114985                                                                     Bank capital to assets ratio (%)           7.373009e+00             9.784577e+00               0.060746         ESP  Europe & Central Asia                       57
# ...
# 307                        0.591037                                                Final consumption expenditure, etc. (annual % growth)           6.902956e-01             2.825037e+00               0.571008         ESP  Europe & Central Asia                       57
# 404                        0.594857                                      Household final consumption expenditure, etc. (annual % growth)           9.478489e-01             2.875387e+00               0.449380         ESP  Europe & Central Asia                       57
# 197                        0.613703                                                   Net incurrence of liabilities, domestic (% of GDP)           3.499509e+00             1.388954e+00               2.308967         ESP  Europe & Central Asia                       57
# 211                        0.615465                                                                   International migrant stock, total           6.377524e+06             9.341270e+05              33.956914         ESP  Europe & Central Asia                       57
# 48                         0.626583                                                       Adjusted net national income (annual % growth)          -3.340291e-01             3.114501e+00               1.226002         ESP  Europe & Central Asia                       57
# 400                        0.632432                                   General government final consumption expenditure (annual % growth)          -2.144615e-02             2.785364e+00               1.015458         ESP  Europe & Central Asia                       57
# 247                        0.633113                                                         Manufacturing, value added (annual % growth)           2.210592e+00             3.087564e+00               0.080675         ESP  Europe & Central Asia                       57
# 210                        0.635074                                                    Net incurrence of liabilities, foreign (% of GDP)           6.136880e+00             1.467971e+00              10.115704         ESP  Europe & Central Asia                       57
# 384                        0.652695                                                                Stocks traded, total value (% of GDP)           7.309773e+01             2.780909e+01               2.652193         ESP  Europe & Central Asia                       57
# 15                         0.655085                                                                            Deposit interest rate (%)           2.500000e+00             1.615783e+01               0.714492         ESP  Europe & Central Asia                       57
# 145                        0.664519                          Droughts, floods, extreme temperatures (% of population, average 1990-2009)           7.291935e-01             3.921125e-01               0.739005         ESP  Europe & Central Asia                       57
# 292                        0.668662                                         Insurance and financial services (% of service imports, BoP)           1.092190e+01             1.035899e+01               0.002953         ESP  Europe & Central Asia                       57
# 93                         0.668802                                                                   Current account balance (% of GDP)           7.625079e-01            -2.736980e+00               1.634804         ESP  Europe & Central Asia                       57
# 23                         0.672693                        Computer, communications and other services (% of commercial service exports)           3.777497e+01             2.701670e+01               0.158570         ESP  Europe & Central Asia                       57
# 258                        0.676523                 GEF benefits index for biodiversity (0 = no biodiversity potential to 100 = maximum)           6.842703e+00             1.700861e+00               9.139028         ESP  Europe & Central Asia                       57
# 225                        0.683509                                            Household final consumption expenditure (annual % growth)           1.153731e+00             3.009131e+00               0.380183         ESP  Europe & Central Asia                       57
# 233                        0.684170                                                          Arms exports (SIPRI trend indicator values)           1.110000e+09             5.101027e+08               1.383053         ESP  Europe & Central Asia                       57
# 239                        0.700273                                                                Energy imports, net (% of energy use)           7.095697e+01             3.206391e+01               1.471335         ESP  Europe & Central Asia                       57
# 81                         0.710225                                                                            Lending interest rate (%)           4.305833e+00             2.672562e+01               0.703732         ESP  Europe & Central Asia                       57
# 212                        0.712826                                                      Gross fixed capital formation (annual % growth)           3.494269e+00             3.723042e+00               0.003776         ESP  Europe & Central Asia                       57
# 362                        0.715829                                                              Industry, value added (annual % growth)           2.637987e-01             3.175055e+00               0.840734         ESP  Europe & Central Asia                       57
# 98                         0.722960                                                                               Real interest rate (%)           1.831941e-01             5.277996e+00               0.931787         ESP  Europe & Central Asia                       57
# 348                        0.724168                                            Adjusted net national income per capita (annual % growth)          -6.918938e-03             2.738137e+00               1.005060         ESP  Europe & Central Asia                       57
# 399                        0.725578                            Share of tariff lines with international peaks, manufactured products (%)           1.140800e-01             2.372699e+00               0.906151         ESP  Europe & Central Asia                       57
# 332                        0.728902                                                            Personal remittances, received (% of GDP)           2.257983e-01             3.076990e+00               0.858619         ESP  Europe & Central Asia                       57
# 302                        0.749694                                Renewable internal freshwater resources, total (billion cubic meters)           1.112000e+02             1.290996e+02               0.019224         ESP  Europe & Central Asia                       57
# 135                        0.760860                                    Out-of-school children of primary school age, both sexes (number)           4.242200e+04             4.279596e+04               0.000076         ESP  Europe & Central Asia                       57
# 196                        0.761431                                 Household final consumption expenditure per capita growth (annual %)           1.623358e+00             2.693243e+00               0.157806         ESP  Europe & Central Asia                       57
# 328                        0.775840                                                         Railways, goods transported (million ton-km)           8.005000e+03             7.182322e+04               0.789514         ESP  Europe & Central Asia                       57
# 383                        0.789267                                           Communications, computer, etc. (% of service imports, BoP)           7.255856e+01             7.998828e+01               0.008628         ESP  Europe & Central Asia                       57
# 170                        0.790930                                                       Adjusted savings: mineral depletion (% of GNI)           2.585496e-02             2.412447e-01               0.797140         ESP  Europe & Central Asia                       57
# 216                        0.794173                                                             Total natural resources rents (% of GDP)           1.456906e-01             4.048716e+00               0.929326         ESP  Europe & Central Asia                       57
# 350                        0.804208                                            Interest rate spread (lending rate minus deposit rate, %)           1.805833e+00             1.213853e+01               0.724595         ESP  Europe & Central Asia                       57
# 293                        0.812496                                                  Population density (people per sq. km of land area)           9.277024e+01             3.708514e+02               0.562268         ESP  Europe & Central Asia                       57
# 257                        0.821302                                                    External balance on goods and services (% of GDP)           2.494621e+00            -2.875638e+00               3.487564         ESP  Europe & Central Asia                       57
# 128                        0.821848                                   Risk premium on lending (lending rate minus treasury bill rate, %)           9.666667e-01             4.697010e+00               0.630746         ESP  Europe & Central Asia                       57
# 7                          0.825317                                   Insurance and financial services (% of commercial service imports)           7.746410e+00             9.845406e+00               0.045452         ESP  Europe & Central Asia                       57
# 234                        0.828399                                                                                 Forest area (sq. km)           1.852532e+05             1.885463e+05               0.000305         ESP  Europe & Central Asia                       57
# 204                        0.830278                                                       Transport services (% of service imports, BoP)           3.290260e+01             7.104119e+01               0.288210         ESP  Europe & Central Asia                       57
# 159                        0.844095                                                   Foreign direct investment, net outflows (% of GDP)           2.278448e+00             1.429536e+01               0.706636         ESP  Europe & Central Asia                       57
# 434                        0.844895                                                          Travel services (% of service imports, BoP)           2.589535e+01             6.833604e+01               0.385714         ESP  Europe & Central Asia                       57
# 131                        0.862621  Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% ...          -1.320000e+00            -4.286879e-01               4.322919         ESP  Europe & Central Asia                       57
# 110                        0.875108                                                                         Natural gas rents (% of GDP)           4.647670e-04             1.171231e+00               0.999207         ESP  Europe & Central Asia                       57
# 345                        0.877352                                             Adjusted savings: natural resources depletion (% of GNI)           3.438640e-02             2.451990e+00               0.972149         ESP  Europe & Central Asia                       57
# 352                        0.882192                                                  Fertilizer consumption (% of fertilizer production)           1.045284e+02             7.069328e+02               0.726139         ESP  Europe & Central Asia                       57
# 30                         0.887702                                                                                Coal rents (% of GDP)           3.117627e-03             1.497264e-01               0.958789         ESP  Europe & Central Asia                       57
# 324                        0.901757                                    Renewable internal freshwater resources per capita (cubic meters)           2.385240e+03             7.473349e+04               0.937185         ESP  Europe & Central Asia                       57
# 244                        0.903105                                                                Inflation, consumer prices (annual %)          -1.470318e-01             2.202373e+01               1.013397         ESP  Europe & Central Asia                       57
# 319                        0.903261                                                                   Rural population growth (annual %)          -1.551949e+00            -1.976884e-01              46.929087         ESP  Europe & Central Asia                       57
# 180                        0.912392                                                            Gross capital formation (annual % growth)           4.762497e+00             5.945948e+00               0.039615         ESP  Europe & Central Asia                       57
# 339                        0.919779                                                        Adjusted savings: energy depletion (% of GNI)           8.531443e-03             1.852276e+00               0.990809         ESP  Europe & Central Asia                       57
# 396                        0.925823                                                                   Inflation, GDP deflator (annual %)          -3.965585e-01             4.622718e+01               1.017231         ESP  Europe & Central Asia                       57
# 2                          0.927703                                                 Transport services (% of commercial service imports)           2.333632e+01             5.237966e+01               0.307445         ESP  Europe & Central Asia                       57
# 51                         0.933879                                                                                 Oil rents (% of GDP)           1.519286e-02             1.709505e+00               0.982304         ESP  Europe & Central Asia                       57
# 45                         0.934410                                                    Travel services (% of commercial service imports)           1.783642e+01             5.740334e+01               0.475106         ESP  Europe & Central Asia                       57
# 390                        0.973188                                                           Agriculture, value added (annual % growth)          -3.737019e+00             1.831404e+00               9.244774         ESP  Europe & Central Asia                       57
# 303                        1.013096                        Computer, communications and other services (% of commercial service imports)           5.108085e+01            -1.962841e+01              12.977243         ESP  Europe & Central Asia                       57
# 274                        1.250545                                                          Taxes on international trade (% of revenue)           1.290656e-03             4.783586e+00               0.999460         ESP  Europe & Central Asia                       57
# 31                         1.283427                                                   Customs and other import duties (% of tax revenue)           2.544303e-03             6.477522e+00               0.999215         ESP  Europe & Central Asia                       57

# %%
for IndicatorName in df_cosine_results.head(20).IndicatorName.values :
    try:
        plt ,df_country,df_rest = Draw_Difference(IndicatorName,CountryCode,CountryCompare)
    except :
        pass

# %%
df_indicators = pd.concat([df_rankings.head(20),df_cosine_results.head(20)])
df_indicators.sort_values(by=['distance with average'], ascending=False)
# Out:
#      ranking   order                                                                                       IndicatorName  Last Value in country  average Value in region  distance with average CountryCode                 Region  countries in the region  Cosine distance country-region
# 0        1.0     top                                                                    Listed domestic companies, total            3538.000000               335.466119              91.136036         ESP  Europe & Central Asia                       57                             NaN
# 0        1.0     top                                                            Time required to start a business (days)             138.000000                20.780268              31.819927         ESP  Europe & Central Asia                       57                             NaN
# 2        3.0     top                GEF benefits index for biodiversity (0 = no biodiversity potential to 100 = maximum)               6.842703                 1.700861               9.139028         ESP  Europe & Central Asia                       57                             NaN
# 2        3.0     top                                                        Point-of-sale terminals (per 100,000 adults)            3523.039000              1349.233603               2.595775         ESP  Europe & Central Asia                       57                             NaN
# 1        2.0     top                                       Taxes on income, profits and capital gains (% of total taxes)              68.677883                33.503132               1.102278         ESP  Europe & Central Asia                       57                             NaN
# 837      2.0  bottom                                                   Adjusted savings: net forest depletion (% of GNI)               0.000000                 0.085367               1.000000         ESP  Europe & Central Asia                       57                             NaN
# 123      2.0  bottom    Time spent dealing with the requirements of government regulations (% of senior management time)               0.800000                 8.116800               0.812592         ESP  Europe & Central Asia                       57                             NaN
# 910      1.0  bottom                                     Unemployment with secondary education (% of total unemployment)               7.400000                49.480351               0.723258         ESP  Europe & Central Asia                       57                             NaN
# 651      1.0  bottom                                Taxes on goods and services (% value added of industry and services)               2.575314                13.903937               0.663863         ESP  Europe & Central Asia                       57                             NaN
# 658      1.0  bottom                                                          Taxes on goods and services (% of revenue)               9.558768                33.697314               0.513135         ESP  Europe & Central Asia                       57                             NaN
# 671      3.0  bottom                                                                              Tax revenue (% of GDP)               7.161857                20.054054               0.413285         ESP  Europe & Central Asia                       57                             NaN
# 113      2.0  bottom                                                             Lead time to export, median case (days)               1.000000                 2.485481               0.357202         ESP  Europe & Central Asia                       57                             NaN
# 64       4.0  bottom                                    Firms that do not report all sales for tax purposes (% of firms)              18.330000                44.543971               0.346328         ESP  Europe & Central Asia                       57                             NaN
# 91       5.0  bottom                                                              Cause of death, by injury (% of total)               3.400000                 6.317708               0.213287         ESP  Europe & Central Asia                       57                             NaN
# 1        2.0     top                                     Net intake rate to Grade 1 of primary education, both sexes (%)              98.988243                79.050172               0.063615         ESP  Europe & Central Asia                       57                             NaN
# 346      NaN     NaN                                                             Life expectancy at birth, total (years)              82.426829                71.639248               0.022675         ESP  Europe & Central Asia                       57                        0.002130
# 107      4.0     top                           Improved sanitation facilities, rural (% of rural population with access)             100.000000                90.653517               0.010630         ESP  Europe & Central Asia                       57                             NaN
# 0        1.0     top                                                         Net enrolment rate, primary, both sexes (%)              99.997190                94.017695               0.004045         ESP  Europe & Central Asia                       57                             NaN
# 318      NaN     NaN                                           Cause of death, by non-communicable diseases (% of total)              91.800000                87.362500               0.002580         ESP  Europe & Central Asia                       57                        0.002771
# 0        1.0     top                                                Adjusted net enrolment rate, primary, both sexes (%)              99.997190                95.277061               0.002454         ESP  Europe & Central Asia                       57                             NaN
# 174      NaN     NaN                                                                     Income share held by fourth 20%              23.450000                22.414477               0.002134         ESP  Europe & Central Asia                       57                        0.000271
# 70       NaN     NaN                                                         Net enrolment rate, primary, both sexes (%)              98.441780                94.101064               0.002128         ESP  Europe & Central Asia                       57                        0.001889
# 261      NaN     NaN                           Improved sanitation facilities, urban (% of urban population with access)              99.800000                95.908346               0.001646         ESP  Europe & Central Asia                       57                        0.001505
# 296      NaN     NaN      Current education expenditure, primary (% of total expenditure in primary public institutions)              95.908958                92.549688               0.001317         ESP  Europe & Central Asia                       57                        0.000980
# 113      NaN     NaN                                                                 Population, ages 15-64 (% of total)              66.685543                64.517429               0.001129         ESP  Europe & Central Asia                       57                        0.001911
# 89       NaN     NaN                                                Adjusted net enrolment rate, primary, both sexes (%)              98.489731                95.377286               0.001065         ESP  Europe & Central Asia                       57                        0.001687
# 238      NaN     NaN                                Survival rate to the last grade of primary education, both sexes (%)              97.147438                94.791047               0.000618         ESP  Europe & Central Asia                       57                        0.002328
# 363      3.0     top                                                              Binding coverage, primary products (%)             100.000000                97.823469               0.000495         ESP  Europe & Central Asia                       57                             NaN
# 243      NaN     NaN                                                              Binding coverage, primary products (%)             100.000000                97.823469               0.000495         ESP  Europe & Central Asia                       57                        0.001612
# 181      NaN     NaN                                           Gross enrolment ratio, primary, gender parity index (GPI)               1.009460                 0.991537               0.000327         ESP  Europe & Central Asia                       57                        0.000461
# 124      NaN     NaN                             Gross enrolment ratio, primary and secondary, gender parity index (GPI)               1.007720                 0.993185               0.000214         ESP  Europe & Central Asia                       57                        0.001391
# 16       NaN     NaN                                                                  Binding coverage, all products (%)             100.000000                98.614088               0.000198         ESP  Europe & Central Asia                       57                        0.002439
# 358      2.0     top                                                                  Binding coverage, all products (%)             100.000000                98.614088               0.000198         ESP  Europe & Central Asia                       57                             NaN
# 256      NaN     NaN                                                         Binding coverage, manufactured products (%)             100.000000                98.848062               0.000136         ESP  Europe & Central Asia                       57                        0.002847
# 333      NaN     NaN                                           Adult literacy rate, population 15+ years, both sexes (%)              98.079124                97.011481               0.000121         ESP  Europe & Central Asia                       57                        0.000620
# 433      NaN     NaN  Current education expenditure, secondary (% of total expenditure in secondary public institutions)              91.605614                92.424764               0.000079         ESP  Europe & Central Asia                       57                        0.001231
# 351      NaN     NaN                                                                      Income share held by third 20%              17.030000                16.906247               0.000054         ESP  Europe & Central Asia                       57                        0.001440
# 129      NaN     NaN                                                             Access to electricity (% of population)             100.000000                99.572972               0.000018         ESP  Europe & Central Asia                       57                        0.000099
# 78       NaN     NaN                Current education expenditure, total (% of total expenditure in public institutions)              92.155197                91.786435               0.000016         ESP  Europe & Central Asia                       57                        0.001379
# 21       NaN     NaN                                         Youth literacy rate, population 15-24 years, both sexes (%)              99.669258                99.280955               0.000015         ESP  Europe & Central Asia                       57                        0.000040

# %% [markdown]
# # Get feature importance

# %%
indicators_to_improve = ['Time required to start a business (days)',
                       'Firms that do not report all sales for tax purposes (% of firms)',
                      'Population, ages 15-64 (% of total)']

# %% [markdown]
# # Build model

# %%
def get_data(REGION,array_indicators):
    
    """Return dataframe, with the indicators specified in """
    conn = sqlite3.connect('../input/world-development-indicators/database.sqlite')
    array_dfs=[]

    MIN_YEAR=pd.read_sql(f""" SELECT Min(Year) FROM Indicators""",conn).values[0][0]

    array_countries=pd.read_sql(f"""SELECT CountryCode from Country WHERE Region = '{REGION}' """,conn).CountryCode.values

    for CountryCode in tqdm(array_countries):
        array_results = []
        array_years_with_data = pd.read_sql(f""" SELECT distinct(Year) FROM Indicators WHERE  CountryCode = '{CountryCode}'  """,conn).Year.values
        df_country_all_years = pd.read_sql(f"""
                        SELECT IndicatorName,Value,Year
                        FROM Indicators
                        WHERE 
                        CountryCode = '{CountryCode}' """,conn) 
        for Year in array_years_with_data:
            dict_country_year = { 'CountryCode' : CountryCode , "Year" : Year, "Decade" : round((Year - MIN_YEAR) / 10)}
            try :
                df = df_country_all_years.query(f"Year == {Year}")[["IndicatorName","Value"]]
                df = df.T
                df.columns=df.iloc[0]
                df = df.iloc[1:].rename_axis(None, axis=1)
                df = df.reset_index()
                dict_row = {k : v[0] for k,v in df.to_dict('dict').items()}
            except: continue
            array_results.append({**dict_country_year, **dict_row} )

        df_temp = pd.DataFrame(array_results)
        kk=pd.DataFrame()
        kk[["CountryCode" ,"Year", "Decade"]]=df_temp[["CountryCode" ,"Year", "Decade"]]
        for column in list(set(df_temp.columns)&set(array_indicators)) :
            df_temp[column].apply(pd.to_numeric,errors='coerce')
            kk[column]=df_temp[column].fillna(df_temp[column].mean())  
        array_dfs.append(kk)
    df=pd.concat(array_dfs)
    return df

#df = get_data(Region,ARRAY_INDICATORS)
#df
# Out:
# HBox(children=(FloatProgress(value=0.0, max=57.0), HTML(value='')))
#    CountryCode  Year  Decade  Household final consumption expenditure, etc. (constant 2005 US$)  Age dependency ratio (% of working-age population)  Transport services (% of commercial service imports)  Official entrance age to lower secondary education (years)  Electricity production from oil sources (% of total)  Arable land (% of land area)  Insurance and financial services (% of commercial service imports)  ...  Market capitalization of listed domestic companies (% of GDP)  Stocks traded, turnover ratio of domestic shares (%)  Listed domestic companies, total  Population in the largest city (% of urban population)  Real effective exchange rate index (2010 = 100)  Fertilizer consumption (% of fertilizer production)  Net intake rate to Grade 1 of primary education, both sexes (%)  Population in largest city  Stocks traded, total value (% of GDP)  S&P Global Equity Indices (annual % change)
# 0          ALB  1960     0.0                                                       6.601730e+09                                           83.706330                                             16.387704                                                   10.136364                                             13.356935                     20.460129                                                             4.68933  ...                                                            NaN                                                   NaN                               NaN                                                     NaN                                              NaN                                                  NaN                                                              NaN                         NaN                                    NaN                                          NaN
# 1          ALB  1961     0.0                                                       6.601730e+09                                           84.952419                                             16.387704                                                   10.136364                                             13.356935                     15.766423                                                             4.68933  ...                                                            NaN                                                   NaN                               NaN                                                     NaN                                              NaN                                                  NaN                                                              NaN                         NaN                                    NaN                                          NaN
# 2          ALB  1962     0.0                                                       6.601730e+09                                           86.238243                                             16.387704                                                   10.136364                                             13.356935                     15.912409                                                             4.68933  ...                                                            NaN                                                   NaN                               NaN                                                     NaN                                              NaN                                                  NaN                                                              NaN                         NaN                                    NaN                                          NaN
# 3          ALB  1963     0.0                                                       6.601730e+09                                           87.430722                                             16.387704                                                   10.136364                                             13.356935                     16.058394                                                             4.68933  ...                                                            NaN                                                   NaN                               NaN                                                     NaN                                              NaN                                                  NaN                                                              NaN                         NaN                                    NaN                                          NaN
# 4          ALB  1964     0.0                                                       6.601730e+09                                           88.282914                                             16.387704                                                   10.136364                                             13.356935                     16.167883                                                             4.68933  ...                                                            NaN                                                   NaN                               NaN                                                     NaN                                              NaN                                                  NaN                                                              NaN                         NaN                                    NaN                                          NaN
# ..         ...   ...     ...                                                                ...                                                 ...                                                   ...                                                         ...                                                   ...                           ...                                                                 ...  ...                                                            ...                                                   ...                               ...                                                     ...                                              ...                                                  ...                                                              ...                         ...                                    ...                                          ...
# 51         UZB  2011     5.0                                                       7.913044e+09                                           50.436668                                                   NaN                                                   11.000000                                              1.038168                     10.108134                                                                 NaN  ...                                                        1.01988                                             61.103086                        132.000000                                               20.889082                                              NaN                                            80.551714                                                        75.766876                2.216946e+06                               0.182279                                          NaN
# 52         UZB  2012     5.0                                                       7.913044e+09                                           49.987291                                                   NaN                                                   11.000000                                              0.729524                     10.343206                                                                 NaN  ...                                                        1.01988                                             61.103086                         98.166667                                               20.654283                                              NaN                                            85.604000                                                        75.766876                2.225088e+06                               0.209045                                          NaN
# 53         UZB  2013     5.0                                                       7.913044e+09                                           49.699655                                                   NaN                                                   11.000000                                              6.732192                     10.343206                                                                 NaN  ...                                                        1.01988                                             61.103086                         98.166667                                               20.389138                                              NaN                                            85.436190                                                        75.766876                2.233259e+06                               0.209045                                          NaN
# 54         UZB  2014     5.0                                                       7.913044e+09                                           49.597630                                                   NaN                                                   11.000000                                              6.732192                     10.412767                                                                 NaN  ...                                                        1.01988                                             61.103086                         98.166667                                               20.097807                                              NaN                                            77.712101                                                        75.766876                2.241461e+06                               0.209045                                          NaN
# 55         UZB  2015     6.0                                                       7.913044e+09                                           79.206565                                                   NaN                                                   10.400000                                              6.732192                     10.412767                                                                 NaN  ...                                                        1.01988                                             61.103086                         98.166667                                               26.553256                                              NaN                                            77.712101                                                        75.766876                1.833444e+06                               0.209045                                          NaN
#
# [3191 rows x 441 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

def train_data_for(kk,X_column):
    def r2(rf, X_train, y_train):
        return r2_score(y_train, rf.predict(X_train))
    
    y = kk[X_column]
    X = kk[[ x  for x in  kk.columns  if x != X_column]]
    np.random.seed(seed = 42)
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size = 0.8, random_state = 42)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
    
    xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)
#Fit the regressor to the training set and make predictions on the test set using the familiar .fit() and .predict() methods.

    xg_reg.fit(X_train,y_train)

    preds = xg_reg.predict(X_test)

    rf = xg_reg  
    print('R^2 Training Score: {:.2f} \nR^2 Validation Score: {:.2f}'.format(
        rf.score(X_train, y_train),rf.score(X_valid, y_valid))) 
    
    perm_imp_rfpimp = permutation_importances(rf, X_train, y_train, r2)
    ax = perm_imp_rfpimp.head(10).plot(kind="barh")
    ax.set_title(X_column) 
    return ax,perm_imp_rfpimp

ax,perm_imp_rfpimp = train_data_for(kk,X_column)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4cd6dc9ea059> in <module>
#      30     return ax,perm_imp_rfpimp
#      31
# ---> 32 ax,perm_imp_rfpimp = train_data_for(kk,X_column)
#      33
#
# NameError: name 'kk' is not defined

# %%
X_column='GDP per person employed (constant 1990 PPP $)'

# %%
all_values.shape

# %%
def get_data(Region,array_indicators):
    
    """Return dataframe, with the indicators specified in """
    conn = sqlite3.connect('../input/world-development-indicators/database.sqlite')
    array_dfs=[]

    MIN_YEAR=pd.read_sql(f""" SELECT Min(Year) FROM Indicators""",conn).values[0][0]

    array_countries=pd.read_sql(f"""SELECT CountryCode from Country WHERE Region = '{Region}' """,conn).CountryCode.values

    all_values =  pd.read_sql(f"""SELECT IndicatorName,Year,Value,CountryCode
               FROM Indicators
               WHERE 
                    CountryCode in ( SELECT CountryCode  FROM Country WHERE Region = '{Region}' )  
               """,conn)
    print(all_values.shape)
    for CountryCode in tqdm(array_countries):
        array_results = []
        #print("1")
           
        #array_years_with_data = pd.read_sql(f""" SELECT distinct(Year) FROM Indicators WHERE  CountryCode = '{CountryCode}'  """,conn).Year.values
        df_country_all_years = all_values.copy().query(f"  CountryCode == '{CountryCode}'")
        #df_country_all_years = pd.read_sql(f"""
        #                SELECT IndicatorName,Value,Year
        #                FROM Indicators
        #                WHERE 
        #                CountryCode = '{CountryCode}' """,conn) 
        array_years_with_data = df_country_all_years.Year.unique().tolist()
        #print("2",array_years_with_data)

        for Year in tqdm(array_years_with_data):
            dict_country_year = { 'CountryCode' : CountryCode , "Year" : Year, "Decade" : round((Year - MIN_YEAR) / 10)}
            try :
                #print("3")

                df = df_country_all_years.query(f"Year == {Year}")[["IndicatorName","Value"]]
 
                #print("4")

                df = df.T
                df.columns=df.iloc[0]
                #print("5")

                df = df.iloc[1:].rename_axis(None, axis=1)
                df = df.reset_index()
                #print("6")
                dict_row = {k : v[0] for k,v in df.to_dict('dict').items()}
            except: continue
            array_results.append({**dict_country_year, **dict_row} )

        df_temp = pd.DataFrame(array_results)
        kk=pd.DataFrame()
        kk[["CountryCode" ,"Year", "Decade"]]=df_temp[["CountryCode" ,"Year", "Decade"]]
        for column in list(set(df_temp.columns)&set(array_indicators)) :
            df_temp[column].apply(pd.to_numeric,errors='coerce')
            kk[column]=df_temp[column].fillna(df_temp[column].mean())  
        array_dfs.append(kk)
    df=pd.concat(array_dfs)
    return df

df = get_data(Region,ARRAY_INDICATORS)
df
# Out:
# (1113747, 4)
# HBox(children=(FloatProgress(value=0.0, max=57.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=55.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
#    CountryCode  Year  Decade  Pump price for diesel fuel (US$ per liter)  Theoretical duration of secondary education (years)  Employment to population ratio, 15+, total (%) (modeled ILO estimate)  Merchandise trade (% of GDP)  Travel services (% of service imports, BoP)  Fixed broadband subscriptions (per 100 people)  Time required to build a warehouse (days)  ...  Market capitalization of listed domestic companies (% of GDP)  Population in largest city  Stocks traded, turnover ratio of domestic shares (%)  Stocks traded, total value (% of GDP)  Population in urban agglomerations of more than 1 million (% of total population)  Listed domestic companies, total  Net intake rate to Grade 1 of primary education, both sexes (%)  Real effective exchange rate index (2010 = 100)  Fertilizer consumption (% of fertilizer production)  S&P Global Equity Indices (annual % change)
# 0          ALB  1960     0.0                                    1.084444                                             7.866667                                                              51.158333                     44.211000                                    66.113343                                        3.341800                                 307.142857  ...                                                            NaN                         NaN                                                   NaN                                    NaN                                                                                NaN                               NaN                                                              NaN                                              NaN                                                  NaN                                          NaN
# 1          ALB  1961     0.0                                    1.084444                                             7.866667                                                              51.158333                     44.211000                                    66.113343                                        3.341800                                 307.142857  ...                                                            NaN                         NaN                                                   NaN                                    NaN                                                                                NaN                               NaN                                                              NaN                                              NaN                                                  NaN                                          NaN
# 2          ALB  1962     0.0                                    1.084444                                             7.866667                                                              51.158333                     44.211000                                    66.113343                                        3.341800                                 307.142857  ...                                                            NaN                         NaN                                                   NaN                                    NaN                                                                                NaN                               NaN                                                              NaN                                              NaN                                                  NaN                                          NaN
# 3          ALB  1963     0.0                                    1.084444                                             7.866667                                                              51.158333                     44.211000                                    66.113343                                        3.341800                                 307.142857  ...                                                            NaN                         NaN                                                   NaN                                    NaN                                                                                NaN                               NaN                                                              NaN                                              NaN                                                  NaN                                          NaN
# 4          ALB  1964     0.0                                    1.084444                                             7.866667                                                              51.158333                     44.211000                                    66.113343                                        3.341800                                 307.142857  ...                                                            NaN                         NaN                                                   NaN                                    NaN                                                                                NaN                               NaN                                                              NaN                                              NaN                                                  NaN                                          NaN
# ..         ...   ...     ...                                         ...                                                  ...                                                                    ...                           ...                                          ...                                             ...                                        ...  ...                                                            ...                         ...                                                   ...                                    ...                                                                                ...                               ...                                                              ...                                              ...                                                  ...                                          ...
# 51         UZB  2011     5.0                                    0.597000                                             7.000000                                                              54.400002                     52.347479                                          NaN                                        0.285345                                 192.000000  ...                                                        1.01988                2.216946e+06                                             61.103086                               0.182279                                                                           7.556208                        132.000000                                                        75.766876                                              NaN                                            80.551714                                          NaN
# 52         UZB  2012     5.0                                    0.870000                                             7.000000                                                              54.700001                     45.413971                                          NaN                                        0.772824                                 192.000000  ...                                                        1.01988                2.225088e+06                                             61.103086                               0.209045                                                                           7.473133                         98.166667                                                        75.766876                                              NaN                                            85.604000                                          NaN
# 53         UZB  2013     5.0                                    0.597000                                             7.000000                                                              55.000000                     45.147016                                          NaN                                        1.058612                                 176.000000  ...                                                        1.01988                2.233259e+06                                             61.103086                               0.209045                                                                           7.384334                         98.166667                                                        75.766876                                              NaN                                            85.436190                                          NaN
# 54         UZB  2014     5.0                                    1.930000                                             7.000000                                                              55.299999                     43.419993                                          NaN                                        0.285345                                 176.000000  ...                                                        1.01988                2.241461e+06                                             61.103086                               0.209045                                                                           7.291082                         98.166667                                                        75.766876                                              NaN                                            77.712101                                          NaN
# 55         UZB  2015     6.0                                    0.597000                                             7.000000                                                              53.416667                     52.376520                                          NaN                                        0.285345                                 176.000000  ...                                                        1.01988                1.833444e+06                                             61.103086                               0.209045                                                                          10.046132                         98.166667                                                        75.766876                                              NaN                                            77.712101                                          NaN
#
# [3191 rows x 441 columns]

# %%
CountryCode = 'ESP'
all_values =  pd.read_sql(f"""SELECT IndicatorName,Year,Value,CountryCode
           FROM Indicators
           WHERE 
                CountryCode in ( SELECT CountryCode  FROM Country WHERE Region = '{Region}' )  
           group by Year,IndicatorName""",conn)
df_country_all_years = all_values.copy().query(f"  CountryCode == '{CountryCode}'")
array_years_with_data = df_country_all_years.Year.unique().tolist()
array_years_with_data
# Out:
# [1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1991,
#  1992,
#  1995,
#  1999,
#  2004,
#  2005]
