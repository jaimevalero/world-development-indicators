# %% [markdown]
# -- Get indicator to analyze
#
#   -- Top/Bottom method
#
#   -- Cosine Vector method
#
# -- Get df_indicators
#
# -- Return list_indicator_to_analyze
#
# 	-- for each indicator.
#
# 	 -- calcule features.

# %%
# Load libraries
import sqlite3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as spstats
from scipy.spatial import distance 
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from tqdm.notebook import tqdm



pd.set_option("display.width"    , 1000)
pd.set_option("display.max_rows" , 1500)

pd.options.display.max_colwidth = 100

# Static info
REMOVE_COUNTRIES_CLUSTERS ="""
   ( 
      CountryCode != 'WLD' AND     CountryCode != 'LMY' AND     CountryCode != 'MIC' AND     CountryCode != 'LMC' AND     CountryCode != 'UMC' AND     CountryCode != 'EAS' AND     CountryCode != 'EAP' AND     CountryCode != 'SAS' AND     CountryCode != 'HIC' AND     CountryCode != 'OED' AND     CountryCode != 'OEC' AND     CountryCode != 'SSF' AND     CountryCode != 'SSA' AND     CountryCode != 'LDC' AND     CountryCode != 'ECS' AND     CountryCode != 'LCN' AND     CountryCode != 'LIC' AND     CountryCode != 'LAC' AND     CountryCode != 'EUU' AND     CountryCode != 'FCS' AND     CountryCode != 'MEA' AND     CountryCode != 'ARB' AND     CountryCode != 'MNA' AND     CountryCode != 'NAC' AND     CountryCode != 'EMU' AND     CountryCode != 'NOC'   AND     CountryCode != 'ECA' AND     CountryCode != 'HPC' 
    )
"""


ARRAY_INDICATORS=[       'Access to electricity (% of population)',
    'Access to non-solid fuel (% of population)',
    'Adjusted net enrolment rate, primary, both sexes (%)',
    'Adjusted net national income (annual % growth)',
    'Adjusted net national income (constant 2005 US$)',
    'Adjusted net national income per capita (annual % growth)',
    'Adjusted net national income per capita (constant 2005 US$)',
    'Adjusted net savings, excluding particulate emission damage (% of GNI)',
    'Adjusted net savings, including particulate emission damage (% of GNI)',
    'Adjusted savings: carbon dioxide damage (% of GNI)',
    'Adjusted savings: consumption of fixed capital (% of GNI)',
    'Adjusted savings: education expenditure (% of GNI)',
    'Adjusted savings: energy depletion (% of GNI)',
    'Adjusted savings: gross savings (% of GNI)',
    'Adjusted savings: mineral depletion (% of GNI)',
    'Adjusted savings: natural resources depletion (% of GNI)',
    'Adjusted savings: net forest depletion (% of GNI)',
    'Adjusted savings: net national savings (% of GNI)',
    'Adjusted savings: particulate emission damage (% of GNI)',
    'Adolescent fertility rate (births per 1,000 women ages 15-19)',
    'Adult literacy rate, population 15+ years, both sexes (%)',
    'Age dependency ratio (% of working-age population)',
    'Age dependency ratio, old (% of working-age population)',
    'Age dependency ratio, young (% of working-age population)',
    'Agricultural irrigated land (% of total agricultural land)',
    'Agricultural land (% of land area)',
    'Agricultural machinery, tractors per 100 sq. km of arable land',
    'Agricultural raw materials exports (% of merchandise exports)',
    'Agricultural raw materials imports (% of merchandise imports)',
    'Agriculture value added per worker (constant 2005 US$)',
    'Agriculture, value added (% of GDP)',
    'Agriculture, value added (annual % growth)',
    'Agriculture, value added (constant 2005 US$)',
    'Alternative and nuclear energy (% of total energy use)',
    'Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)',
    'Annualized average growth rate in per capita real survey mean consumption or income, total population (%)',
    'Arable land (% of land area)',
    'Armed forces personnel, total',
    'Arms exports (SIPRI trend indicator values)',
    'Arms imports (SIPRI trend indicator values)',
    'Automated teller machines (ATMs) (per 100,000 adults)',
    'Average precipitation in depth (mm per year)',
    'Average time to clear exports through customs (days)',
    'Bank capital to assets ratio (%)',
    'Bank nonperforming loans to total gross loans (%)',
    'Battle-related deaths (number of people)',
    'Binding coverage, all products (%)',
    'Binding coverage, manufactured products (%)',
    'Binding coverage, primary products (%)',
    'Bound rate, simple mean, all products (%)',
    'Bound rate, simple mean, manufactured products (%)',
    'Bound rate, simple mean, primary products (%)',
    'Burden of customs procedure, WEF (1=extremely inefficient to 7=extremely efficient)',
    'Business extent of disclosure index (0=less disclosure to 10=more disclosure)',
    'Cash surplus/deficit (% of GDP)',
    'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)',
    'Cause of death, by injury (% of total)',
    'Cause of death, by non-communicable diseases (% of total)',
    'Central government debt, total (% of GDP)',
    'Cereal production (metric tons)', 'Cereal yield (kg per hectare)',
    'Chemicals (% of value added in manufacturing)',
    'Coal rents (% of GDP)',
    'Combustible renewables and waste (% of total energy)',
    'Commercial bank branches (per 100,000 adults)',
    'Communications, computer, etc. (% of service exports, BoP)',
    'Communications, computer, etc. (% of service imports, BoP)',
    'Compensation of employees (% of expense)',
    'Computer, communications and other services (% of commercial service exports)',
    'Computer, communications and other services (% of commercial service imports)',
    'Consumer price index (2010 = 100)',
    'Container port traffic (TEU: 20 foot equivalent units)',
    'Contraceptive prevalence (% of women ages 15-49)',
    'Contributing family workers, total (% of total employed)',
    'Cost of business start-up procedures (% of GNI per capita)',
    'Cost to export (US$ per container)',
    'Cost to import (US$ per container)',
    'Crop production index (2004-2006 = 100)',
    'Current account balance (% of GDP)',
    'Current education expenditure, primary (% of total expenditure in primary public institutions)',
    'Current education expenditure, secondary (% of total expenditure in secondary public institutions)',
    'Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)',
    'Current education expenditure, total (% of total expenditure in public institutions)',
    'Customs and other import duties (% of tax revenue)',
    'Death rate, crude (per 1,000 people)',
    'Delay in obtaining an electrical connection (days)',
    'Deposit interest rate (%)',
    'Depth of credit information index (0=low to 8=high)',
    'Diabetes prevalence (% of population ages 20 to 79)',
    'Distance to frontier score (0=lowest performance to 100=frontier)',
    'Documents to export (number)', 'Documents to import (number)',
    'Droughts, floods, extreme temperatures (% of population, average 1990-2009)',
    'Ease of doing business index (1=most business-friendly regulations)',
    'Electric power consumption (kWh per capita)',
    'Electric power transmission and distribution losses (% of output)',
    'Electricity production from coal sources (% of total)',
    'Electricity production from hydroelectric sources (% of total)',
    'Electricity production from natural gas sources (% of total)',
    'Electricity production from nuclear sources (% of total)',
    'Electricity production from oil sources (% of total)',
    'Electricity production from renewable sources, excluding hydroelectric (% of total)',
    'Electricity production from renewable sources, excluding hydroelectric (kWh)',
    'Emigration rate of tertiary educated (% of total tertiary educated population)',
    'Employers, total (% of employment)',
    'Employment in agriculture (% of total employment)',
    'Employment in industry (% of total employment)',
    'Employment in services (% of total employment)',
    'Employment to population ratio, 15+, total (%) (modeled ILO estimate)',
    'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
    'Energy imports, net (% of energy use)',
    'Energy intensity level of primary energy (MJ/$2011 PPP GDP)',
    'Energy use (kg of oil equivalent per capita)',
    'Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)',
    'Enrolment in primary education, both sexes (number)',
    'Enrolment in secondary education, both sexes (number)',
    'Enrolment in secondary general, both sexes (number)',
    'Enrolment in secondary vocational, both sexes (number)',
    'Expenditure on education as % of total government expenditure (%)',
    'Expenditure on primary as % of government expenditure on education (%)',
    'Expenditure on secondary as % of government expenditure on education (%)',
    'Expenditure on tertiary as % of government expenditure on education (%)',
    'Export value index (2000 = 100)',
    'Export volume index (2000 = 100)',
    'Exports of goods and services (% of GDP)',
    'Exports of goods and services (annual % growth)',
    'Exports of goods and services (constant 2005 US$)',
    'External balance on goods and services (% of GDP)',
    'External resources for health (% of total expenditure on health)',
    'Fertility rate, total (births per woman)',
    'Fertilizer consumption (% of fertilizer production)',
    'Fertilizer consumption (kilograms per hectare of arable land)',
    'Final consumption expenditure (constant 2005 US$)',
    'Final consumption expenditure, etc. (% of GDP)',
    'Final consumption expenditure, etc. (annual % growth)',
    'Final consumption expenditure, etc. (constant 2005 US$)',
    'Firms expected to give gifts in meetings with tax officials (% of firms)',
    'Firms offering formal training (% of firms)',
    'Firms that do not report all sales for tax purposes (% of firms)',
    'Firms using banks to finance investment (% of firms)',
    'Firms using banks to finance working capital (% of firms)',
    'Fixed broadband subscriptions (per 100 people)',
    'Fixed telephone subscriptions (per 100 people)',
    'Food exports (% of merchandise exports)',
    'Food imports (% of merchandise imports)',
    'Food production index (2004-2006 = 100)',
    'Food, beverages and tobacco (% of value added in manufacturing)',
    'Foreign direct investment, net inflows (% of GDP)',
    'Foreign direct investment, net outflows (% of GDP)',
    'Forest area (% of land area)', 'Forest area (sq. km)',
    'Forest rents (% of GDP)',
    'Fossil fuel energy consumption (% of total)',
    'Fuel exports (% of merchandise exports)',
    'GDP deflator (base year varies by country)',
    'GDP growth (annual %)',
    'GDP per capita (constant 2005 US$)',
    'GDP per person employed (constant 1990 PPP $)',
    'GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent)',
    'GDP, PPP (constant 2011 international $)',
    'GEF benefits index for biodiversity (0 = no biodiversity potential to 100 = maximum)',
    'GINI index (World Bank estimate)', 'GNI (constant 2005 US$)',
    'GNI growth (annual %)', 'GNI per capita (constant 2005 US$)',
    'GNI per capita growth (annual %)',
    'GNI per capita, PPP (constant 2011 international $)',
    'General government final consumption expenditure (% of GDP)',
    'General government final consumption expenditure (annual % growth)',
    'General government final consumption expenditure (constant 2005 US$)',
    'Goods and services expense (% of expense)',
    'Government expenditure on education as % of GDP (%)',
    'Government expenditure per primary student as % of GDP per capita (%)',
    'Government expenditure per secondary student as % of GDP per capita (%)',
    'Government expenditure per tertiary student as % of GDP per capita (%)',
    'Grants and other revenue (% of revenue)',
    'Gross capital formation (% of GDP)',
    'Gross capital formation (annual % growth)',
    'Gross capital formation (constant 2005 US$)',
    'Gross domestic income (constant 2005 US$)',
    'Gross domestic savings (% of GDP)',
    'Gross enrolment ratio, pre-primary, both sexes (%)',
    'Gross enrolment ratio, primary and secondary, gender parity index (GPI)',
    'Gross enrolment ratio, primary, both sexes (%)',
    'Gross enrolment ratio, primary, gender parity index (GPI)',
    'Gross enrolment ratio, secondary, both sexes (%)',
    'Gross enrolment ratio, tertiary, both sexes (%)',
    'Gross enrolment ratio, tertiary, gender parity index (GPI)',
    'Gross fixed capital formation (% of GDP)',
    'Gross fixed capital formation (annual % growth)',
    'Gross fixed capital formation (constant 2005 US$)',
    'Gross intake ratio to Grade 1 of primary education, both sexes (%)',
    'Gross national expenditure (% of GDP)',
    'Gross national expenditure (constant 2005 US$)',
    'Gross national expenditure deflator (base year varies by country)',
    'Gross savings (% of GDP)', 'Gross savings (% of GNI)',
    'Gross value added at factor cost (constant 2005 US$)',
    'Health expenditure per capita, PPP (constant 2011 international $)',
    'Health expenditure, private (% of GDP)',
    'Health expenditure, public (% of GDP)',
    'Health expenditure, total (% of GDP)',
    'High-technology exports (% of manufactured exports)',
    'Hospital beds (per 1,000 people)',
    'Household final consumption expenditure (annual % growth)',
    'Household final consumption expenditure (constant 2005 US$)',
    'Household final consumption expenditure per capita (constant 2005 US$)',
    'Household final consumption expenditure per capita growth (annual %)',
    'Household final consumption expenditure, PPP (constant 2011 international $)',
    'Household final consumption expenditure, PPP (current international $)',
    'Household final consumption expenditure, etc. (% of GDP)',
    'Household final consumption expenditure, etc. (annual % growth)',
    'Household final consumption expenditure, etc. (constant 2005 US$)',
    'ICT goods exports (% of total goods exports)',
    'ICT goods imports (% total goods imports)',
    'ICT service exports (% of service exports, BoP)',
    'Import value index (2000 = 100)',
    'Imports of goods and services (% of GDP)',
    'Improved sanitation facilities (% of population with access)',
    'Improved sanitation facilities, rural (% of rural population with access)',
    'Improved sanitation facilities, urban (% of urban population with access)',
    'Income share held by fourth 20%',
    'Income share held by highest 10%',
    'Income share held by highest 20%',
    'Income share held by lowest 10%',
    'Income share held by lowest 20%',
    'Income share held by second 20%',
    'Income share held by third 20%',
    'Industry, value added (% of GDP)',
    'Industry, value added (annual % growth)',
    'Industry, value added (constant 2005 US$)',
    'Inflation, GDP deflator (annual %)',
    'Inflation, consumer prices (annual %)',
    'Informal payments to public officials (% of firms)',
    'Insurance and financial services (% of commercial service exports)',
    'Insurance and financial services (% of commercial service imports)',
    'Insurance and financial services (% of service exports, BoP)',
    'Insurance and financial services (% of service imports, BoP)',
    'Intentional homicides (per 100,000 people)',
    'Interest payments (% of expense)',
    'Interest payments (% of revenue)',
    'Interest rate spread (lending rate minus deposit rate, %)',
    'International migrant stock (% of population)',
    'International migrant stock, total',
    'International tourism, expenditures (% of total imports)',
    'International tourism, number of arrivals',
    'International tourism, number of departures',
    'International tourism, receipts (% of total exports)',
    'Internationally-recognized quality certification (% of firms)',
    'Internet users (per 100 people)',
    'Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
    'Labor force participation rate for ages 15-24, total (%) (national estimate)',
    'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
    'Labor force participation rate, total (% of total population ages 15+) (national estimate)',
    'Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
    'Labor force with primary education (% of total)',
    'Labor force with secondary education (% of total)',
    'Labor force with tertiary education (% of total)',
    'Labor tax and contributions (% of commercial profits)',
    'Lead time to export, median case (days)',
    'Lead time to import, median case (days)',
    'Lending interest rate (%)',
    'Life expectancy at birth, total (years)',
    'Lifetime risk of maternal death (%)',
    'Lifetime risk of maternal death (1 in: rate varies by country)',
    'Liner shipping connectivity index (maximum value in 2004 = 100)',
    'Listed domestic companies, total',
    'Livestock production index (2004-2006 = 100)',
    'Logistics performance index: Overall (1=low to 5=high)',
    'Long-term unemployment (% of total unemployment)',
    'Losses due to theft, robbery, vandalism, and arson (% sales)',
    'Low-birthweight babies (% of births)',
    'Lower secondary completion rate, both sexes (%)',
    'Machinery and transport equipment (% of value added in manufacturing)',
    'Manufactures exports (% of merchandise exports)',
    'Manufactures imports (% of merchandise imports)',
    'Manufacturing, value added (% of GDP)',
    'Manufacturing, value added (annual % growth)',
    'Manufacturing, value added (constant 2005 US$)',
    'Marine protected areas (% of territorial waters)',
    'Market capitalization of listed domestic companies (% of GDP)',
    'Merchandise trade (% of GDP)',
    'Military expenditure (% of GDP)',
    'Military expenditure (% of central government expenditure)',
    'Mobile cellular subscriptions (per 100 people)',
    'Mortality rate, infant (per 1,000 live births)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Mortality rate, under-5 (per 1,000)',
    'Natural gas rents (% of GDP)',
    'Net barter terms of trade index (2000 = 100)',
    'Net enrolment rate, primary, both sexes (%)',
    'Net enrolment rate, secondary, both sexes (%)',
    'Net incurrence of liabilities, domestic (% of GDP)',
    'Net incurrence of liabilities, foreign (% of GDP)',
    'Net intake rate to Grade 1 of primary education, both sexes (%)',
    'New business density (new registrations per 1,000 people ages 15-64)',
    'Nurses and midwives (per 1,000 people)',
    'Official entrance age to lower secondary education (years)',
    'Official entrance age to primary education (years)',
    'Oil rents (% of GDP)',
    'Ores and metals exports (% of merchandise exports)',
    'Ores and metals imports (% of merchandise imports)',
    'Other expense (% of expense)',
    'Other manufacturing (% of value added in manufacturing)',
    'Other taxes payable by businesses (% of commercial profits)',
    'Out-of-pocket health expenditure (% of private expenditure on health)',
    'Out-of-pocket health expenditure (% of total expenditure on health)',
    'Out-of-school children of primary school age, both sexes (number)',
    'Part time employment, total (% of total employment)',
    'Percentage of enrolment in primary education in private institutions (%)',
    'Percentage of enrolment in secondary education in private institutions (%)',
    'Percentage of repeaters in primary education, all grades, both sexes (%)',
    'Percentage of repeaters in secondary general education, all grades, both sexes (%)',
    'Permanent cropland (% of land area)',
    'Personal remittances, received (% of GDP)',
    'Point-of-sale terminals (per 100,000 adults)',
    'Population ages 65 and above (% of total)',
    'Population density (people per sq. km of land area)',
    'Population growth (annual %)', 'Population in largest city',
    'Population in the largest city (% of urban population)',
    'Population in urban agglomerations of more than 1 million (% of total population)',
    'Population living in areas where elevation is below 5 meters (% of total population)',
    'Population, ages 0-14 (% of total)',
    'Population, ages 15-64 (% of total)',
    'Price level ratio of PPP conversion factor (GDP) to market exchange rate',
    'Primary completion rate, both sexes (%)',
    'Primary to secondary general education transition rate, both sexes (%)',
    'Private credit bureau coverage (% of adults)',
    'Procedures to build a warehouse (number)',
    'Procedures to register property (number)',
    'Profit tax (% of commercial profits)',
    'Proportion of seats held by women in national parliaments (%)',
    'Public credit registry coverage (% of adults)',
    'Pump price for diesel fuel (US$ per liter)',
    'Pump price for gasoline (US$ per liter)',
    'Pupil-teacher ratio in primary education (headcount basis)',
    'Pupil-teacher ratio in secondary education (headcount basis)',
    'Quality of port infrastructure, WEF (1=extremely underdeveloped to 7=well developed and efficient by international standards)',
    'Rail lines (total route-km)',
    'Railways, goods transported (million ton-km)',
    'Railways, passengers carried (million passenger-km)',
    'Real effective exchange rate index (2010 = 100)',
    'Real interest rate (%)',
    'Renewable electricity output (% of total electricity output)',
    'Renewable energy consumption (% of total final energy consumption)',
    'Renewable internal freshwater resources per capita (cubic meters)',
    'Renewable internal freshwater resources, total (billion cubic meters)',
    'Research and development expenditure (% of GDP)',
    'Researchers in R&D (per million people)',
    'Revenue, excluding grants (% of GDP)',
    'Risk premium on lending (lending rate minus treasury bill rate, %)',
    'Rural population (% of total population)',
    'Rural population growth (annual %)',
    'S&P Global Equity Indices (annual % change)',
    'Scientific and technical journal articles',
    'Self-employed, total (% of total employed)',
    'Services, etc., value added (% of GDP)',
    'Services, etc., value added (annual % growth)',
    'Services, etc., value added (constant 2005 US$)',
    'Share of tariff lines with international peaks, all products (%)',
    'Share of tariff lines with international peaks, manufactured products (%)',
    'Share of tariff lines with international peaks, primary products (%)',
    'Share of tariff lines with specific rates, all products (%)',
    'Share of tariff lines with specific rates, manufactured products (%)',
    'Share of tariff lines with specific rates, primary products (%)',
    'Share of women in wage employment in the nonagricultural sector (% of total nonagricultural employment)',
    'Share of youth not in education, employment, or training, total (% of youth population)',
    'Social contributions (% of revenue)',
    'Start-up procedures to register a business (number)',
    'Stocks traded, total value (% of GDP)',
    'Stocks traded, turnover ratio of domestic shares (%)',
    'Strength of legal rights index (0=weak to 12=strong)',
    'Subsidies and other transfers (% of expense)',
    'Survey mean consumption or income per capita, bottom 40% of population (2011 PPP $ per day)',
    'Survey mean consumption or income per capita, total population (2011 PPP $ per day)',
    'Survival rate to Grade 5 of primary education, both sexes (%)',
    'Survival rate to the last grade of primary education, both sexes (%)',
    'Tariff rate, applied, simple mean, all products (%)',
    'Tariff rate, applied, simple mean, manufactured products (%)',
    'Tariff rate, applied, simple mean, primary products (%)',
    'Tariff rate, applied, weighted mean, all products (%)',
    'Tariff rate, applied, weighted mean, manufactured products (%)',
    'Tariff rate, applied, weighted mean, primary products (%)',
    'Tariff rate, most favored nation, simple mean, all products (%)',
    'Tariff rate, most favored nation, simple mean, manufactured products (%)',
    'Tariff rate, most favored nation, simple mean, primary products (%)',
    'Tariff rate, most favored nation, weighted mean, all products (%)',
    'Tariff rate, most favored nation, weighted mean, manufactured products (%)',
    'Tariff rate, most favored nation, weighted mean, primary products (%)',
    'Tax payments (number)', 'Tax revenue (% of GDP)',
    'Taxes on goods and services (% of revenue)',
    'Taxes on goods and services (% value added of industry and services)',
    'Taxes on income, profits and capital gains (% of revenue)',
    'Taxes on income, profits and capital gains (% of total taxes)',
    'Taxes on international trade (% of revenue)',
    'Teachers in primary education, both sexes (number)',
    'Teachers in secondary education, both sexes (number)',
    'Technicians in R&D (per million people)',
    'Terrestrial and marine protected areas (% of total territorial area)',
    'Terrestrial protected areas (% of total land area)',
    'Textiles and clothing (% of value added in manufacturing)',
    'Theoretical duration of primary education (years)',
    'Theoretical duration of secondary education (years)',
    'Time required to build a warehouse (days)',
    'Time required to enforce a contract (days)',
    'Time required to get electricity (days)',
    'Time required to register property (days)',
    'Time required to start a business (days)',
    'Time spent dealing with the requirements of government regulations (% of senior management time)',
    'Time to export (days)', 'Time to import (days)',
    'Time to prepare and pay taxes (hours)',
    'Time to resolve insolvency (years)',
    'Total natural resources rents (% of GDP)',
    'Total reserves in months of imports',
    'Total tax rate (% of commercial profits)', 'Trade (% of GDP)',
    'Trade in services (% of GDP)',
    'Transport services (% of commercial service exports)',
    'Transport services (% of commercial service imports)',
    'Transport services (% of service exports, BoP)',
    'Transport services (% of service imports, BoP)',
    'Travel services (% of commercial service exports)',
    'Travel services (% of commercial service imports)',
    'Travel services (% of service exports, BoP)',
    'Travel services (% of service imports, BoP)',
    'Unemployment, total (% of total labor force)',
    'Unmet need for contraception (% of married women ages 15-49)',
    'Urban population (% of total)',
    'Urban population growth (annual %)',
    'Vulnerable employment, total (% of total employment)',
    'Wage and salaried workers, total (% of total employed)',
    'Wholesale price index (2010 = 100)',
    'Youth literacy rate, population 15-24 years, both sexes (%)']


ARRAY_INDICATORS = list(set(ARRAY_INDICATORS))

conn = sqlite3.connect('../input/world-development-indicators/database.sqlite')

# %% [markdown]
# # Get indicators to analyze

# %% [markdown]
# ## Top/Bottom method

# %% [markdown]
# ### Get data for the country

# %%
CountryName = 'Spain'  # Change this to another country

# %%
CountryCode = pd.read_sql(f"""SELECT CountryCode 
               FROM Indicators
               WHERE CountryName = '{CountryName}'
               LIMIT 1""",
           conn).values[0][0]

Region  = pd.read_sql(f"""SELECT Region
               FROM Country
               WHERE CountryCode = '{CountryCode}'
               LIMIT 1""", conn).values[0][0]

Neigbours_in_the_zone  = pd.read_sql(f"""SELECT *
               FROM Country
               WHERE Region = '{Region}'
               """, conn)

neighbours = Neigbours_in_the_zone.shape[0]
neighbours

print(f"Lets analyze the indicator for: {CountryName} ({CountryCode}), from zone: {Region}, that has {neighbours} countries")
# Out:
# Lets analyze the indicator for: Spain (ESP), from zone: Europe & Central Asia, that has 57 countries

# %%
# %%time

### Rankings

LIMIT_TOPBOTTOM_FEATURES=10

### For each indicator, last values, for all countries.
def get_indicators_topbottom_method(CountryCode):
    """Return DataFrame with the indicators ranked according the position in the region for a given country (aka, very good/very bad indicators for a country )"""
    arr_rankings = []
    
    Region  = pd.read_sql(f"""SELECT Region
               FROM Country
               WHERE CountryCode = '{CountryCode}'
               LIMIT 1""", conn).values[0][0]
    
    Neigbours_in_the_zone  = pd.read_sql(f"""SELECT *
                   FROM Country
                   WHERE Region = '{Region}'
                   """, conn)

    neighbours = Neigbours_in_the_zone.shape[0]
    neighbours
      
    for indicator in tqdm(ARRAY_INDICATORS) :
            
        SQL=f"""   
        SELECT 
            Indicators.CountryCode AS CountryCode, 
            Indicators.Value AS  'Last Value in country', 
            Indicators.IndicatorName
        FROM
        Indicators,
        (
            SELECT  (CountryCode||'_'||MAX(Year)) AS Country_Year
            FROM   Indicators 
            WHERE  IndicatorName = '{indicator}'
                   AND CountryCode in ( SELECT CountryCode  FROM Country WHERE Region = '{Region}' )
            GROUP BY CountryCode, Year
            ORDER BY Value desc
        ) LAST_YEAR_WITH_DATA
        WHERE 
            LAST_YEAR_WITH_DATA.Country_Year =  (Indicators.CountryCode||'_'||Indicators.Year) AND
            IndicatorName = '{indicator}'
        ORDER BY Value desc
        """
        #print(f"SQL={SQL}")
        df_sql =  pd.read_sql(SQL,conn)
        for ascending in [True,False]:
            df_indicators = df_sql.copy()

            df_indicators = df_indicators.sort_values(by=['Last Value in country'], ascending=ascending)
            if CountryCode not in df_indicators.CountryCode.head(LIMIT_TOPBOTTOM_FEATURES).values: continue

            df_indicators['order'] = "bottom" if ascending else "top"
            df_indicators['average Value in region']=  df_indicators['Last Value in country'].mean()
            df_indicators = df_indicators.head(LIMIT_TOPBOTTOM_FEATURES)
            df_indicators['ranking'] = range(1,df_indicators.shape[0]+1)
            df_indicators['distance with average'] = ( 
                (
                    (df_indicators['Last Value in country'] - df_indicators['average Value in region']) **2
                    / 
                    (df_indicators['average Value in region']) **2
                )  ).astype(float).map(lambda n: '{:.2}'.format(n))
            arr_rankings.append(df_indicators.query( f'CountryCode == "{CountryCode}"', engine = 'python'  ).head(1))

    

    df_rankings = pd.concat(arr_rankings)
    df_rankings['countries in the region'] = neighbours
    df_rankings = df_rankings.sort_values('ranking')
    df_rankings['Region'] = Region 

    df_rankings= df_rankings[['ranking','order','IndicatorName','Last Value in country',
                       'average Value in region','distance with average','CountryCode' ,'Region', 'countries in the region'
                      ]]

    return  df_rankings


df_rankings = get_indicators_topbottom_method(CountryCode)
df_rankings = df_rankings.head(25)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=436.0), HTML(value='')))
# CPU times: user 10.5 s, sys: 7.76 s, total: 18.3 s
# Wall time: 18.2 s

# %%
df_rankings.head(30)
# Out:
#      ranking   order                                                                                     IndicatorName  Last Value in country  average Value in region distance with average CountryCode                 Region  countries in the region
# 658        1  bottom                                                        Taxes on goods and services (% of revenue)           9.558768e+00             3.369731e+01                  0.51         ESP  Europe & Central Asia                       57
# 651        1  bottom                              Taxes on goods and services (% value added of industry and services)           2.575314e+00             1.390394e+01                  0.66         ESP  Europe & Central Asia                       57
# 0          1     top                                              Adjusted net enrolment rate, primary, both sexes (%)           9.999719e+01             9.527706e+01                0.0025         ESP  Europe & Central Asia                       57
# 0          1     top                                                          Time required to start a business (days)           1.380000e+02             2.078027e+01               3.2e+01         ESP  Europe & Central Asia                       57
# 0          1     top                                                       Net enrolment rate, primary, both sexes (%)           9.999719e+01             9.401769e+01                 0.004         ESP  Europe & Central Asia                       57
# 0          1     top                                                                  Listed domestic companies, total           3.538000e+03             3.354661e+02               9.1e+01         ESP  Europe & Central Asia                       57
# 1          2     top                                   Net intake rate to Grade 1 of primary education, both sexes (%)           9.898824e+01             7.905017e+01                 0.064         ESP  Europe & Central Asia                       57
# 837        2  bottom                                                 Adjusted savings: net forest depletion (% of GNI)           0.000000e+00             8.536748e-02                   1.0         ESP  Europe & Central Asia                       57
# 358        2     top                                                                Binding coverage, all products (%)           1.000000e+02             9.861409e+01                0.0002         ESP  Europe & Central Asia                       57
# 113        2  bottom                                                           Lead time to export, median case (days)           1.000000e+00             2.485481e+00                  0.36         ESP  Europe & Central Asia                       57
# 1          2     top                                     Taxes on income, profits and capital gains (% of total taxes)           6.867788e+01             3.350313e+01                   1.1         ESP  Europe & Central Asia                       57
# 123        2  bottom  Time spent dealing with the requirements of government regulations (% of senior management time)           8.000000e-01             8.116800e+00                  0.81         ESP  Europe & Central Asia                       57
# 2          3     top                                                      Point-of-sale terminals (per 100,000 adults)           3.523039e+03             1.349234e+03                   2.6         ESP  Europe & Central Asia                       57
# 2          3     top              GEF benefits index for biodiversity (0 = no biodiversity potential to 100 = maximum)           6.842703e+00             1.700861e+00                   9.1         ESP  Europe & Central Asia                       57
# 363        3     top                                                            Binding coverage, primary products (%)           1.000000e+02             9.782347e+01                0.0005         ESP  Europe & Central Asia                       57
# 671        3  bottom                                                                            Tax revenue (% of GDP)           7.161857e+00             2.005405e+01                  0.41         ESP  Europe & Central Asia                       57
# 64         4  bottom                                  Firms that do not report all sales for tax purposes (% of firms)           1.833000e+01             4.454397e+01                  0.35         ESP  Europe & Central Asia                       57
# 107        4     top                         Improved sanitation facilities, rural (% of rural population with access)           1.000000e+02             9.065352e+01                 0.011         ESP  Europe & Central Asia                       57
# 118        5  bottom                                                Informal payments to public officials (% of firms)           4.400000e+00             3.093089e+01                  0.74         ESP  Europe & Central Asia                       57
# 4          5     top                                                                   Income share held by fourth 20%           2.358000e+01             2.240126e+01                0.0028         ESP  Europe & Central Asia                       57
# 91         5  bottom                                                            Cause of death, by injury (% of total)           3.400000e+00             6.317708e+00                  0.21         ESP  Europe & Central Asia                       57
# 5          6     top                       Droughts, floods, extreme temperatures (% of population, average 1990-2009)           7.291935e-01             3.921125e-01                  0.74         ESP  Europe & Central Asia                       57
# 5          6     top                      Electricity production from renewable sources, excluding hydroelectric (kWh)           7.417000e+10             1.980949e+09               1.3e+03         ESP  Europe & Central Asia                       57
# 5          6     top                                      Pupil-teacher ratio in secondary education (headcount basis)           2.614025e+01             1.253845e+01                   1.2         ESP  Europe & Central Asia                       57
# 68         6     top                                                        Access to non-solid fuel (% of population)           1.000000e+02             8.761239e+01                  0.02         ESP  Europe & Central Asia                       57
# 136        7  bottom                                                              Profit tax (% of commercial profits)           1.200000e+00             1.189860e+01                  0.81         ESP  Europe & Central Asia                       57
# 7          8     top                                                              Profit tax (% of commercial profits)           2.190000e+01             1.189860e+01                  0.71         ESP  Europe & Central Asia                       57
# 7          8     top                                            Container port traffic (TEU: 20 foot equivalent units)           1.418468e+07             3.382160e+06                 1e+01         ESP  Europe & Central Asia                       57
# 8          9     top                                                           Lead time to import, median case (days)           7.070000e+00             3.230154e+00                   1.4         ESP  Europe & Central Asia                       57
# 133        9     top                                                           Access to electricity (% of population)           1.000000e+02             9.957297e+01               1.8e-05         ESP  Europe & Central Asia                       57

# %% [markdown]
# ## Cosine distance  method

# %%
import traceback
def get_comparision_df(CountryCode1,CountryCode2,filter_indicator='%',DEBUG=False):
    """ Compare two countries with a specific filter"""
    result_array = []
    df_result = pd.DataFrame()

    # We extract indicator from
    df_indicators = pd.read_sql(f"""
                   SELECT distinct(IndicatorName) as IndicatorName
                   FROM Indicators
                   WHERE  CountryCode  = '{CountryCode1}'
                          AND IndicatorName LIKE  '%{filter_indicator}%' """,
               conn)
    if DEBUG : print(f"""SELECT distinct(IndicatorName) as IndicatorName
                   FROM Indicators
                   WHERE  CountryCode  = '{CountryCode1}'
                          AND IndicatorName LIKE  '%{filter_indicator}%' """)
    df_world = pd.read_sql(f"""
                  SELECT distinct(IndicatorName) as IndicatorName
                   FROM Indicators
                   WHERE  CountryCode   = '{CountryCode2}' 
                          AND IndicatorName LIKE  '%{filter_indicator}%'""",
               conn)
    if DEBUG : print(f"""2 : SELECT distinct(IndicatorName) as IndicatorName
                   FROM Indicators
                   WHERE  CountryCode   = '{CountryCode2}' 
                          AND IndicatorName LIKE  '%{filter_indicator}%' """)
    
    indicators_array = df_indicators.IndicatorName.values
    world_array      = df_world.IndicatorName.values
    indicator_array  = set(indicators_array) & set( world_array)  & set( ARRAY_INDICATORS)
    indicator_array_size = len (indicator_array)
    if DEBUG : print(f"""Indicadores::: df_indicators,{df_indicators.shape}, df_world,{df_world.shape}, indicator_array_size,{indicator_array_size}""")
    # Get Diferences between a country and the rest
    
    for IndicatorName in tqdm(indicator_array) :

        try :
            SQL=  f"""
                SELECT
                A.Year AS Year,
                A.Value as 'Value_{CountryCode2}',
                B.Value as 'Value_{CountryCode1}'
                FROM 
                  ( SELECT Year,Value, CountryName  FROM Indicators WHERE IndicatorName = '{IndicatorName}' AND CountryCode = '{CountryCode2}' ) A   ,
                  ( SELECT Year,Value, CountryName  FROM Indicators WHERE IndicatorName = '{IndicatorName}' AND CountryCode = '{CountryCode1}') B 
                WHERE A.Year = B.Year """ 
            df_values =  pd.read_sql(SQL,conn)
            #Year	Value_EMU	Value_ESP
            length = df_values.shape[0]
            if length < 3 : 
                if DEBUG : print(f"df_values: {IndicatorName} not enough common values  {length} ,to evaluate properly")
                continue
                    
            x = df_values[['Year','Value_'+CountryCode2]].values
            #x              = otro[['Year','Value']].values
            min_max_scaler = preprocessing.MinMaxScaler()
            otro_scaled    = min_max_scaler.fit_transform(x)
            x_otro         = [ point[1] for point in otro_scaled ]

            x = df_values[['Year','Value_'+CountryCode1]].values

            df_scaled = min_max_scaler.fit_transform(x)
            x_df         = [ point[1] for point in df_scaled ]


            #dst = distance.cosine(df.Value,otro.Value)
            dst = distance.cosine(x_otro,x_df)

            result_array.append({ 
                "value"          : dst, 
                "CountryCode"    : CountryCode1 , 
                'CountryCompare' : CountryCode2 , 
                "IndicatorName"  : IndicatorName  } )
            
        except Exception as e : 
            print(IndicatorName,e)
    df_result = pd.DataFrame(result_array) 

    length = df_result.shape[0]
    if DEBUG : print(df_result.columns,length)

    if length == 0 : 
        if DEBUG : print(f"Vacio: {IndicatorName} al the end")
        return None
    df_result = df_result[df_result['value'].notna()]
    df_result = df_result.sort_values('value')
    return df_result

CountryCompare ='WLD'

df_cosine_results = get_comparision_df('ESP',CountryCompare,'%',False)
df_cosine_results
# Out:
# HBox(children=(FloatProgress(value=0.0, max=358.0), HTML(value='')))
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
#         value CountryCode CountryCompare                                                                                        IndicatorName
# 243  0.000420         ESP            WLD                                             Adjusted savings: particulate emission damage (% of GNI)
# 9    0.000684         ESP            WLD                                                              Researchers in R&D (per million people)
# 274  0.002244         ESP            WLD                                                 Gross value added at factor cost (constant 2005 US$)
# 231  0.002636         ESP            WLD                                                            Scientific and technical journal articles
# 221  0.003198         ESP            WLD                                              Final consumption expenditure, etc. (constant 2005 US$)
# 308  0.003356         ESP            WLD                                                    Final consumption expenditure (constant 2005 US$)
# 14   0.003584         ESP            WLD                                                                              GNI (constant 2005 US$)
# 314  0.003732         ESP            WLD                                                                   GDP per capita (constant 2005 US$)
# 86   0.004500         ESP            WLD                                 General government final consumption expenditure (constant 2005 US$)
# 50   0.005030         ESP            WLD                                                     Adjusted net national income (constant 2005 US$)
# 310  0.005326         ESP            WLD                                                      Services, etc., value added (constant 2005 US$)
# 44   0.005464         ESP            WLD                                                       Fixed broadband subscriptions (per 100 people)
# 318  0.005628         ESP            WLD                                    Household final consumption expenditure, etc. (constant 2005 US$)
# 148  0.006068         ESP            WLD                                              Age dependency ratio, old (% of working-age population)
# 207  0.006096         ESP            WLD                                          Household final consumption expenditure (constant 2005 US$)
# 72   0.006585         ESP            WLD                                                              Life expectancy at birth, total (years)
# 210  0.006975         ESP            WLD                                               Container port traffic (TEU: 20 foot equivalent units)
# 263  0.006984         ESP            WLD                                                  Population density (people per sq. km of land area)
# 279  0.007386         ESP            WLD                                                       Gross national expenditure (constant 2005 US$)
# 13   0.007470         ESP            WLD                                                                   GNI per capita (constant 2005 US$)
# 283  0.007717         ESP            WLD                                                    Exports of goods and services (constant 2005 US$)
# 328  0.007719         ESP            WLD                                                         ICT goods exports (% of total goods exports)
# 10   0.008292         ESP            WLD                                                           Pump price for diesel fuel (US$ per liter)
# 11   0.009025         ESP            WLD                                                            Population ages 65 and above (% of total)
# 91   0.009147         ESP            WLD                                    Renewable internal freshwater resources per capita (cubic meters)
# 222  0.009593         ESP            WLD                               Household final consumption expenditure per capita (constant 2005 US$)
# 194  0.009632         ESP            WLD                                                          Electric power consumption (kWh per capita)
# 180  0.010037         ESP            WLD                                          Adjusted net national income per capita (constant 2005 US$)
# 16   0.010240         ESP            WLD                                   Health expenditure per capita, PPP (constant 2011 international $)
# 125  0.011046         ESP            WLD                                                                Manufacturing, value added (% of GDP)
# 305  0.011215         ESP            WLD                               Household final consumption expenditure, PPP (current international $)
# 48   0.013281         ESP            WLD                                                              Pump price for gasoline (US$ per liter)
# 134  0.013726         ESP            WLD                                                            Gross domestic income (constant 2005 US$)
# 176  0.014268         ESP            WLD                                                                      Internet users (per 100 people)
# 240  0.014624         ESP            WLD                                               Logistics performance index: Overall (1=low to 5=high)
# 6    0.014900         ESP            WLD                                                      ICT service exports (% of service exports, BoP)
# 136  0.015661         ESP            WLD                                                                                     Trade (% of GDP)
# 198  0.017255         ESP            WLD                                               Agriculture value added per worker (constant 2005 US$)
# 45   0.017367         ESP            WLD                                                         Livestock production index (2004-2006 = 100)
# 220  0.017542         ESP            WLD                                                             Exports of goods and services (% of GDP)
# 121  0.017975         ESP            WLD                                                                         Merchandise trade (% of GDP)
# 97   0.018590         ESP            WLD                                                              Food imports (% of merchandise imports)
# 304  0.021101         ESP            WLD                                       Agricultural machinery, tractors per 100 sq. km of arable land
# 15   0.021692         ESP            WLD                                                                   Cost to export (US$ per container)
# 190  0.021786         ESP            WLD                                            Age dependency ratio, young (% of working-age population)
# 254  0.022768         ESP            WLD                                                             Imports of goods and services (% of GDP)
# 174  0.022879         ESP            WLD                                                         Private credit bureau coverage (% of adults)
# 291  0.023081         ESP            WLD                                                Labor tax and contributions (% of commercial profits)
# 63   0.024009         ESP            WLD                                                              Food production index (2004-2006 = 100)
# 82   0.024773         ESP            WLD                                                                   Population, ages 0-14 (% of total)
# 282  0.025530         ESP            WLD                                           Gross enrolment ratio, tertiary, gender parity index (GPI)
# 90   0.025561         ESP            WLD                                                      Gross enrolment ratio, tertiary, both sexes (%)
# 297  0.026094         ESP            WLD                                                               Binding coverage, primary products (%)
# 188  0.026965         ESP            WLD                                                             Fertility rate, total (births per woman)
# 31   0.028297         ESP            WLD                                                      Manufactures imports (% of merchandise imports)
# 179  0.028531         ESP            WLD                                                                      Cash surplus/deficit (% of GDP)
# 77   0.028731         ESP            WLD                                                                        Cereal yield (kg per hectare)
# 321  0.029374         ESP            WLD                                                      Exports of goods and services (annual % growth)
# 22   0.029425         ESP            WLD                                        Agricultural raw materials imports (% of merchandise imports)
# 258  0.029632         ESP            WLD                         Electricity production from renewable sources, excluding hydroelectric (kWh)
# 26   0.030578         ESP            WLD                                                                Time to prepare and pay taxes (hours)
# 196  0.031682         ESP            WLD                                                              Crop production index (2004-2006 = 100)
# 58   0.031753         ESP            WLD                                                            International tourism, number of arrivals
# 1    0.031756         ESP            WLD                                                             GDP, PPP (constant 2011 international $)
# 202  0.032342         ESP            WLD                                             Electricity production from nuclear sources (% of total)
# 241  0.032676         ESP            WLD                                                    Gross fixed capital formation (constant 2005 US$)
# 150  0.032977         ESP            WLD                                                            Goods and services expense (% of expense)
# 34   0.033036         ESP            WLD                                              Tariff rate, applied, simple mean, primary products (%)
# 140  0.034652         ESP            WLD                                                                              Forest rents (% of GDP)
# 261  0.034703         ESP            WLD                                                                   Cost to import (US$ per container)
# 120  0.034808         ESP            WLD                                                   Age dependency ratio (% of working-age population)
# 244  0.035260         ESP            WLD                                 Share of tariff lines with international peaks, primary products (%)
# 266  0.035291         ESP            WLD                                                          Gross capital formation (constant 2005 US$)
# 142  0.035742         ESP            WLD                                          General government final consumption expenditure (% of GDP)
# 132  0.036320         ESP            WLD                                                 Teachers in secondary education, both sexes (number)
# 234  0.036568         ESP            WLD                                                       Fixed telephone subscriptions (per 100 people)
# 242  0.039142         ESP            WLD                                                                  Mortality rate, under-5 (per 1,000)
# 21   0.039883         ESP            WLD                                                         Energy use (kg of oil equivalent per capita)
# 163  0.040023         ESP            WLD                                                       Mortality rate, infant (per 1,000 live births)
# 183  0.040113         ESP            WLD                         Household final consumption expenditure, PPP (constant 2011 international $)
# 316  0.040779         ESP            WLD                                                                  Population, ages 15-64 (% of total)
# 177  0.040999         ESP            WLD                                               Alternative and nuclear energy (% of total energy use)
# 269  0.041397         ESP            WLD                                                     Gross enrolment ratio, secondary, both sexes (%)
# 235  0.041653         ESP            WLD                                                                        Urban population (% of total)
# 289  0.041722         ESP            WLD                                        Market capitalization of listed domestic companies (% of GDP)
# 290  0.042200         ESP            WLD                                           Communications, computer, etc. (% of service exports, BoP)
# 38   0.042435         ESP            WLD                                                Final consumption expenditure, etc. (annual % growth)
# 7    0.042569         ESP            WLD                                                                Health expenditure, public (% of GDP)
# 272  0.043036         ESP            WLD                                                                                GDP growth (annual %)
# 295  0.043073         ESP            WLD                                                  Tariff rate, applied, simple mean, all products (%)
# 76   0.044931         ESP            WLD                                        Proportion of seats held by women in national parliaments (%)
# 80   0.045118         ESP            WLD                                                 Stocks traded, turnover ratio of domestic shares (%)
# 181  0.045716         ESP            WLD                                                     Mortality rate, neonatal (per 1,000 live births)
# 300  0.046501         ESP            WLD                                                         Manufacturing, value added (annual % growth)
# 98   0.046607         ESP            WLD                                                   Foreign direct investment, net outflows (% of GDP)
# 273  0.047260         ESP            WLD                                   Insurance and financial services (% of commercial service imports)
# 259  0.047486         ESP            WLD                                                    Travel services (% of commercial service exports)
# 88   0.047516         ESP            WLD                                      Household final consumption expenditure, etc. (annual % growth)
# 257  0.048148         ESP            WLD                        Computer, communications and other services (% of commercial service exports)
# 126  0.048297         ESP            WLD                  Electricity production from renewable sources, excluding hydroelectric (% of total)
# 197  0.048774         ESP            WLD                                                      Gross fixed capital formation (annual % growth)
# 100  0.050091         ESP            WLD                                                        Net enrolment rate, secondary, both sexes (%)
# 217  0.051085         ESP            WLD                    Population in urban agglomerations of more than 1 million (% of total population)
# 55   0.051128         ESP            WLD                                   Insurance and financial services (% of commercial service exports)
# 101  0.052195         ESP            WLD                                            Household final consumption expenditure (annual % growth)
# 286  0.053048         ESP            WLD                             Percentage of repeaters in primary education, all grades, both sexes (%)
# 47   0.053425         ESP            WLD                                                        GDP per person employed (constant 1990 PPP $)
# 71   0.054084         ESP            WLD                                                          Net enrolment rate, primary, both sexes (%)
# 320  0.055391         ESP            WLD                                                                      Cereal production (metric tons)
# 74   0.055553         ESP            WLD                                                              Time required to get electricity (days)
# 130  0.056218         ESP            WLD                                                          International tourism, number of departures
# 293  0.056402         ESP            WLD                                 Share of tariff lines with specific rates, manufactured products (%)
# 245  0.056775         ESP            WLD                                                                               Tax revenue (% of GDP)
# 166  0.057325         ESP            WLD                                                            Gross capital formation (annual % growth)
# 285  0.057410         ESP            WLD                                                        Services, etc., value added (annual % growth)
# 118  0.057720         ESP            WLD                                                                   Wholesale price index (2010 = 100)
# 311  0.057784         ESP            WLD                                                                                GNI growth (annual %)
# 182  0.057839         ESP            WLD                                                      Manufactures exports (% of merchandise exports)
# 139  0.058401         ESP            WLD                                 Household final consumption expenditure per capita growth (annual %)
# 112  0.061192         ESP            WLD                                           Military expenditure (% of central government expenditure)
# 79   0.061675         ESP            WLD                                                   Net incurrence of liabilities, domestic (% of GDP)
# 215  0.062108         ESP            WLD                                                 Transport services (% of commercial service exports)
# 237  0.062439         ESP            WLD                                     Share of tariff lines with international peaks, all products (%)
# 302  0.062567         ESP            WLD                                                             Rural population (% of total population)
# 253  0.062607         ESP            WLD                                                                Stocks traded, total value (% of GDP)
# 307  0.062746         ESP            WLD                                   General government final consumption expenditure (annual % growth)
# 113  0.063168         ESP            WLD                                                                     Listed domestic companies, total
# 40   0.064561         ESP            WLD                                                   Gross enrolment ratio, pre-primary, both sexes (%)
# 306  0.065293         ESP            WLD                                                                     GNI per capita growth (annual %)
# 33   0.065532         ESP            WLD                                                 Adjusted net enrolment rate, primary, both sexes (%)
# 116  0.065612         ESP            WLD                                                   Ores and metals imports (% of merchandise imports)
# 315  0.066304         ESP            WLD                                           Cost of business start-up procedures (% of GNI per capita)
# 87   0.067433         ESP            WLD                                                   Teachers in primary education, both sexes (number)
# 46   0.067509         ESP            WLD                                           Pupil-teacher ratio in primary education (headcount basis)
# 284  0.067809         ESP            WLD                                       Tariff rate, applied, weighted mean, manufactured products (%)
# 66   0.069042         ESP            WLD                                                             Time required to start a business (days)
# 204  0.071528         ESP            WLD                                                       Adjusted net national income (annual % growth)
# 195  0.074194         ESP            WLD                                                                Inflation, consumer prices (annual %)
# 127  0.074873         ESP            WLD                                                  GNI per capita, PPP (constant 2011 international $)
# 8    0.076004         ESP            WLD                                                       Mobile cellular subscriptions (per 100 people)
# 19   0.076364         ESP            WLD                                            Adjusted net national income per capita (annual % growth)
# 323  0.078321         ESP            WLD                                                                     Hospital beds (per 1,000 people)
# 114  0.078329         ESP            WLD                                                     Marine protected areas (% of territorial waters)
# 128  0.079169         ESP            WLD                                                   Ores and metals exports (% of merchandise exports)
# 145  0.079401         ESP            WLD                                                 International tourism, receipts (% of total exports)
# 219  0.080076         ESP            WLD                                                                      Military expenditure (% of GDP)
# 39   0.081582         ESP            WLD                                         Insurance and financial services (% of service exports, BoP)
# 252  0.081632         ESP            WLD                             Tariff rate, most favored nation, simple mean, manufactured products (%)
# 123  0.083301         ESP            WLD                                          Energy intensity level of primary energy (MJ/$2011 PPP GDP)
# 278  0.083612         ESP            WLD                                  Tariff rate, most favored nation, simple mean, primary products (%)
# 232  0.084192         ESP            WLD                                 Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)
# 225  0.085404         ESP            WLD                                      Share of tariff lines with specific rates, primary products (%)
# 239  0.085748         ESP            WLD                                                                   Inflation, GDP deflator (annual %)
# 78   0.085882         ESP            WLD                                      Tariff rate, most favored nation, simple mean, all products (%)
# 209  0.086408         ESP            WLD                                                            ICT goods imports (% total goods imports)
# 146  0.086737         ESP            WLD                                                        Public credit registry coverage (% of adults)
# 276  0.088076         ESP            WLD                                                 Electricity production from oil sources (% of total)
# 93   0.089450         ESP            WLD                                                              Food exports (% of merchandise exports)
# 153  0.089470         ESP            WLD                                                                     Interest payments (% of expense)
# 200  0.089725         ESP            WLD                                                                 Revenue, excluding grants (% of GDP)
# 104  0.091352         ESP            WLD                                        Agricultural raw materials exports (% of merchandise exports)
# 57   0.091512         ESP            WLD                                       Electricity production from hydroelectric sources (% of total)
# 224  0.094168         ESP            WLD  Share of women in wage employment in the nonagricultural sector (% of total nonagricultural empl...
# 117  0.094641         ESP            WLD                                                                 Health expenditure, total (% of GDP)
# 149  0.095941         ESP            WLD                                                    Employment in agriculture (% of total employment)
# 102  0.098199         ESP            WLD                                                              Industry, value added (annual % growth)
# 280  0.098909         ESP            WLD                            Share of tariff lines with international peaks, manufactured products (%)
# 267  0.099779         ESP            WLD                                                        Bound rate, simple mean, primary products (%)
# 106  0.100150         ESP            WLD                                            Adjusted savings: consumption of fixed capital (% of GNI)
# 73   0.105515         ESP            WLD                              Gross enrolment ratio, primary and secondary, gender parity index (GPI)
# 108  0.106632         ESP            WLD                                                                  Agriculture, value added (% of GDP)
# 129  0.106866         ESP            WLD                                         Electricity production from natural gas sources (% of total)
# 298  0.109680         ESP            WLD                                       Lifetime risk of maternal death (1 in: rate varies by country)
# 85   0.113541         ESP            WLD                                                                                 Forest area (sq. km)
# 324  0.115833         ESP            WLD  Quality of port infrastructure, WEF (1=extremely underdeveloped to 7=well developed and efficien...
# 192  0.117826         ESP            WLD                                                         Agriculture, value added (constant 2005 US$)
# 268  0.119058         ESP            WLD                                                    Foreign direct investment, net inflows (% of GDP)
# 292  0.119583         ESP            WLD                                                                  Lifetime risk of maternal death (%)
# 43   0.120071         ESP            WLD                                                                             Gross savings (% of GDP)
# 67   0.121005         ESP            WLD                                                                    Gross domestic savings (% of GDP)
# 60   0.123092         ESP            WLD                                                                   International migrant stock, total
# 171  0.125426         ESP            WLD                           Tariff rate, most favored nation, weighted mean, manufactured products (%)
# 326  0.125928         ESP            WLD                                                                     Industry, value added (% of GDP)
# 168  0.127283         ESP            WLD                                         Tariff rate, applied, simple mean, manufactured products (%)
# 12   0.129475         ESP            WLD                      Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)
# 54   0.131680         ESP            WLD                                                  High-technology exports (% of manufactured exports)
# 154  0.132236         ESP            WLD                                                                   Binding coverage, all products (%)
# 151  0.133399         ESP            WLD                                                                   Urban population growth (annual %)
# 216  0.133974         ESP            WLD                            GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent)
# 135  0.137667         ESP            WLD                               Adjusted net savings, excluding particulate emission damage (% of GNI)
# 94   0.138800         ESP            WLD                                                                   Gross capital formation (% of GDP)
# 157  0.142049         ESP            WLD                                                               Health expenditure, private (% of GDP)
# 251  0.142870         ESP            WLD                                                            Bound rate, simple mean, all products (%)
# 141  0.143445         ESP            WLD                                          Share of tariff lines with specific rates, all products (%)
# 23   0.144845         ESP            WLD                                                             Total tax rate (% of commercial profits)
# 213  0.146542         ESP            WLD                                                       Manufacturing, value added (constant 2005 US$)
# 322  0.148944         ESP            WLD                                                    External balance on goods and services (% of GDP)
# 319  0.149187         ESP            WLD                                                       Employment in services (% of total employment)
# 65   0.154341         ESP            WLD                                   Renewable energy consumption (% of total final energy consumption)
# 53   0.156063         ESP            WLD                                  Out-of-pocket health expenditure (% of total expenditure on health)
# 89   0.160895         ESP            WLD                                 Survival rate to the last grade of primary education, both sexes (%)
# 299  0.161293         ESP            WLD                                                           Agriculture, value added (annual % growth)
# 325  0.164650         ESP            WLD                                                          Fossil fuel energy consumption (% of total)
# 25   0.165307         ESP            WLD                                                  Start-up procedures to register a business (number)
# 156  0.165647         ESP            WLD                        Computer, communications and other services (% of commercial service imports)
# 248  0.166460         ESP            WLD                                                                  Total reserves in months of imports
# 228  0.169665         ESP            WLD                                                    Net incurrence of liabilities, foreign (% of GDP)
# 103  0.173481         ESP            WLD                                                          Arms imports (SIPRI trend indicator values)
# 218  0.176729         ESP            WLD                   Percentage of repeaters in secondary general education, all grades, both sexes (%)
# 211  0.178571         ESP            WLD                                                             Gross fixed capital formation (% of GDP)
# 124  0.178906         ESP            WLD                                                   Adjusted savings: carbon dioxide damage (% of GNI)
# 52   0.182439         ESP            WLD                                         Renewable electricity output (% of total electricity output)
# 226  0.185594         ESP            WLD                                                               Services, etc., value added (% of GDP)
# 275  0.190185         ESP            WLD                                                            Industry, value added (constant 2005 US$)
# 49   0.194013         ESP            WLD                                                        International migrant stock (% of population)
# 83   0.195718         ESP            WLD                                                              Fuel exports (% of merchandise exports)
# 18   0.196281         ESP            WLD                                                                     Interest payments (% of revenue)
# 105  0.196517         ESP            WLD                                   Gross intake ratio to Grade 1 of primary education, both sexes (%)
# 56   0.202381         ESP            WLD                                                  Fertilizer consumption (% of fertilizer production)
# 233  0.205092         ESP            WLD                                                                  Permanent cropland (% of land area)
# 29   0.207161         ESP            WLD                                                    Adjusted savings: net national savings (% of GNI)
# 41   0.208773         ESP            WLD                                                                         Documents to import (number)
# 256  0.209504         ESP            WLD                                    Electric power transmission and distribution losses (% of output)
# 5    0.210725         ESP            WLD                                                          Travel services (% of service exports, BoP)
# 36   0.213487         ESP            WLD                         Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)
# 159  0.216265         ESP            WLD                                                Electricity production from coal sources (% of total)
# 187  0.220499         ESP            WLD                                                  Enrolment in secondary general, both sexes (number)
# 230  0.221608         ESP            WLD                                                                         Forest area (% of land area)
# 206  0.223202         ESP            WLD                                                         Unemployment, total (% of total labor force)
# 260  0.223511         ESP            WLD                                                                         Population growth (annual %)
# 28   0.224120         ESP            WLD                                         Insurance and financial services (% of service imports, BoP)
# 208  0.227608         ESP            WLD                                    Distance to frontier score (0=lowest performance to 100=frontier)
# 68   0.228830         ESP            WLD                                                            Time required to register property (days)
# 69   0.231284         ESP            WLD                                        Adolescent fertility rate (births per 1,000 women ages 15-19)
# 75   0.233529         ESP            WLD                                                                                Time to import (days)
# 173  0.241736         ESP            WLD                                Out-of-pocket health expenditure (% of private expenditure on health)
# 169  0.249022         ESP            WLD                                                       Employment in industry (% of total employment)
# 162  0.253682         ESP            WLD                                                             Total natural resources rents (% of GDP)
# 205  0.256516         ESP            WLD                                                   Bound rate, simple mean, manufactured products (%)
# 265  0.257648         ESP            WLD                                                                         Trade in services (% of GDP)
# 84   0.258695         ESP            WLD                                                         Railways, goods transported (million ton-km)
# 288  0.261551         ESP            WLD                                                                        Armed forces personnel, total
# 309  0.262618         ESP            WLD                                             International tourism, expenditures (% of total imports)
# 133  0.263105         ESP            WLD                                                           Adjusted savings: gross savings (% of GNI)
# 143  0.263801         ESP            WLD                                                                   Agricultural land (% of land area)
# 61   0.264299         ESP            WLD                                                                                 Oil rents (% of GDP)
# 24   0.265418         ESP            WLD                                                    Travel services (% of commercial service imports)
# 62   0.265542         ESP            WLD                                           Communications, computer, etc. (% of service imports, BoP)
# 277  0.265757         ESP            WLD                                                                             Gross savings (% of GNI)
# 96   0.267300         ESP            WLD                                                Enrolment in secondary education, both sexes (number)
# 167  0.269912         ESP            WLD                                                      Research and development expenditure (% of GDP)
# 70   0.291157         ESP            WLD                                                 Combustible renewables and waste (% of total energy)
# 271  0.291967         ESP            WLD                                                        Adjusted savings: energy depletion (% of GNI)
# 0    0.300428         ESP            WLD                                             Adjusted savings: natural resources depletion (% of GNI)
# 152  0.306121         ESP            WLD                                               Population in the largest city (% of urban population)
# 160  0.308598         ESP            WLD                                             Household final consumption expenditure, etc. (% of GDP)
# 296  0.314657         ESP            WLD                  Burden of customs procedure, WEF (1=extremely inefficient to 7=extremely efficient)
# 189  0.315927         ESP            WLD                               Primary to secondary general education transition rate, both sexes (%)
# 30   0.318500         ESP            WLD                                 Terrestrial and marine protected areas (% of total territorial area)
# 301  0.320361         ESP            WLD                                               Enrolment in secondary vocational, both sexes (number)
# 27   0.320833         ESP            WLD                                      Net intake rate to Grade 1 of primary education, both sexes (%)
# 250  0.321177         ESP            WLD                                 New business density (new registrations per 1,000 people ages 15-64)
# 164  0.322257         ESP            WLD                                                         Subsidies and other transfers (% of expense)
# 119  0.324742         ESP            WLD                                                                         Arable land (% of land area)
# 327  0.325386         ESP            WLD                                                           Time required to enforce a contract (days)
# 20   0.326563         ESP            WLD                                                       Transport services (% of service exports, BoP)
# 238  0.330162         ESP            WLD                                                          Travel services (% of service imports, BoP)
# 329  0.340143         ESP            WLD                                                                 Death rate, crude (per 1,000 people)
# 158  0.347609         ESP            WLD                                        Fertilizer consumption (kilograms per hectare of arable land)
# 42   0.347952         ESP            WLD                                            Taxes on income, profits and capital gains (% of revenue)
# 17   0.352609         ESP            WLD                                    Tariff rate, most favored nation, weighted mean, all products (%)
# 92   0.352665         ESP            WLD                                                        Commercial bank branches (per 100,000 adults)
# 247  0.356562         ESP            WLD                                                   Terrestrial protected areas (% of total land area)
# 131  0.357320         ESP            WLD                                                             Compensation of employees (% of expense)
# 287  0.375047         ESP            WLD                                                Tariff rate, applied, weighted mean, all products (%)
# 115  0.379068         ESP            WLD           Labor force participation rate, total (% of total population ages 15+) (national estimate)
# 185  0.381178         ESP            WLD                                                                                Coal rents (% of GDP)
# 37   0.385869         ESP            WLD                                                              Primary completion rate, both sexes (%)
# 227  0.391085         ESP            WLD                                                                                Tax payments (number)
# 199  0.393343         ESP            WLD                                                              Lead time to export, median case (days)
# 109  0.398590         ESP            WLD                                                Automated teller machines (ATMs) (per 100,000 adults)
# 172  0.401967         ESP            WLD                                                       Gross enrolment ratio, primary, both sexes (%)
# 51   0.402923         ESP            WLD                                                       Transport services (% of service imports, BoP)
# 107  0.405551         ESP            WLD                                    Out-of-school children of primary school age, both sexes (number)
# 4    0.409959         ESP            WLD                                                           Taxes on goods and services (% of revenue)
# 201  0.421127         ESP            WLD                                                                         Other expense (% of expense)
# 2    0.421868         ESP            WLD                                            Tariff rate, applied, weighted mean, primary products (%)
# 144  0.425139         ESP            WLD                                                 Transport services (% of commercial service imports)
# 203  0.444509         ESP            WLD                                Tariff rate, most favored nation, weighted mean, primary products (%)
# 303  0.450152         ESP            WLD                                                  Railways, passengers carried (million passenger-km)
# 186  0.468800         ESP            WLD                                                  Enrolment in primary education, both sexes (number)
# 249  0.470351         ESP            WLD                                Employment to population ratio, 15+, total (%) (modeled ILO estimate)
# 111  0.487851         ESP            WLD                                                   Adjusted savings: education expenditure (% of GNI)
# 35   0.494935         ESP            WLD                                            Gross enrolment ratio, primary, gender parity index (GPI)
# 170  0.499899         ESP            WLD                                                              Lead time to import, median case (days)
# 229  0.501399         ESP            WLD                                                           Intentional homicides (per 100,000 people)
# 59   0.511921         ESP            WLD                                                       Adjusted savings: mineral depletion (% of GNI)
# 264  0.523345         ESP            WLD                                                                   Rural population growth (annual %)
# 223  0.565178         ESP            WLD                                                                     Bank capital to assets ratio (%)
# 294  0.565306         ESP            WLD                                                            Personal remittances, received (% of GDP)
# 138  0.568009         ESP            WLD                                                              Grants and other revenue (% of revenue)
# 184  0.572500         ESP            WLD                                                                 Profit tax (% of commercial profits)
# 95   0.576924         ESP            WLD                             Percentage of enrolment in primary education in private institutions (%)
# 191  0.581277         ESP            WLD                                                                Energy imports, net (% of energy use)
# 175  0.623590         ESP            WLD                           Percentage of enrolment in secondary education in private institutions (%)
# 99   0.635220         ESP            WLD                               Adjusted net savings, including particulate emission damage (% of GNI)
# 270  0.645728         ESP            WLD                                                                         Natural gas rents (% of GDP)
# 122  0.652998         ESP            WLD                            Improved sanitation facilities, urban (% of urban population with access)
# 214  0.667938         ESP            WLD      Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)
# 178  0.671941         ESP            WLD                                                            Time required to build a warehouse (days)
# 281  0.678996         ESP            WLD                                         Pupil-teacher ratio in secondary education (headcount basis)
# 193  0.691579         ESP            WLD                                            Interest rate spread (lending rate minus deposit rate, %)
# 147  0.700291         ESP            WLD                                                    Bank nonperforming loans to total gross loans (%)
# 236  0.708492         ESP            WLD        Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)
# 312  0.802296         ESP            WLD                                                      Lower secondary completion rate, both sexes (%)
# 81   0.825137         ESP            WLD                                                             Procedures to register property (number)
# 155  0.852878         ESP            WLD                                                             Procedures to build a warehouse (number)

# %%
df_cosine_results.sort_values('value').head(25)
# Out:
#         value CountryCode CountryCompare                                                         IndicatorName
# 243  0.000420         ESP            WLD              Adjusted savings: particulate emission damage (% of GNI)
# 9    0.000684         ESP            WLD                               Researchers in R&D (per million people)
# 274  0.002244         ESP            WLD                  Gross value added at factor cost (constant 2005 US$)
# 231  0.002636         ESP            WLD                             Scientific and technical journal articles
# 221  0.003198         ESP            WLD               Final consumption expenditure, etc. (constant 2005 US$)
# 308  0.003356         ESP            WLD                     Final consumption expenditure (constant 2005 US$)
# 14   0.003584         ESP            WLD                                               GNI (constant 2005 US$)
# 314  0.003732         ESP            WLD                                    GDP per capita (constant 2005 US$)
# 86   0.004500         ESP            WLD  General government final consumption expenditure (constant 2005 US$)
# 50   0.005030         ESP            WLD                      Adjusted net national income (constant 2005 US$)
# 310  0.005326         ESP            WLD                       Services, etc., value added (constant 2005 US$)
# 44   0.005464         ESP            WLD                        Fixed broadband subscriptions (per 100 people)
# 318  0.005628         ESP            WLD     Household final consumption expenditure, etc. (constant 2005 US$)
# 148  0.006068         ESP            WLD               Age dependency ratio, old (% of working-age population)
# 207  0.006096         ESP            WLD           Household final consumption expenditure (constant 2005 US$)
# 72   0.006585         ESP            WLD                               Life expectancy at birth, total (years)
# 210  0.006975         ESP            WLD                Container port traffic (TEU: 20 foot equivalent units)
# 263  0.006984         ESP            WLD                   Population density (people per sq. km of land area)
# 279  0.007386         ESP            WLD                        Gross national expenditure (constant 2005 US$)
# 13   0.007470         ESP            WLD                                    GNI per capita (constant 2005 US$)
# 283  0.007717         ESP            WLD                     Exports of goods and services (constant 2005 US$)
# 328  0.007719         ESP            WLD                          ICT goods exports (% of total goods exports)
# 10   0.008292         ESP            WLD                            Pump price for diesel fuel (US$ per liter)
# 11   0.009025         ESP            WLD                             Population ages 65 and above (% of total)
# 91   0.009147         ESP            WLD     Renewable internal freshwater resources per capita (cubic meters)

# %% [markdown]
# https://datascience-enthusiast.com/figures/cosine_sim.png

# %%
def Draw_Difference(IndicatorName,CountryCode1, CountryCode2):
    """ Draw difference between a country and the rest of the world"""
    CountryCode = CountryCode1
    conn = sqlite3.connect('../input/world-development-indicators/database.sqlite')
    df = pd.read_sql(f"""SELECT CountryName,IndicatorName,IndicatorCode,Year,Value
                   FROM Indicators
                   WHERE IndicatorName = '{IndicatorName}' 
                     AND CountryCode   = '{CountryCode}'  """,
               conn)

    length = df.shape[0]
    large_name  = df.CountryName.values[0]

    x = df['Year' ].values
    y = df['Value'].values
    x = x.reshape(length,1)
    y = y.reshape(length,1)
    fig = plt.figure()
    plt.scatter(x,y,color='red')
    regr = LinearRegression()
    regr.fit(x,y)
    plt.plot(x,regr.predict(x),color='red',label=f'{large_name}')
    otro =  pd.read_sql(f"""SELECT IndicatorName,IndicatorCode,Year,AVG(Value) As Value
                   FROM Indicators
                   WHERE IndicatorName = '{IndicatorName}' 
                     AND CountryCode != '{CountryCode}' 
                     AND CountryCode = '{CountryCode2}' 
                     group by Year""",
               conn)
    
    if otro.shape[0] == 0 :
        print(f"vacio, {IndicatorName}")
        otro =  pd.read_sql(f"""SELECT IndicatorName,IndicatorCode,Year,AVG(Value) As Value
               FROM Indicators
               WHERE IndicatorName = '{IndicatorName}' 
                 AND CountryCode != '{CountryCode}' 
                group by Year""",
           conn)
    
    length = otro.shape[0]

    x = otro['Year' ].values
    y = otro['Value'].values
    x = x.reshape(length,1)
    y = y.reshape(length,1)
    regr = LinearRegression()
    regr.fit(x,y)

    # Get Large name for the title
    CountryName2 = pd.read_sql(f"""SELECT CountryName
               FROM Indicators
               WHERE CountryCode = '{CountryCode2}'
               LIMIT 1""",
           conn).values[0][0]
    
    plt.title(f"{IndicatorName}, {large_name} vs {CountryName2} ")
    plt.scatter(x,y,color='gray')
    plt.plot(x,regr.predict(x),color='gray',label=f'{CountryName2}')
    plt.legend(loc=2)

    return plt ,df,otro

for IndicatorName in df_cosine_results.head(20).IndicatorName.values :
    try:
        plt ,df_country,df_rest = Draw_Difference(IndicatorName,CountryCode,CountryCompare)
    except :
        pass

# %%
 df_cosine_results.head(20)
# Out:
#         value CountryCode CountryCompare                                                         IndicatorName
# 243  0.000420         ESP            WLD              Adjusted savings: particulate emission damage (% of GNI)
# 9    0.000684         ESP            WLD                               Researchers in R&D (per million people)
# 274  0.002244         ESP            WLD                  Gross value added at factor cost (constant 2005 US$)
# 231  0.002636         ESP            WLD                             Scientific and technical journal articles
# 221  0.003198         ESP            WLD               Final consumption expenditure, etc. (constant 2005 US$)
# 308  0.003356         ESP            WLD                     Final consumption expenditure (constant 2005 US$)
# 14   0.003584         ESP            WLD                                               GNI (constant 2005 US$)
# 314  0.003732         ESP            WLD                                    GDP per capita (constant 2005 US$)
# 86   0.004500         ESP            WLD  General government final consumption expenditure (constant 2005 US$)
# 50   0.005030         ESP            WLD                      Adjusted net national income (constant 2005 US$)
# 310  0.005326         ESP            WLD                       Services, etc., value added (constant 2005 US$)
# 44   0.005464         ESP            WLD                        Fixed broadband subscriptions (per 100 people)
# 318  0.005628         ESP            WLD     Household final consumption expenditure, etc. (constant 2005 US$)
# 148  0.006068         ESP            WLD               Age dependency ratio, old (% of working-age population)
# 207  0.006096         ESP            WLD           Household final consumption expenditure (constant 2005 US$)
# 72   0.006585         ESP            WLD                               Life expectancy at birth, total (years)
# 210  0.006975         ESP            WLD                Container port traffic (TEU: 20 foot equivalent units)
# 263  0.006984         ESP            WLD                   Population density (people per sq. km of land area)
# 279  0.007386         ESP            WLD                        Gross national expenditure (constant 2005 US$)
# 13   0.007470         ESP            WLD                                    GNI per capita (constant 2005 US$)

# %%
CountryCode1 = 'ESP'
CountryCode2 = 'WLD'
filter_indicator = '%'
DEBUG=False
def get_comparision_df(CountryCode1,CountryCode2,filter_indicator='%',DEBUG=False):

    """ Compare two countries with a specific filter"""
    result_array = []
    df_result = pd.DataFrame()

    # We extract indicator from
    df_indicators = pd.read_sql(f"""
                   SELECT distinct(IndicatorName) as IndicatorName
                   FROM Indicators
                   WHERE  CountryCode  = '{CountryCode1}'
                          AND IndicatorName LIKE  '%{filter_indicator}%' """,
               conn)
    if DEBUG : print(f"""SELECT distinct(IndicatorName) as IndicatorName
                   FROM Indicators
                   WHERE  CountryCode  = '{CountryCode1}'
                          AND IndicatorName LIKE  '%{filter_indicator}%' """)
    df_world = pd.read_sql(f"""
                  SELECT distinct(IndicatorName) as IndicatorName
                   FROM Indicators
                   WHERE  CountryCode   = '{CountryCode2}' 
                          AND IndicatorName LIKE  '%{filter_indicator}%'""",
               conn)
    if DEBUG : print(f"""2 : SELECT distinct(IndicatorName) as IndicatorName
                   FROM Indicators
                   WHERE  CountryCode   = '{CountryCode2}' 
                          AND IndicatorName LIKE  '%{filter_indicator}%' """)

    indicators_array = df_indicators.IndicatorName.values
    world_array      = df_world.IndicatorName.values
    indicator_array  = set(indicators_array) & set( world_array)  & set( ARRAY_INDICATORS)
    indicator_array_size = len (indicator_array)

    
    SQL=  f"""
    SELECT Year,Value, CountryName,IndicatorName
    FROM Indicators
    WHERE CountryCode = '{CountryCode1}'  """ 
    df_CountryCode1_master =  pd.read_sql(SQL,conn)
    
    SQL=  f"""
    SELECT Year,Value, CountryName,IndicatorName
    FROM Indicators
    WHERE CountryCode = '{CountryCode2}'  """ 
    df_CountryCode2_master =  pd.read_sql(SQL,conn)

    for IndicatorName in tqdm(indicator_array) :
        df_CountryCode1 = df_CountryCode1_master.copy()
        df_CountryCode2 = df_CountryCode2_master.copy()
        df_1 = df_CountryCode1.loc[df_CountryCode1['IndicatorName'] == IndicatorName]
        df_2 = df_CountryCode2.loc[df_CountryCode2['IndicatorName'] == IndicatorName]

        df_dst = pd.merge(df_1, df_2, on='Year')
        length = df_dst.shape[0]
        if length < 3 : 
            if DEBUG : print(f"df_values: {IndicatorName} not enough common values  {length} ,to evaluate properly")
            continue
        dst = distance.cosine(df_dst.Value_x.values ,df_dst.Value_y.values )

        result_array.append({ 
            "value"          : dst, 
            "CountryCode"    : CountryCode1 , 
            'CountryCompare' : CountryCode2 , 
            'CountryValue'   : df_dst.Value_x.values[-1] ,
            'Region Value'   : df_dst.Value_y.values[-1] ,
            "IndicatorName"  : IndicatorName  } )

    df_result = pd.DataFrame(result_array) 

    length = df_result.shape[0]
    if DEBUG : print(df_result.columns,length)

    if length == 0 : 
        if DEBUG : print(f"Vacio: {IndicatorName} al the end")
        return None
    df_result = df_result[df_result['value'].notna()]
    df_result = df_result.sort_values('value')
    return df_result    

CountryCompare ='WLD'

df_cosine_results = get_comparision_df('ESP',CountryCompare,'%',False)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=358.0), HTML(value='')))
# /root/anaconda2/envs/jupyter/lib/python3.6/site-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
df_cosine_results
# Out:
#         value CountryCode CountryCompare  CountryValue  Region Value                                                                                        IndicatorName
# 240  0.000023         ESP            WLD  3.718636e+00  2.894279e+00                                               Logistics performance index: Overall (1=low to 5=high)
# 291  0.000068         ESP            WLD  3.590000e+01  1.586461e+01                                                Labor tax and contributions (% of commercial profits)
# 122  0.000117         ESP            WLD  9.980000e+01  8.218400e+01                            Improved sanitation facilities, urban (% of urban population with access)
# 27   0.000166         ESP            WLD  9.809294e+01  6.499488e+01                                      Net intake rate to Grade 1 of primary education, both sexes (%)
# 327  0.000185         ESP            WLD  5.100000e+02  6.298720e+02                                                           Time required to enforce a contract (days)
# 212  0.000270         ESP            WLD  4.000000e+00  6.201058e+00                                                                         Documents to export (number)
# 316  0.000277         ESP            WLD  6.668554e+01  6.567021e+01                                                                  Population, ages 15-64 (% of total)
# 255  0.000344         ESP            WLD  5.000000e+00  5.105820e+00                                                 Strength of legal rights index (0=weak to 12=strong)
# 72   0.000464         ESP            WLD  8.242683e+01  7.120961e+01                                                              Life expectancy at birth, total (years)
# 208  0.000480         ESP            WLD  7.486000e+01  6.102778e+01                                    Distance to frontier score (0=lowest performance to 100=frontier)
# 15   0.000529         ESP            WLD  1.310000e+03  1.559882e+03                                                                   Cost to export (US$ per container)
# 310  0.000531         ESP            WLD  7.817266e+11  3.558080e+13                                                      Services, etc., value added (constant 2005 US$)
# 215  0.000565         ESP            WLD  1.612044e+01  2.123189e+01                                                 Transport services (% of commercial service exports)
# 226  0.000616         ESP            WLD  7.449763e+01  7.050414e+01                                                               Services, etc., value added (% of GDP)
# 105  0.000644         ESP            WLD  9.820932e+01  1.095542e+02                                   Gross intake ratio to Grade 1 of primary education, both sexes (%)
# 274  0.000743         ESP            WLD  1.054572e+12  4.934023e+13                                                 Gross value added at factor cost (constant 2005 US$)
# 296  0.000841         ESP            WLD  4.800000e+00  4.060417e+00                  Burden of customs procedure, WEF (1=extremely inefficient to 7=extremely efficient)
# 154  0.000850         ESP            WLD  9.342000e+01  7.807000e+01                                                                   Binding coverage, all products (%)
# 262  0.000886         ESP            WLD  7.000000e+00  4.375661e+00                                                  Depth of credit information index (0=low to 8=high)
# 261  0.000918         ESP            WLD  1.400000e+03  1.877167e+03                                                                   Cost to import (US$ per container)
# 64   0.000924         ESP            WLD  1.000000e+02  8.458387e+01                                                              Access to electricity (% of population)
# 324  0.000986         ESP            WLD  5.800000e+00  4.118056e+00  Quality of port infrastructure, WEF (1=extremely underdeveloped to 7=well developed and efficien...
# 145  0.001054         ESP            WLD  1.537737e+01  6.055957e+00                                                 International tourism, receipts (% of total exports)
# 110  0.001159         ESP            WLD  1.000000e+02  7.736000e+01                                                          Binding coverage, manufactured products (%)
# 259  0.001159         ESP            WLD  4.177557e+01  2.551031e+01                                                    Travel services (% of commercial service exports)
# 89   0.001163         ESP            WLD  9.714744e+01  7.552320e+01                                 Survival rate to the last grade of primary education, both sexes (%)
# 308  0.001178         ESP            WLD  8.584414e+11  4.236374e+13                                                    Final consumption expenditure (constant 2005 US$)
# 221  0.001184         ESP            WLD  8.597951e+11  4.232853e+13                                              Final consumption expenditure, etc. (constant 2005 US$)
# 243  0.001213         ESP            WLD  1.369102e-01  2.500255e-01                                             Adjusted savings: particulate emission damage (% of GNI)
# 71   0.001246         ESP            WLD  9.844178e+01  8.903608e+01                                                          Net enrolment rate, primary, both sexes (%)
# 160  0.001304         ESP            WLD  5.802620e+01  5.997647e+01                                             Household final consumption expenditure, etc. (% of GDP)
# 20   0.001305         ESP            WLD  1.807520e+01  1.929143e+01                                                       Transport services (% of service exports, BoP)
# 120  0.001319         ESP            WLD  4.995754e+01  5.385009e+01                                                   Age dependency ratio (% of working-age population)
# 150  0.001452         ESP            WLD  3.105456e+00  1.196485e+01                                                            Goods and services expense (% of expense)
# 73   0.001460         ESP            WLD  1.007720e+00  9.737100e-01                              Gross enrolment ratio, primary and secondary, gender parity index (GPI)
# 14   0.001467         ESP            WLD  1.151073e+12  5.663609e+13                                                                              GNI (constant 2005 US$)
# 297  0.001503         ESP            WLD  7.110000e+01  8.053000e+01                                                               Binding coverage, primary products (%)
# 125  0.001559         ESP            WLD  1.308689e+01  1.616823e+01                                                                Manufacturing, value added (% of GDP)
# 161  0.001619         ESP            WLD  5.000000e+00  5.525926e+00                        Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 325  0.001625         ESP            WLD  7.502599e+01  8.134007e+01                                                          Fossil fuel energy consumption (% of total)
# 115  0.001670         ESP            WLD  5.940000e+01  6.225125e+01           Labor force participation rate, total (% of total population ages 15+) (national estimate)
# 33   0.001715         ESP            WLD  9.848973e+01  9.103225e+01                                                 Adjusted net enrolment rate, primary, both sexes (%)
# 50   0.001735         ESP            WLD  9.541172e+11  4.637541e+13                                                     Adjusted net national income (constant 2005 US$)
# 152  0.001781         ESP            WLD  1.665384e+01  1.632522e+01                                               Population in the largest city (% of urban population)
# 173  0.001795         ESP            WLD  7.708185e+01  4.609556e+01                                Out-of-pocket health expenditure (% of private expenditure on health)
# 189  0.001807         ESP            WLD  9.867530e+01  9.108381e+01                               Primary to secondary general education transition rate, both sexes (%)
# 100  0.001833         ESP            WLD  9.595604e+01  6.600383e+01                                                        Net enrolment rate, secondary, both sexes (%)
# 155  0.001950         ESP            WLD  1.300000e+01  1.429514e+01                                                             Procedures to build a warehouse (number)
# 273  0.001965         ESP            WLD  7.746410e+00  8.830064e+00                                   Insurance and financial services (% of commercial service imports)
# 265  0.001986         ESP            WLD  1.478987e+01  1.321317e+01                                                                         Trade in services (% of GDP)
# 37   0.002015         ESP            WLD  9.917982e+01  9.230936e+01                                                              Primary completion rate, both sexes (%)
# 5    0.002025         ESP            WLD  4.847244e+01  2.304696e+01                                                          Travel services (% of service exports, BoP)
# 309  0.002093         ESP            WLD  5.751506e+00  5.634491e+00                                             International tourism, expenditures (% of total imports)
# 216  0.002165         ESP            WLD  1.184860e+01  7.476701e+00                            GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent)
# 35   0.002165         ESP            WLD  1.009460e+00  9.752100e-01                                            Gross enrolment ratio, primary, gender parity index (GPI)
# 257  0.002173         ESP            WLD  3.777497e+01  4.444933e+01                        Computer, communications and other services (% of commercial service exports)
# 200  0.002216         ESP            WLD  2.078999e+01  2.351256e+01                                                                 Revenue, excluding grants (% of GDP)
# 222  0.002257         ESP            WLD  1.345380e+04  4.604072e+03                               Household final consumption expenditure per capita (constant 2005 US$)
# 143  0.002270         ESP            WLD  5.386138e+01  3.772633e+01                                                                   Agricultural land (% of land area)
# 210  0.002288         ESP            WLD  1.402016e+07  6.510986e+08                                               Container port traffic (TEU: 20 foot equivalent units)
# 53   0.002354         ESP            WLD  2.279539e+01  1.859162e+01                                  Out-of-pocket health expenditure (% of total expenditure on health)
# 7    0.002383         ESP            WLD  6.253399e+00  5.954674e+00                                                                Health expenditure, public (% of GDP)
# 326  0.002392         ESP            WLD  2.268072e+01  2.636294e+01                                                                     Industry, value added (% of GDP)
# 235  0.002457         ESP            WLD  7.935500e+01  5.338644e+01                                                                        Urban population (% of total)
# 246  0.002483         ESP            WLD  1.112000e+02  4.292096e+04                                Renewable internal freshwater resources, total (billion cubic meters)
# 224  0.002545         ESP            WLD  4.260000e+01  3.652540e+01  Share of women in wage employment in the nonagricultural sector (% of total nonagricultural empl...
# 123  0.002546         ESP            WLD  3.586443e+00  5.842442e+00                                          Energy intensity level of primary energy (MJ/$2011 PPP GDP)
# 232  0.002566         ESP            WLD  8.439816e+01  1.337488e+02                                 Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)
# 172  0.002588         ESP            WLD  1.044767e+02  1.079925e+02                                                       Gross enrolment ratio, primary, both sexes (%)
# 117  0.002601         ESP            WLD  8.879260e+00  9.966924e+00                                                                 Health expenditure, total (% of GDP)
# 279  0.002616         ESP            WLD  1.110168e+12  5.583140e+13                                                       Gross national expenditure (constant 2005 US$)
# 43   0.002638         ESP            WLD  2.061894e+01  2.256220e+01                                                                             Gross savings (% of GDP)
# 12   0.002702         ESP            WLD  3.670000e+01  4.728956e+01                      Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)
# 16   0.002702         ESP            WLD  2.845697e+03  1.223351e+03                                   Health expenditure per capita, PPP (constant 2011 international $)
# 74   0.002714         ESP            WLD  1.070000e+02  9.663492e+01                                                              Time required to get electricity (days)
# 313  0.002792         ESP            WLD  9.990000e+01  6.752295e+01                                         Improved sanitation facilities (% of population with access)
# 217  0.002805         ESP            WLD  2.443615e+01  2.239246e+01                    Population in urban agglomerations of more than 1 million (% of total population)
# 6    0.002899         ESP            WLD  3.586122e+01  3.146745e+01                                                      ICT service exports (% of service exports, BoP)
# 67   0.002902         ESP            WLD  2.235017e+01  2.247189e+01                                                                    Gross domestic savings (% of GDP)
# 39   0.002962         ESP            WLD  4.853961e+00  1.093927e+01                                         Insurance and financial services (% of service exports, BoP)
# 131  0.002990         ESP            WLD  7.486690e+00  2.226184e+01                                                             Compensation of employees (% of expense)
# 55   0.002997         ESP            WLD  4.329026e+00  8.933187e+00                                   Insurance and financial services (% of commercial service exports)
# 32   0.003012         ESP            WLD  1.000000e+02  5.857255e+01                                                           Access to non-solid fuel (% of population)
# 157  0.003068         ESP            WLD  2.625860e+00  4.001566e+00                                                               Health expenditure, private (% of GDP)
# 207  0.003194         ESP            WLD  6.272169e+11  3.303201e+13                                          Household final consumption expenditure (constant 2005 US$)
# 236  0.003215         ESP            WLD  5.900000e+01  6.349484e+01        Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)
# 205  0.003216         ESP            WLD  4.010000e+00  2.843000e+01                                                   Bound rate, simple mean, manufactured products (%)
# 75   0.003317         ESP            WLD  9.000000e+00  2.447090e+01                                                                                Time to import (days)
# 3    0.003389         ESP            WLD  1.000000e+01  2.153175e+01                                                                                Time to export (days)
# 252  0.003521         ESP            WLD  4.030000e+00  8.820000e+00                             Tariff rate, most favored nation, simple mean, manufactured products (%)
# 13   0.003656         ESP            WLD  2.469051e+04  7.894058e+03                                                                   GNI per capita (constant 2005 US$)
# 133  0.003690         ESP            WLD  2.126487e+01  2.560450e+01                                                           Adjusted savings: gross savings (% of GNI)
# 134  0.003724         ESP            WLD  7.502600e+11  1.223329e+14                                                            Gross domestic income (constant 2005 US$)
# 44   0.003729         ESP            WLD  2.726798e+01  9.596899e+00                                                       Fixed broadband subscriptions (per 100 people)
# 277  0.003747         ESP            WLD  2.071502e+01  2.550784e+01                                                                             Gross savings (% of GNI)
# 318  0.003750         ESP            WLD  6.289739e+11  3.286601e+13                                    Household final consumption expenditure, etc. (constant 2005 US$)
# 290  0.003759         ESP            WLD  4.304289e+01  4.549373e+01                                           Communications, computer, etc. (% of service exports, BoP)
# 85   0.003815         ESP            WLD  1.852532e+05  3.943012e+07                                                                                 Forest area (sq. km)
# 164  0.003875         ESP            WLD  6.757085e+01  4.766410e+01                                                         Subsidies and other transfers (% of expense)
# 230  0.003947         ESP            WLD  3.668379e+01  3.076202e+01                                                                         Forest area (% of land area)
# 48   0.003986         ESP            WLD  1.630000e+00  1.340000e+00                                                              Pump price for gasoline (US$ per liter)
# 41   0.003990         ESP            WLD  4.000000e+00  7.259259e+00                                                                         Documents to import (number)
# 214  0.004003         ESP            WLD  7.440000e+01  6.866070e+01      Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)
# 175  0.004029         ESP            WLD  2.715305e+01  2.296021e+01                           Percentage of enrolment in secondary education in private institutions (%)
# 112  0.004186         ESP            WLD  3.146723e+00  9.329619e+00                                           Military expenditure (% of central government expenditure)
# 106  0.004283         ESP            WLD  1.748829e+01  1.513519e+01                                            Adjusted savings: consumption of fixed capital (% of GNI)
# 180  0.004390         ESP            WLD  2.046581e+04  6.463941e+03                                          Adjusted net national income per capita (constant 2005 US$)
# 218  0.004488         ESP            WLD  1.141207e+01  4.605644e+00                   Percentage of repeaters in secondary general education, all grades, both sexes (%)
# 10   0.004603         ESP            WLD  1.550000e+00  1.170000e+00                                                           Pump price for diesel fuel (US$ per liter)
# 45   0.004663         ESP            WLD  1.004600e+02  1.171013e+02                                                         Livestock production index (2004-2006 = 100)
# 305  0.004770         ESP            WLD  7.901215e+11  5.176362e+13                               Household final consumption expenditure, PPP (current international $)
# 58   0.004797         ESP            WLD  6.066100e+07  1.123200e+09                                                            International tourism, number of arrivals
# 269  0.004824         ESP            WLD  1.305654e+02  7.521412e+01                                                     Gross enrolment ratio, secondary, both sexes (%)
# 127  0.004887         ESP            WLD  3.166913e+04  1.407309e+04                                                  GNI per capita, PPP (constant 2011 international $)
# 283  0.005282         ESP            WLD  3.724670e+11  1.903094e+13                                                    Exports of goods and services (constant 2005 US$)
# 144  0.005345         ESP            WLD  2.333632e+01  2.592127e+01                                                 Transport services (% of commercial service imports)
# 9    0.005477         ESP            WLD  2.889457e+03  1.268319e+03                                                              Researchers in R&D (per million people)
# 323  0.005483         ESP            WLD  3.400000e+00  2.920454e+00                                                                     Hospital beds (per 1,000 people)
# 171  0.005675         ESP            WLD  3.380000e+00  4.610000e+00                           Tariff rate, most favored nation, weighted mean, manufactured products (%)
# 249  0.005710         ESP            WLD  4.440000e+01  5.971112e+01                                Employment to population ratio, 15+, total (%) (modeled ILO estimate)
# 76   0.005824         ESP            WLD  4.114286e+01  2.253837e+01                                        Proportion of seats held by women in national parliaments (%)
# 314  0.005934         ESP            WLD  2.525970e+04  8.008632e+03                                                                   GDP per capita (constant 2005 US$)
# 136  0.006101         ESP            WLD  6.070426e+01  5.940856e+01                                                                                     Trade (% of GDP)
# 31   0.006110         ESP            WLD  6.322052e+01  6.826738e+01                                                      Manufactures imports (% of merchandise imports)
# 254  0.006173         ESP            WLD  2.874906e+01  2.960144e+01                                                             Imports of goods and services (% of GDP)
# 11   0.006228         ESP            WLD  1.844159e+01  8.102776e+00                                                            Population ages 65 and above (% of total)
# 54   0.006317         ESP            WLD  7.666208e+00  1.704951e+01                                                  High-technology exports (% of manufactured exports)
# 78   0.006321         ESP            WLD  4.140000e+00  9.340000e+00                                      Tariff rate, most favored nation, simple mean, all products (%)
# 198  0.006395         ESP            WLD  4.173952e+04  1.254297e+03                                               Agriculture value added per worker (constant 2005 US$)
# 87   0.006397         ESP            WLD  2.235170e+05  2.889754e+07                                                   Teachers in primary education, both sexes (number)
# 119  0.006496         ESP            WLD  2.512945e+01  1.085166e+01                                                                         Arable land (% of land area)
# 47   0.006526         ESP            WLD  4.259500e+04  1.974334e+04                                                        GDP per person employed (constant 1990 PPP $)
# 24   0.006528         ESP            WLD  1.783642e+01  2.422251e+01                                                    Travel services (% of commercial service imports)
# 56   0.006567         ESP            WLD  1.045284e+02  9.058730e+01                                                  Fertilizer consumption (% of fertilizer production)
# 209  0.006577         ESP            WLD  4.540346e+00  1.105688e+01                                                            ICT goods imports (% total goods imports)
# 1    0.006629         ESP            WLD  1.475756e+12  1.037315e+14                                                             GDP, PPP (constant 2011 international $)
# 251  0.006648         ESP            WLD  3.960000e+00  3.245000e+01                                                            Bound rate, simple mean, all products (%)
# 317  0.006769         ESP            WLD  1.000000e+02  5.032770e+01                            Improved sanitation facilities, rural (% of rural population with access)
# 211  0.007202         ESP            WLD  1.920822e+01  2.187104e+01                                                             Gross fixed capital formation (% of GDP)
# 51   0.007249         ESP            WLD  3.290260e+01  2.463054e+01                                                       Transport services (% of service imports, BoP)
# 94   0.007471         ESP            WLD  1.914403e+01  2.226744e+01                                                                   Gross capital formation (% of GDP)
# 97   0.007529         ESP            WLD  1.079814e+01  8.124557e+00                                                              Food imports (% of merchandise imports)
# 121  0.007531         ESP            WLD  4.913344e+01  4.878953e+01                                                                         Merchandise trade (% of GDP)
# 183  0.007794         ESP            WLD  7.509603e+11  5.439941e+13                         Household final consumption expenditure, PPP (constant 2011 international $)
# 219  0.007811         ESP            WLD  9.216931e-01  2.294644e+00                                                                      Military expenditure (% of GDP)
# 148  0.007832         ESP            WLD  2.765456e+01  1.233859e+01                                              Age dependency ratio, old (% of working-age population)
# 174  0.007902         ESP            WLD  1.410000e+01  2.955434e+01                                                         Private credit bureau coverage (% of adults)
# 284  0.007948         ESP            WLD  1.610000e+00  3.350000e+00                                       Tariff rate, applied, weighted mean, manufactured products (%)
# 192  0.008006         ESP            WLD  3.556207e+10  1.912546e+12                                                         Agriculture, value added (constant 2005 US$)
# 81   0.008015         ESP            WLD  5.000000e+00  5.804865e+00                                                             Procedures to register property (number)
# 238  0.008048         ESP            WLD  2.589535e+01  2.251033e+01                                                          Travel services (% of service imports, BoP)
# 234  0.008088         ESP            WLD  4.055764e+01  1.518472e+01                                                       Fixed telephone subscriptions (per 100 people)
# 153  0.008174         ESP            WLD  7.105410e+00  5.880200e+00                                                                     Interest payments (% of expense)
# 91   0.008259         ESP            WLD  2.385240e+03  6.013166e+03                                    Renewable internal freshwater resources per capita (cubic meters)
# 194  0.008401         ESP            WLD  5.573401e+03  3.064496e+03                                                          Electric power consumption (kWh per capita)
# 23   0.008440         ESP            WLD  5.000000e+01  4.075132e+01                                                             Total tax rate (% of commercial profits)
# 263  0.008456         ESP            WLD  9.277024e+01  5.596471e+01                                                  Population density (people per sq. km of land area)
# 227  0.008558         ESP            WLD  9.000000e+00  2.564127e+01                                                                                Tax payments (number)
# 220  0.008807         ESP            WLD  3.195520e+01  2.980712e+01                                                             Exports of goods and services (% of GDP)
# 156  0.008969         ESP            WLD  5.108085e+01  4.102652e+01                        Computer, communications and other services (% of commercial service imports)
# 181  0.009190         ESP            WLD  2.800000e+00  1.920000e+01                                                     Mortality rate, neonatal (per 1,000 live births)
# 25   0.009252         ESP            WLD  7.000000e+00  6.910053e+00                                                  Start-up procedures to register a business (number)
# 190  0.009597         ESP            WLD  2.230298e+01  3.993745e+01                                            Age dependency ratio, young (% of working-age population)
# 182  0.009677         ESP            WLD  6.937157e+01  7.062823e+01                                                      Manufactures exports (% of merchandise exports)
# 132  0.009950         ESP            WLD  2.904010e+05  3.254462e+07                                                 Teachers in secondary education, both sexes (number)
# 302  0.009995         ESP            WLD  2.064500e+01  4.661365e+01                                                             Rural population (% of total population)
# 62   0.010119         ESP            WLD  7.255856e+01  4.417996e+01                                           Communications, computer, etc. (% of service imports, BoP)
# 233  0.010283         ESP            WLD  9.933828e+00  1.274346e+00                                                                  Permanent cropland (% of land area)
# 188  0.010621         ESP            WLD  1.320000e+00  2.482718e+00                                                             Fertility rate, total (births per woman)
# 63   0.010644         ESP            WLD  1.088100e+02  1.229987e+02                                                              Food production index (2004-2006 = 100)
# 223  0.010679         ESP            WLD  7.241612e+00  9.962707e+00                                                                     Bank capital to assets ratio (%)
# 108  0.010804         ESP            WLD  2.821651e+00  3.116015e+00                                                                  Agriculture, value added (% of GDP)
# 82   0.010888         ESP            WLD  1.487286e+01  2.622701e+01                                                                   Population, ages 0-14 (% of total)
# 288  0.011122         ESP            WLD  2.139500e+05  2.720662e+07                                                                        Armed forces personnel, total
# 275  0.011409         ESP            WLD  2.362679e+11  1.535185e+13                                                            Industry, value added (constant 2005 US$)
# 77   0.011704         ESP            WLD  4.080632e+03  3.851312e+03                                                                        Cereal yield (kg per hectare)
# 295  0.011909         ESP            WLD  1.490000e+00  6.800000e+00                                                  Tariff rate, applied, simple mean, all products (%)
# 319  0.012005         ESP            WLD  7.280000e+01  5.089587e+01                                                       Employment in services (% of total employment)
# 90   0.012596         ESP            WLD  8.593115e+01  3.288329e+01                                                      Gross enrolment ratio, tertiary, both sexes (%)
# 241  0.012651         ESP            WLD  2.483821e+11  1.324608e+13                                                    Gross fixed capital formation (constant 2005 US$)
# 266  0.012942         ESP            WLD  2.469369e+11  1.363558e+13                                                          Gross capital formation (constant 2005 US$)
# 42   0.013135         ESP            WLD  2.007158e+01  2.174934e+01                                            Taxes on income, profits and capital gains (% of revenue)
# 245  0.013317         ESP            WLD  7.161857e+00  1.422066e+01                                                                               Tax revenue (% of GDP)
# 28   0.013477         ESP            WLD  1.092190e+01  8.307369e+00                                         Insurance and financial services (% of service imports, BoP)
# 282  0.013687         ESP            WLD  1.220120e+00  1.102930e+00                                           Gross enrolment ratio, tertiary, gender parity index (GPI)
# 178  0.013693         ESP            WLD  2.050000e+02  1.604941e+02                                                            Time required to build a warehouse (days)
# 213  0.014032         ESP            WLD  1.373058e+11  9.872163e+12                                                       Manufacturing, value added (constant 2005 US$)
# 225  0.014117         ESP            WLD  3.108900e+01  1.016181e+01                                      Share of tariff lines with specific rates, primary products (%)
# 176  0.014200         ESP            WLD  7.619000e+01  4.068914e+01                                                                      Internet users (per 100 people)
# 21   0.014337         ESP            WLD  2.671805e+03  1.897945e+03                                                         Energy use (kg of oil equivalent per capita)
# 40   0.014428         ESP            WLD  9.588371e+01  5.376516e+01                                                   Gross enrolment ratio, pre-primary, both sexes (%)
# 196  0.014909         ESP            WLD  1.151100e+02  1.251318e+02                                                              Crop production index (2004-2006 = 100)
# 95   0.014921         ESP            WLD  3.167808e+01  1.299010e+01                             Percentage of enrolment in primary education in private institutions (%)
# 86   0.015330         ESP            WLD  2.313540e+11  9.300149e+12                                 General government final consumption expenditure (constant 2005 US$)
# 312  0.016202         ESP            WLD  8.088891e+01  7.300173e+01                                                      Lower secondary completion rate, both sexes (%)
# 116  0.016338         ESP            WLD  3.799463e+00  3.825631e+00                                                   Ores and metals imports (% of merchandise imports)
# 68   0.016672         ESP            WLD  1.250000e+01  4.833568e+01                                                            Time required to register property (days)
# 167  0.017070         ESP            WLD  1.269160e+00  2.177305e+00                                                      Research and development expenditure (% of GDP)
# 26   0.017151         ESP            WLD  1.580000e+02  2.607127e+02                                                                Time to prepare and pay taxes (hours)
# 169  0.017550         ESP            WLD  2.310000e+01  2.882185e+01                                                       Employment in industry (% of total employment)
# 177  0.017791         ESP            WLD  1.957749e+01  8.452133e+00                                               Alternative and nuclear energy (% of total energy use)
# 142  0.018274         ESP            WLD  1.962363e+01  1.754813e+01                                          General government final consumption expenditure (% of GDP)
# 22   0.018315         ESP            WLD  1.150583e+00  1.407721e+00                                        Agricultural raw materials imports (% of merchandise imports)
# 278  0.019204         ESP            WLD  4.670000e+00  1.105000e+01                                  Tariff rate, most favored nation, simple mean, primary products (%)
# 92   0.019602         ESP            WLD  7.024744e+01  1.345754e+01                                                        Commercial bank branches (per 100,000 adults)
# 158  0.019907         ESP            WLD  1.391527e+02  1.199210e+02                                        Fertilizer consumption (kilograms per hectare of arable land)
# 286  0.020352         ESP            WLD  2.377390e+00  4.586016e+00                             Percentage of repeaters in primary education, all grades, both sexes (%)
# 320  0.020363         ESP            WLD  2.523181e+07  2.779919e+09                                                                      Cereal production (metric tons)
# 128  0.020485         ESP            WLD  3.320706e+00  4.010887e+00                                                   Ores and metals exports (% of merchandise exports)
# 135  0.021019         ESP            WLD  7.946313e+00  1.142239e+01                               Adjusted net savings, excluding particulate emission damage (% of GNI)
# 168  0.021385         ESP            WLD  1.410000e+00  6.520000e+00                                         Tariff rate, applied, simple mean, manufactured products (%)
# 34   0.022527         ESP            WLD  1.970000e+00  8.840000e+00                                              Tariff rate, applied, simple mean, primary products (%)
# 202  0.022544         ESP            WLD  2.091229e+01  1.084323e+01                                             Electricity production from nuclear sources (% of total)
# 329  0.022639         ESP            WLD  8.300000e+00  7.801129e+00                                                                 Death rate, crude (per 1,000 people)
# 231  0.023563         ESP            WLD  2.291030e+04  8.427565e+05                                                            Scientific and technical journal articles
# 292  0.023884         ESP            WLD  6.811344e-03  5.600680e-01                                                                  Lifetime risk of maternal death (%)
# 65   0.023976         ESP            WLD  1.574528e+01  1.812472e+01                                   Renewable energy consumption (% of total final energy consumption)
# 18   0.024826         ESP            WLD  9.723410e+00  5.619464e+00                                                                     Interest payments (% of revenue)
# 36   0.025185         ESP            WLD  1.540000e+01  4.110006e+01                         Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)
# 93   0.025933         ESP            WLD  1.556785e+01  9.384242e+00                                                              Food exports (% of merchandise exports)
# 298  0.026292         ESP            WLD  1.470000e+04  1.800000e+02                                       Lifetime risk of maternal death (1 in: rate varies by country)
# 256  0.026439         ESP            WLD  8.734716e+00  8.115611e+00                                    Electric power transmission and distribution losses (% of output)
# 149  0.027303         ESP            WLD  4.100000e+00  1.981007e+01                                                    Employment in agriculture (% of total employment)
# 124  0.028198         ESP            WLD  1.934798e-01  4.737067e-01                                                   Adjusted savings: carbon dioxide damage (% of GNI)
# 315  0.028431         ESP            WLD  5.200000e+00  2.606508e+01                                           Cost of business start-up procedures (% of GNI per capita)
# 4    0.028520         ESP            WLD  9.558768e+00  3.435954e+01                                                           Taxes on goods and services (% of revenue)
# 328  0.028834         ESP            WLD  1.071439e+00  9.794158e+00                                                         ICT goods exports (% of total goods exports)
# 267  0.029703         ESP            WLD  3.790000e+00  4.543000e+01                                                        Bound rate, simple mean, primary products (%)
# 140  0.029964         ESP            WLD  7.626969e-02  3.302237e-01                                                                              Forest rents (% of GDP)
# 258  0.030805         ESP            WLD  6.641700e+10  1.071589e+12                         Electricity production from renewable sources, excluding hydroelectric (kWh)
# 229  0.030955         ESP            WLD  7.601518e-01  5.658178e+00                                                           Intentional homicides (per 100,000 people)
# 52   0.031096         ESP            WLD  2.958475e+01  2.093183e+01                                         Renewable electricity output (% of total electricity output)
# 244  0.034534         ESP            WLD  3.972541e+00  1.843665e+01                                 Share of tariff lines with international peaks, primary products (%)
# 280  0.035557         ESP            WLD  1.162745e-01  1.143541e+01                            Share of tariff lines with international peaks, manufactured products (%)
# 250  0.035779         ESP            WLD  2.970000e+00  4.005581e+00                                 New business density (new registrations per 1,000 people ages 15-64)
# 46   0.036499         ESP            WLD  1.260121e+01  2.449428e+01                                           Pupil-teacher ratio in primary education (headcount basis)
# 84   0.037374         ESP            WLD  7.806000e+03  4.419500e+03                                                         Railways, goods transported (million ton-km)
# 186  0.040599         ESP            WLD  2.934648e+06  7.135719e+08                                                  Enrolment in primary education, both sexes (number)
# 289  0.040899         ESP            WLD  7.188036e+01  9.456248e+01                                        Market capitalization of listed domestic companies (% of GDP)
# 113  0.041049         ESP            WLD  3.419000e+03  4.408600e+04                                                                     Listed domestic companies, total
# 237  0.042242         ESP            WLD  1.074459e+00  1.264977e+01                                     Share of tariff lines with international peaks, all products (%)
# 80   0.042428         ESP            WLD  9.573281e+01  1.159858e+02                                                 Stocks traded, turnover ratio of domestic shares (%)
# 99   0.042913         ESP            WLD  7.809403e+00  1.115946e+01                               Adjusted net savings, including particulate emission damage (% of GNI)
# 79   0.043501         ESP            WLD  6.537262e+00  1.481026e+00                                                   Net incurrence of liabilities, domestic (% of GDP)
# 104  0.046292         ESP            WLD  1.079316e+00  1.556777e+00                                        Agricultural raw materials exports (% of merchandise exports)
# 130  0.048443         ESP            WLD  1.124600e+07  1.214972e+09                                                          International tourism, number of departures
# 281  0.050109         ESP            WLD  1.135027e+01  1.721370e+01                                         Pupil-teacher ratio in secondary education (headcount basis)
# 146  0.051582         ESP            WLD  4.980000e+01  1.179524e+01                                                        Public credit registry coverage (% of adults)
# 304  0.051626         ESP            WLD  6.300351e+02  1.960293e+02                                       Agricultural machinery, tractors per 100 sq. km of arable land
# 242  0.052192         ESP            WLD  4.100000e+00  4.250000e+01                                                                  Mortality rate, under-5 (per 1,000)
# 206  0.052357         ESP            WLD  2.470000e+01  5.933420e+00                                                         Unemployment, total (% of total labor force)
# 69   0.053562         ESP            WLD  8.522000e+00  4.476558e+01                                        Adolescent fertility rate (births per 1,000 women ages 15-19)
# 159  0.054536         ESP            WLD  1.904832e+01  4.029799e+01                                                Electricity production from coal sources (% of total)
# 303  0.054646         ESP            WLD  2.381500e+04  3.025000e+03                                                  Railways, passengers carried (million passenger-km)
# 29   0.055187         ESP            WLD  3.776541e+00  1.046931e+01                                                    Adjusted savings: net national savings (% of GNI)
# 187  0.055519         ESP            WLD  2.749260e+06  5.063428e+08                                                  Enrolment in secondary general, both sexes (number)
# 109  0.056665         ESP            WLD  1.196279e+02  4.397288e+01                                                Automated teller machines (ATMs) (per 100,000 adults)
# 163  0.059959         ESP            WLD  3.500000e+00  3.170000e+01                                                       Mortality rate, infant (per 1,000 live births)
# 276  0.060391         ESP            WLD  5.212253e+00  4.097084e+00                                                 Electricity production from oil sources (% of total)
# 248  0.061384         ESP            WLD  1.206425e+00  1.382123e+01                                                                  Total reserves in months of imports
# 118  0.063541         ESP            WLD  9.644541e+01  1.154909e+02                                                                   Wholesale price index (2010 = 100)
# 253  0.063634         ESP            WLD  7.309773e+01  1.079573e+02                                                                Stocks traded, total value (% of GDP)
# 141  0.064166         ESP            WLD  7.883273e+00  2.668245e+00                                          Share of tariff lines with specific rates, all products (%)
# 96   0.065026         ESP            WLD  3.296359e+06  5.685367e+08                                                Enrolment in secondary education, both sexes (number)
# 111  0.069044         ESP            WLD  4.397638e+00  4.156796e+00                                                   Adjusted savings: education expenditure (% of GNI)
# 126  0.070677         ESP            WLD  2.259527e+01  4.720662e+00                  Electricity production from renewable sources, excluding hydroelectric (% of total)
# 66   0.075074         ESP            WLD  1.400000e+01  2.044233e+01                                                             Time required to start a business (days)
# 8    0.076004         ESP            WLD  1.078493e+02  9.626505e+01                                                       Mobile cellular subscriptions (per 100 people)
# 195  0.077015         ESP            WLD -1.470318e-01  2.510876e+00                                                                Inflation, consumer prices (annual %)
# 83   0.082332         ESP            WLD  6.674910e+00  1.073333e+01                                                              Fuel exports (% of merchandise exports)
# 201  0.082365         ESP            WLD  1.473159e+01  7.037785e+00                                                                         Other expense (% of expense)
# 114  0.083867         ESP            WLD  9.371714e+00  1.218684e+01                                                     Marine protected areas (% of territorial waters)
# 293  0.085806         ESP            WLD  2.093401e-01  1.101217e+00                                 Share of tariff lines with specific rates, manufactured products (%)
# 285  0.088454         ESP            WLD -5.792270e-01  2.288381e+00                                                        Services, etc., value added (annual % growth)
# 268  0.089227         ESP            WLD  2.478221e+00  1.997813e+00                                                    Foreign direct investment, net inflows (% of GDP)
# 98   0.090862         ESP            WLD  2.278448e+00  2.138162e+00                                                   Foreign direct investment, net outflows (% of GDP)
# 239  0.093516         ESP            WLD -3.965585e-01  2.034474e+00                                                                   Inflation, GDP deflator (annual %)
# 307  0.098822         ESP            WLD -2.802255e+00  1.006653e+00                                   General government final consumption expenditure (annual % growth)
# 57   0.104061         ESP            WLD  6.989474e+00  1.606693e+01                                       Electricity production from hydroelectric sources (% of total)
# 301  0.106271         ESP            WLD  5.470990e+05  6.219393e+07                                               Enrolment in secondary vocational, both sexes (number)
# 30   0.107217         ESP            WLD  2.531795e+01  1.404186e+01                                 Terrestrial and marine protected areas (% of total territorial area)
# 138  0.109762         ESP            WLD  1.737289e+01  1.576473e+01                                                              Grants and other revenue (% of revenue)
# 247  0.110132         ESP            WLD  2.901139e+01  1.431491e+01                                                   Terrestrial protected areas (% of total land area)
# 199  0.111324         ESP            WLD  3.000000e+00  2.636364e+00                                                              Lead time to export, median case (days)
# 272  0.128475         ESP            WLD  1.360771e+00  2.491769e+00                                                                                GDP growth (annual %)
# 151  0.130081         ESP            WLD -1.779925e-01  2.093874e+00                                                                   Urban population growth (annual %)
# 321  0.154715         ESP            WLD  5.057732e+00  3.277477e+00                                                      Exports of goods and services (annual % growth)
# 170  0.159343         ESP            WLD  2.000000e+00  3.102804e+00                                                              Lead time to import, median case (days)
# 38   0.161251         ESP            WLD -2.927148e+00  2.079738e+00                                                Final consumption expenditure, etc. (annual % growth)
# 193  0.162857         ESP            WLD  1.805833e+00  7.105000e+00                                            Interest rate spread (lending rate minus deposit rate, %)
# 311  0.166211         ESP            WLD -1.440589e+00  2.282894e+00                                                                                GNI growth (annual %)
# 162  0.167469         ESP            WLD  1.456906e-01  4.790698e+00                                                             Total natural resources rents (% of GDP)
# 103  0.170276         ESP            WLD  1.240000e+08  2.814000e+10                                                          Arms imports (SIPRI trend indicator values)
# 60   0.179219         ESP            WLD  6.377524e+06  2.133164e+08                                                                   International migrant stock, total
# 184  0.182573         ESP            WLD  1.330000e+01  1.588708e+01                                                                 Profit tax (% of commercial profits)
# 260  0.186904         ESP            WLD -4.631964e-01  1.201325e+00                                                                         Population growth (annual %)
# 129  0.190512         ESP            WLD  2.493961e+01  2.244597e+01                                         Electricity production from natural gas sources (% of total)
# 88   0.198346         ESP            WLD -2.972263e+00  2.400756e+00                                      Household final consumption expenditure, etc. (annual % growth)
# 204  0.199504         ESP            WLD -3.340291e-01  2.357231e+00                                                       Adjusted net national income (annual % growth)
# 179  0.201489         ESP            WLD -8.916626e+00 -4.954938e+00                                                                      Cash surplus/deficit (% of GDP)
# 101  0.218657         ESP            WLD -3.062723e+00  2.149499e+00                                            Household final consumption expenditure (annual % growth)
# 17   0.223011         ESP            WLD  2.220000e+00  4.040000e+00                                    Tariff rate, most favored nation, weighted mean, all products (%)
# 294  0.230520         ESP            WLD  2.257983e-01  6.832408e-01                                                            Personal remittances, received (% of GDP)
# 287  0.261626         ESP            WLD  1.020000e+00  2.880000e+00                                                Tariff rate, applied, weighted mean, all products (%)
# 0    0.265706         ESP            WLD  3.438640e-02  2.763070e+00                                             Adjusted savings: natural resources depletion (% of GNI)
# 61   0.275943         ESP            WLD  1.519286e-02  3.039110e+00                                                                                 Oil rents (% of GDP)
# 49   0.277231         ESP            WLD  1.369246e+01  3.094068e+00                                                        International migrant stock (% of population)
# 70   0.280855         ESP            WLD  6.167207e+00  9.903444e+00                                                 Combustible renewables and waste (% of total energy)
# 306  0.283326         ESP            WLD -1.117110e+00  1.068077e+00                                                                     GNI per capita growth (annual %)
# 139  0.294022         ESP            WLD -2.744568e+00  9.362659e-01                                 Household final consumption expenditure per capita growth (annual %)
# 271  0.297470         ESP            WLD  8.531443e-03  2.144120e+00                                                        Adjusted savings: energy depletion (% of GNI)
# 19   0.309952         ESP            WLD -6.918938e-03  1.141548e+00                                            Adjusted net national income per capita (annual % growth)
# 228  0.331537         ESP            WLD -3.683158e-01  9.274125e-01                                                    Net incurrence of liabilities, foreign (% of GDP)
# 185  0.381161         ESP            WLD  3.117627e-03  2.727395e-01                                                                                Coal rents (% of GDP)
# 2    0.394782         ESP            WLD  3.500000e-01  2.070000e+00                                            Tariff rate, applied, weighted mean, primary products (%)
# 197  0.409994         ESP            WLD -2.487486e+00  2.804455e+00                                                      Gross fixed capital formation (annual % growth)
# 203  0.410441         ESP            WLD  9.500000e-01  3.050000e+00                                Tariff rate, most favored nation, weighted mean, primary products (%)
# 147  0.422599         ESP            WLD  8.452782e+00  4.234214e+00                                                    Bank nonperforming loans to total gross loans (%)
# 107  0.450018         ESP            WLD  4.242200e+04  5.925538e+07                                    Out-of-school children of primary school age, both sexes (number)
# 166  0.451461         ESP            WLD -3.646813e+00  2.493719e+00                                                            Gross capital formation (annual % growth)
# 300  0.457736         ESP            WLD -1.349338e+00  2.516950e+00                                                         Manufacturing, value added (annual % growth)
# 59   0.472967         ESP            WLD  2.585496e-02  4.529434e-01                                                       Adjusted savings: mineral depletion (% of GNI)
# 270  0.530508         ESP            WLD  4.647670e-04  3.954335e-01                                                                         Natural gas rents (% of GDP)
# 299  0.562202         ESP            WLD -3.737019e+00  2.764515e+00                                                           Agriculture, value added (annual % growth)
# 322  0.668248         ESP            WLD  3.206138e+00  2.056885e-01                                                    External balance on goods and services (% of GDP)
# 102  0.727231         ESP            WLD -6.527512e+00  2.160171e+00                                                              Industry, value added (annual % growth)
# 191  0.773808         ESP            WLD  7.332000e+01 -3.323562e+00                                                                Energy imports, net (% of energy use)
# 264  1.791141         ESP            WLD -1.551949e+00  2.054110e-01                                                                   Rural population growth (annual %)

# %%
for IndicatorName in df_cosine_results.head(20).IndicatorName.values :
    try:
        plt ,df_country,df_rest = Draw_Difference(IndicatorName,CountryCode,CountryCompare)
    except :
        pass
